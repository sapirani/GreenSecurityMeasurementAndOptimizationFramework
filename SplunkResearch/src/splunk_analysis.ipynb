# %%
import numpy as np
import altair as alt
from tqdm import tqdm
import sys
sys.path.append('../../')
from Scanner.general_consts import *
# alt.data_transformers.enable('csv')
import csv
import json

import os

import pandas as pd
from scipy import integrate
import matplotlib.pyplot as plt
sys.path.insert(1, '/home/shouei/GreenSecurity-FirstExperiment/SplunkResearch')

from resources.section_logtypes import section_logtypes
from resources.logtypes import logtypes
from experiment_manager import ExperimentManager
log_types_str = [f"{logtype[0].lower()}_{logtype[1]}" for logtype in logtypes]
# alt.renderers.enable('altair_saver', fmts=['png'])
num_of_logtypes = 30

# %%
manager = ExperimentManager("../experiments/")
# expirment_dir = "/home/shouei/GreenSecurity-FirstExperiment/SplunkResearch/experiments/exp_20230928_211413"
# expirment_dir = "/home/shouei/GreenSecurity-FirstExperiment/SplunkResearch/experiments/exp_20230929_111545"
# expirment_dir = "/home/shouei/GreenSecurity-FirstExperiment/SplunkResearch/experiments/exp_20231117_081610"
# expirment_dir = "/home/shouei/GreenSecurity-FirstExperiment/SplunkResearch/experiments/exp_20231202_212326"
expirment_dir = manager.get_last_experiment_dir()
expirment_dir
# Out:
# '../experiments/exp_20231207_141455'

# %%
#load json file
with open(f'{expirment_dir}/train/reward_values_dict.json') as f:
    train_values = json.load(f)
train_values.keys()
# Out:
# dict_keys(['energy', 'alerts', 'distributions', 'fraction', 'duration', 'num_of_rules'])

# %%
alt.data_transformers.enable('csv')
# Out:
# DataTransformerRegistry.enable('csv')

# %%
energy_df_model_train = pd.DataFrame(train_values['energy'], columns=['energy'])
energy_df_model_train = energy_df_model_train[energy_df_model_train['energy'] != 0].reset_index()
energy_df_model_train.rename(columns={'index': 'episode'}, inplace=True)

# %%
#load json file
with open(f'{expirment_dir}/train/reward_dict.json') as f:
    train_values_reward = json.load(f)
train_values.keys()
# sum each 28 rewards to get the total reward per episode
rewards_df = pd.DataFrame(train_values_reward['total'], columns=['rewards'])
rewards_df = rewards_df.reset_index()
rewards_df.rename(columns={'index': 'step'}, inplace=True)
rewards_df['episode'] = rewards_df['step'] 
rewards_df = rewards_df.groupby('episode').sum().reset_index()
rewards_df['episode'] = rewards_df['episode'] + 1

rewards_df
# rewards_total_df = rewards_total_df[rewards_total_df['total_reward'] < 100]
alt.Chart(rewards_df).mark_line().encode(
    x='step',
    y='rewards',
    
).properties(
    title=' Total Reward',
    width=800,
)
# Out:
# alt.Chart(...)

# %%
# chart for fraction reward
rewards_df['rewards_fraction'] = rewards_df['rewards'] / num_of_logtypes
alt.Chart(rewards_df).mark_line().encode(
    x='episode',
    y='rewards_fraction',
    
).properties(
    title=' Fraction Reward',
    width=800,
)
# Out:
# alt.Chart(...)

# %%
rewards_distributions_df = pd.DataFrame(train_values['distributions'], columns=['distribution']).reset_index()
rewards_distributions_df.rename(columns={'index': 'episode'}, inplace=True)
# rewards_distributions_df['episode'] = rewards_distributions_df['step'] // num_of_logtypes
# rewards_distributions_df = rewards_distributions_df.groupby('episode').sum().reset_index()
# rewards_distributions_df['episode'] = rewards_distributions_df['episode'] + 1
alt.Chart(rewards_distributions_df).mark_line().encode(
    x='episode',
    y='distribution',
    
).properties(
    title='Distributions Values',
    width=800,
)
# Out:
# alt.Chart(...)

# %%
values_df = pd.DataFrame(train_values.values()).T
values_df.columns = train_values.keys()
values_df.reset_index(inplace=True)

# %%
import altair as alt

# Filter the DataFrame
filtered_df = values_df[values_df['num_of_rules'] == 6]

# Create the energy line chart
energy_chart = alt.Chart(filtered_df).mark_line(color='red').encode(
    x='index',
    y=alt.Y('energy:Q', axis=alt.Axis(title='Energy')),
    opacity=alt.value(0.5)
).properties(
    title='Energy and Duration',
    width=800,
)

# Create the duration line chart
duration_chart = alt.Chart(filtered_df).mark_line(color='blue').encode(
    x='index',
    y=alt.Y('duration:Q', axis=alt.Axis(title='Duration')),
    opacity=alt.value(0.5)
)

# Combine the two charts with independent y-scales
combined_chart = alt.layer(energy_chart, duration_chart).resolve_scale(y='independent')

# Create manual legend
legend_df = pd.DataFrame({
    'variable': ['Energy', 'Duration'],
    'color': ['red', 'blue']
})

legend_symbols = alt.Chart(legend_df).mark_square(size=100).encode(
    y=alt.Y('variable:N', axis=None),
    color=alt.Color('color:N', scale=None)
)

legend_text = alt.Chart(legend_df).mark_text(align='left', dx=5).encode(
    y=alt.Y('variable:N', axis=None),
    text='variable:N'
)

legend = alt.hconcat(legend_symbols, legend_text)

# Display the chart with the manual legend
alt.hconcat(combined_chart, legend)
# Out:
# alt.HConcatChart(...)

# %%
def dict_to_df(values_dict):
    energy_df = pd.DataFrame([values_dict['energy'],values_dict['duration'],values_dict['num_of_rules']]).T
    energy_df.columns = ['energy','duration','num_of_rules']
    energy_df = energy_df.reset_index()
    return energy_df

# %%
#load json file
with open(f'{expirment_dir}/test/reward_values_dict.json') as f:
    model_values = json.load(f)
model_values.keys()

with open(f'{expirment_dir}/test_passive_agent/reward_values_dict.json') as f:
    test_passive_agent = json.load(f)
test_passive_agent.keys()

with open(f'{expirment_dir}/test_random_agent/reward_values_dict.json') as f:
    test_random_agent = json.load(f)
test_random_agent.keys()
# Out:
# dict_keys(['energy', 'alerts', 'distributions', 'fraction', 'duration', 'num_of_rules'])

# %%
energy_df_model = dict_to_df(model_values)
energy_df_passive_agent = dict_to_df(test_passive_agent)
energy_df_random_agent= dict_to_df(test_random_agent)

# merge the two dataframes into one dataframe with one column for the energy and one column for the method
energy_df_model['method'] = 'DRL'
energy_df_passive_agent['method'] = 'test_passive_agent'
energy_df_random_agent['method'] = 'test_random_agent'
energy_df = pd.concat([energy_df_model, energy_df_passive_agent, energy_df_random_agent]).reset_index()#.drop(energy_df[energy_df['episode']==0].index)
energy_df.rename(columns={'level_0': 'episode'}, inplace=True)

# %%
# max_actions_value = 20000
# baseline_dfs_list = []
# action_values = [0, max_actions_value, max_actions_value//2]
# for search_window in [5, 15, 30, 60]:
#         for max_actions_value in [0,1000, 20000, 50000, 200000]:#, 100000, 200000]:
#             i = f"{search_window}_{max_actions_value}"
#             with open(f'{expirment_dir}/test_baseline_{i}/reward_values_dict.json') as f:
#                 baseline_values = json.load(f)
#             energy_df_baseline = dict_to_df(baseline_values)
#             energy_df_baseline['method'] = f'baseline_{i}'
#             baseline_dfs_list.append(energy_df_baseline)
# energy_df = pd.concat(baseline_dfs_list).reset_index()
# energy_df.rename(columns={'level_0': 'episode'}, inplace=True)

# %%
# energy_df = energy_df[energy_df['method'] == 'baseline02'].reset_index()
# for i in range(18):
#     if i < 6:
#         j = 0
#     elif i < 12:
#         j = 1
#     else:
#         j = 2
#     energy_df.loc[i, 'method'] = f'baseline0{j}'
# energy_df

# %%
num_of_rules = 6

# %%
energy_df[energy_df['num_of_rules']!=num_of_rules]['episode'].unique()
# Out:
# array([0])

# %%
energy_df.drop(energy_df[energy_df['episode'].isin(energy_df[energy_df['num_of_rules']!=num_of_rules]['episode'].unique())].index, inplace=True)
energy_df
# Out:
#     episode  index      energy  duration  num_of_rules              method
# 1         1      1  659.801858    13.517           6.0                 DRL
# 2         2      2  581.783805    11.185           6.0                 DRL
# 3         3      3  679.532415    15.408           6.0                 DRL
# 4         4      4  624.595724    12.399           6.0                 DRL
# 5         5      5  789.573868    17.204           6.0                 DRL
# 6         6      6  634.400731    13.518           6.0                 DRL
# 7         7      7  584.721312    11.601           6.0                 DRL
# 8         8      8  562.430842    12.759           6.0                 DRL
# 9         9      9  563.358778    12.046           6.0                 DRL
# 10       10     10  594.127337    13.863           6.0                 DRL
# 11       11     11  614.604393    12.613           6.0                 DRL
# 12       12     12  612.133269    12.968           6.0                 DRL
# 13       13     13  552.988751    12.778           6.0                 DRL
# 14       14     14  764.948372    15.500           6.0                 DRL
# 16        1      1  396.638301     9.463           6.0  test_passive_agent
# 17        2      2  414.178764     8.786           6.0  test_passive_agent
# 18        3      3  408.059606     8.716           6.0  test_passive_agent
# 19        4      4  384.665204     8.077           6.0  test_passive_agent
# 20        5      5  376.768039     9.382           6.0  test_passive_agent
# 21        6      6  397.286790     8.218           6.0  test_passive_agent
# 22        7      7  382.921736     7.699           6.0  test_passive_agent
# 23        8      8  448.241666     9.216           6.0  test_passive_agent
# 24        9      9  378.414403     7.816           6.0  test_passive_agent
# 25       10     10  375.625312     6.884           6.0  test_passive_agent
# 26       11     11  424.422549     9.970           6.0  test_passive_agent
# 27       12     12  389.789554     8.064           6.0  test_passive_agent
# 28       13     13  378.118925     7.966           6.0  test_passive_agent
# 29       14     14  373.819151     8.336           6.0  test_passive_agent
# 31        1      1  456.726280    10.840           6.0   test_random_agent
# 32        2      2  361.951103     8.402           6.0   test_random_agent
# 33        3      3  579.110217    13.227           6.0   test_random_agent
# 34        4      4  465.390501     9.976           6.0   test_random_agent
# 35        5      5  324.157485    19.479           6.0   test_random_agent
# 36        6      6  412.489508    10.264           6.0   test_random_agent
# 37        7      7  440.868715     9.558           6.0   test_random_agent
# 38        8      8  422.194009     9.332           6.0   test_random_agent
# 39        9      9  381.260083     8.094           6.0   test_random_agent
# 40       10     10  408.342423     8.521           6.0   test_random_agent
# 41       11     11  363.558432    10.509           6.0   test_random_agent
# 42       12     12  412.138010     8.338           6.0   test_random_agent
# 43       13     13  386.455111     9.325           6.0   test_random_agent
# 44       14     14  410.583839     8.215           6.0   test_random_agent

# %%
len(energy_df)
# Out:
# 42

# %%
# make a bar chart of the mean duration with std
alt.Chart(energy_df.groupby('method').describe()['duration'].reset_index()).mark_bar().encode(
    x=alt.X('method', sort='-y'),
    y=alt.Y('mean', sort='-x'),
    color=alt.Color('method', scale=alt.Scale(scheme='category20'), sort='-y'),
    tooltip=['method', 'mean', 'std'],
    text=alt.Text('mean', format='.2f')
).properties(
    title='Duration per method',

)
# Out:
# alt.Chart(...)

# %%
# make a bar chart of the mean duration with std
alt.Chart(energy_df.groupby('method').describe()['energy'].reset_index()).mark_bar().encode(
    x=alt.X('method', sort='-y'),
    y=alt.Y('mean', sort='-x'),
    color='method',
    tooltip=['method', 'mean', 'std'],
    text=alt.Text('mean', format='.2f')
).properties(
    title='Energy per method',

)
# Out:
# alt.Chart(...)

# %%
alt.Chart(energy_df).mark_line(point=True).encode(
    x='episode',
    y='duration',
    color='method'
    
).properties(
    title='Duration consumption of the DRL method vs the baseline methods',
    width=800,
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(energy_df).mark_line(point=True).encode(
    x='episode',
    y='energy',
    color='method'
    
).properties(
    title='Energy consumption of the DRL method vs the baseline methods',
    width=800,
)
# Out:
# alt.Chart(...)

# %%
# sum each 28 rewards to get the total reward per episode
rewards_df = pd.DataFrame(data['total'], columns=['rewards'])
rewards_df = rewards_df.reset_index()
rewards_df.rename(columns={'index': 'step'}, inplace=True)
rewards_df['episode'] = rewards_df['step'] // 28
rewards_df = rewards_df.groupby('episode').sum().reset_index()
rewards_df['episode'] = rewards_df['episode'] + 1

rewards_df
# rewards_total_df = rewards_total_df[rewards_total_df['total_reward'] < 100]
alt.Chart(rewards_df).mark_line().encode(
    x='episode',
    y='rewards',
    
).properties(
    title=' Total Reward',
    width=800,
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 2
#       1 # sum each 28 rewards to get the total reward per episode
# ----> 2 rewards_df = pd.DataFrame(data['total'], columns=['rewards'])
#       3 rewards_df = rewards_df.reset_index()
#       4 rewards_df.rename(columns={'index': 'step'}, inplace=True)
#
# NameError: name 'data' is not defined

# %%
def get_time_rule_energy_df(mode, file_name):
    with open(f'{expirment_dir}/{mode}/{file_name}.json') as f:
        time_rules_energy_dict_test = json.load(f)
    time_rules_energy_dict_test_data = []
    rules_names = []
    
    for e in time_rules_energy_dict_test:
        # if len(v) == 0:
        #     for n in rules_names:
        #         time_rules_energy_dict_test_data.append({'time': e['time_range'], 'rule_name': n, 'energy': 0})
        # rules_names = []
        
        for r in e['rules']:
            rules_names.append(r['name'])
            time_rules_energy_dict_test_data.append({'time': e['time_range'], 'rule_name': r['name'], 'energy': r['CPU(J)'], 'duration': r['run_duration'], 'num_of_rules': len(e['rules']), 'method': mode})
    return pd.DataFrame(time_rules_energy_dict_test_data)
test_time_rules_energy_df = get_time_rule_energy_df("test", 'time_rules_energy')
random_baseline_time_rules_energy_df = get_time_rule_energy_df("test_random_agent", 'time_rules_energy')
passive_baseline_time_rules_energy_df = get_time_rule_energy_df("test_passive_agent", 'time_rules_energy')
time_rules_energy_df = pd.concat([test_time_rules_energy_df, random_baseline_time_rules_energy_df, passive_baseline_time_rules_energy_df]).reset_index()
time_rules_energy_df
# Out:
#      index                                            time  \
# 0        0  ('06/22/2023:08:30:00', '06/22/2023:09:00:00')
# 1        1  ('06/22/2023:08:30:00', '06/22/2023:09:00:00')
# 2        2  ('06/22/2023:08:30:00', '06/22/2023:09:00:00')
# 3        3  ('06/22/2023:09:00:00', '06/22/2023:09:30:00')
# 4        4  ('06/22/2023:09:00:00', '06/22/2023:09:30:00')
# ..     ...                                             ...
# 262     85  ('06/22/2023:15:30:00', '06/22/2023:16:00:00')
# 263     86  ('06/22/2023:15:30:00', '06/22/2023:16:00:00')
# 264     87  ('06/22/2023:15:30:00', '06/22/2023:16:00:00')
# 265     88  ('06/22/2023:15:30:00', '06/22/2023:16:00:00')
# 266     89  ('06/22/2023:15:30:00', '06/22/2023:16:00:00')
#
#                                              rule_name      energy  duration  \
# 0              Monitor for Additions to Firewall Rules  172.850248     3.026
# 1          Multiple Failed Logins from the Same Source   66.643529     0.960
# 2    Multiple Network Connections to Same Port on E...   82.272691     1.365
# 3              Monitor for Additions to Firewall Rules  173.083026     3.237
# 4                Monitor for Changes to Firewall Rules   54.423788     1.247
# ..                                                 ...         ...       ...
# 262              Monitor for Changes to Firewall Rules   54.377275     1.414
# 263    Monitor for Suspicious_Administrative Processes   71.642878     1.155
# 264        Multiple Failed Logins from the Same Source   61.588690     1.440
# 265  Multiple Network Connections to Same Port on E...   67.826691     1.133
# 266                  Suspicious Remote Thread Creation   58.667743     1.585
#
#      num_of_rules              method
# 0               3                test
# 1               3                test
# 2               3                test
# 3               6                test
# 4               6                test
# ..            ...                 ...
# 262             6  test_passive_agent
# 263             6  test_passive_agent
# 264             6  test_passive_agent
# 265             6  test_passive_agent
# 266             6  test_passive_agent
#
# [267 rows x 7 columns]

# %%
relevant_logtypes = set()
for rule in time_rules_energy_df.groupby(['rule_name']).describe()['energy']['mean'].where(lambda x: x > 60).dropna().sort_values(ascending=False).index.tolist():
    print(rule)
    for logtype in logtypes_by_rule_dict[rule.lower()]:
        relevant_logtypes.add(logtype)
# Out:
# Monitor for Additions to Firewall Rules
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 4
#       2 for rule in time_rules_energy_df.groupby(['rule_name']).describe()['energy']['mean'].where(lambda x: x > 60).dropna().sort_values(ascending=False).index.tolist():
#       3     print(rule)
# ----> 4     for logtype in logtypes_by_rule_dict[rule.lower()]:
#       5         relevant_logtypes.add(logtype)
#
# NameError: name 'logtypes_by_rule_dict' is not defined

# %%
relevant_logtypes
# Out:
# set()

# %%
alt.Chart(time_rules_energy_df.reset_index()).mark_line().encode(
    x='method',
    y='energy',
    color='rule_name',
    
).properties(
    title='Energy consumption of the DRL method vs the baseline methods',
    width=800,
)
# Out:
# alt.Chart(...)

# %%
# concat the dataframes into one dataframe with one column for the energy and one column for the method
# test['method'] = 'DRL'
# baseline1['method'] = 'baseline'
# baseline2['method'] = 'baseline2'
# time_rules_energy_df = pd.concat([test,baseline1, baseline2])
time_to_index = {time:i for (i, time) in enumerate(time_rules_energy_df['time'].unique())}
time_rules_energy_df['index'] = time_rules_energy_df['time'].apply(lambda x: time_to_index[x])

# %%
def get_time_action_df(mode, file_name):
    with open(f'{expirment_dir}/{mode}/{file_name}_{mode}.json') as f:
        time_rules_energy_dict_test = json.load(f)
    time_rules_energy_dict_test_data = []
    for e in time_rules_energy_dict_test:
        for log_type in e:
            time_rules_energy_dict_test_data.append({'time': log_type[0], 'logtype':log_type[2], 'amount': log_type[3], 'method': mode})
    return pd.DataFrame(time_rules_energy_dict_test_data)
# test_action = get_time_action_df("test", 'action_dict_test')
test_action = get_time_action_df("test", 'action_dict')
random_baseline_action = get_time_action_df("test_random_agent", 'action_dict')
passive_baseline_action = get_time_action_df("test_passive_agent", 'action_dict')
time_action_df = pd.concat([test_action, random_baseline_action, passive_baseline_action]).reset_index()

# %%
time_action_df
# Out:
#      index                                            time  \
# 0        0  ('06/22/2023:08:30:00', '06/22/2023:09:00:00')
# 1        1  ('06/22/2023:08:30:00', '06/22/2023:09:00:00')
# 2        2  ('06/22/2023:08:30:00', '06/22/2023:09:00:00')
# 3        3  ('06/22/2023:08:30:00', '06/22/2023:09:00:00')
# 4        4  ('06/22/2023:08:30:00', '06/22/2023:09:00:00')
# ..     ...                                             ...
# 265     85  ('06/22/2023:15:30:00', '06/22/2023:16:00:00')
# 266     86  ('06/22/2023:15:30:00', '06/22/2023:16:00:00')
# 267     87  ('06/22/2023:15:30:00', '06/22/2023:16:00:00')
# 268     88  ('06/22/2023:15:30:00', '06/22/2023:16:00:00')
# 269     89  ('06/22/2023:15:30:00', '06/22/2023:16:00:00')
#
#                                                logtype  amount  \
# 0                     ('wineventlog:security', '2004')    6546
# 1                     ('wineventlog:security', '2005')       1
# 2                     ('wineventlog:security', '4625')       1
# 3                     ('wineventlog:security', '4688')       1
# 4    ('xmlwineventlog:microsoft-windows-sysmon/oper...       1
# ..                                                 ...     ...
# 265                   ('wineventlog:security', '2005')       0
# 266                   ('wineventlog:security', '4625')       0
# 267                   ('wineventlog:security', '4688')       0
# 268  ('xmlwineventlog:microsoft-windows-sysmon/oper...       0
# 269  ('xmlwineventlog:microsoft-windows-sysmon/oper...       0
#
#                  method
# 0                  test
# 1                  test
# 2                  test
# 3                  test
# 4                  test
# ..                  ...
# 265  test_passive_agent
# 266  test_passive_agent
# 267  test_passive_agent
# 268  test_passive_agent
# 269  test_passive_agent
#
# [270 rows x 5 columns]

# %%
# concat the dataframes into one dataframe with one column for the energy and one column for the method
# test_action['method'] = 'DRL'
# baseline1_action['method'] = 'baseline'
# baseline2_action['method'] = 'baseline2'
# time_action_df = pd.concat([test_action,baseline1_action])
# time_action_df = pd.concat(baselines)

# time_action_df['time'] = time_action_df['time'].apply(lambda x: '_'.join(x))
time_to_index = {time:i for (i, time) in enumerate(time_action_df['time'].unique())}
time_action_df['index'] = time_action_df['time'].apply(lambda x: time_to_index[x])
# create a chart that shows the energy consumption of each rule for each method at each time
alt.Chart(time_action_df).mark_bar().encode(
    x=alt.X('logtype', axis=alt.Axis(labelLimit=1000)),
    y='amount',
    column="index",
    color='method'
).properties(
    title='Action of the DRL method vs the baseline methods',
    
    
)
# Out:
# alt.Chart(...)

# %%
logtypes_by_rule_dict = {'Detect Network Connections to Non-Standard Ports':["XmlWinEventLog:Microsoft-Windows-Sysmon/Operational_3"],
 'Disabled Security Tool': ["XmlWinEventLog:Microsoft-Windows-Sysmon/Operational_16"],
 'Monitor for Logon Failures': ["wineventlog:security_4625"],
 'Monitor for Whitelisting bypass attempts': ["wineventlog:security_4688"],
 'System or Application Error': ["wineventlog:system_1074","wineventlog:system_6008", "wineventlog:application_1000"],
 'Creation of a New Local User Account': ["wineventlog:security_4720"],
 'Monitor for Suspicious_Administrative Processes': ["wineventlog:security_4688"],
 'Monitor for Suspicious Network IP’s': ["wineventlog:security_4663"],
 'Monitor for Service State Changes': ["wineventlog:system_7040"],
 'Suspicious Remote Thread Creation': ["XmlWinEventLog:Microsoft-Windows-Sysmon/Operational_8"],
 'Monitor for Logon Success': ["wineventlog:security_4624"],
 'Monitor for File Shares': ["wineventlog:security_5140"],
 'Monitor for Changes to Firewall Rules': ["wineventlog:security_2005"],
 'User Added to Privileged Group': ["wineventlog:security_4728","wineventlog:security_4732","wineventlog:security_4756"],
 'Monitor for Additions to Firewall Rules': ["wineventlog:security_2004"],
 'Detected Registry Modification': ["XmlWinEventLog:Microsoft-Windows-Sysmon/Operational_12","XmlWinEventLog:Microsoft-Windows-Sysmon/Operational_13","XmlWinEventLog:Microsoft-Windows-Sysmon/Operational_14"],
 'An Account Was Logged off': ["wineventlog:security_4634"] ,
 'Detect Network Connections from Non-Browser or Non-Email Client': ["XmlWinEventLog:Microsoft-Windows-Sysmon/Operational_3"],
 'Modification of Executable File': ["XmlWinEventLog:Microsoft-Windows-Sysmon/Operational_11"],
 'Monitor for Administrative and Guest Logon Failures': ["wineventlog:security_4625"],
 'Monitor for New Service Installs': ["wineventlog:security_7045"],
 'Monitor for Registry Changes': ["wineventlog:security_4657"],
 'Multiple Failed Logins from the Same Source': ["wineventlog:security_4625"],
 'Multiple Network Connections to Same Port on External Hosts': ["XmlWinEventLog:Microsoft-Windows-Sysmon/Operational_3"],
 'New Local Admin Account': ["wineventlog:security_4720", "wineventlog:security_4732"],
 'Process Opened a Network Connection': ["XmlWinEventLog:Microsoft-Windows-Sysmon/Operational_3"],
 'User Login with Local Credentials': ["wineventlog:security_4624"],
 'Windows Event Log Clearing Events': ["wineventlog:security_1102", "wineventlog:system_104", "wineventlog:security_1100"],
 }
logtypes_by_rule_dict = {rule.lower(): [logtype.lower() for logtype in logtypes] for rule, logtypes in logtypes_by_rule_dict.items()}
# logtypes_by_rule_dict

# %%
time_rules_energy_df['action_amount'] = 0
time_action_df['logtype'] = time_action_df['logtype'].apply(lambda x: x.strip('[').strip(']').strip('(').strip(')').split(',')).apply(lambda x: '_'.join(x).replace("\'", '').replace(" ", ''))
for method in time_rules_energy_df['method'].unique():
    for time in time_rules_energy_df['time'].unique():
        for rule in time_rules_energy_df['rule_name'].unique():
            relevant_log_types = logtypes_by_rule_dict[rule.lower()]
            # relevant_log_types = [str(logtype.split('_')) for logtype in relevant_log_types]
            print(relevant_log_types)
            print(time, method, rule)
            amount = time_action_df[(time_action_df['time'] == f"{time}") & (time_action_df['method'] == method) & (time_action_df['logtype'].isin(relevant_log_types)) ]['amount'].sum()
            print('amount', amount)
            # print( time_rules_energy_df[(time_rules_energy_df['time'] == time) & (time_rules_energy_df['method'] == method) & (time_rules_energy_df['rule_name'] == rule)])
            time_rules_energy_df.loc[(time_rules_energy_df['time'] == f"{time}") & (time_rules_energy_df['method'] == method) & (time_rules_energy_df['rule_name'] == rule), 'action_amount'] = amount
# Out:
# ['wineventlog:security_2004']
# ('06/22/2023:08:30:00', '06/22/2023:09:00:00') test Monitor for Additions to Firewall Rules
# amount 6546
# ['wineventlog:security_4625']
# ('06/22/2023:08:30:00', '06/22/2023:09:00:00') test Multiple Failed Logins from the Same Source
# amount 1
# ['xmlwineventlog:microsoft-windows-sysmon/operational_3']
# ('06/22/2023:08:30:00', '06/22/2023:09:00:00') test Multiple Network Connections to Same Port on External Hosts
# amount 1
# ['wineventlog:security_2005']
# ('06/22/2023:08:30:00', '06/22/2023:09:00:00') test Monitor for Changes to Firewall Rules
# amount 1
# ['wineventlog:security_4688']
# ('06/22/2023:08:30:00', '06/22/2023:09:00:00') test Monitor for Suspicious_Administrative Processes
# amount 1
# ['xmlwineventlog:microsoft-windows-sysmon/operational_8']
# ('06/22/2023:08:30:00', '06/22/2023:09:00:00') test Suspicious Remote Thread Creation
# amount 13449
# ['wineventlog:security_2004']
# ('06/22/2023:09:00:00', '06/22/2023:09:30:00') test Monitor for Additions to Firewall Rules
# amount 6546
# ['wineventlog:security_4625']
# ('06/22/2023:09:00:00', '06/22/2023:09:30:00') test Multiple Failed Logins from the Same Source
# amount 1
# ['xmlwineventlog:microsoft-windows-sysmon/operational_3']
# ('06/22/2023:09:00:00', '06/22/2023:09:30:00') test Multiple Network Connections to Same Port on External Hosts
# amount 1
# ['wineventlog:security_2005']
# ('06/22/2023:09:00:00', '06/22/2023:09:30:00') test Monitor for Changes to Firewall Rules
# amount 1
# ['wineventlog:security_4688']
# ('06/22/2023:09:00:00', '06/22/2023:09:30:00') test Monitor for Suspicious_Administrative Processes
# amount 1
# ['xmlwineventlog:microsoft-windows-sysmon/operational_8']
# ('06/22/2023:09:00:00', '06/22/2023:09:30:00') test Suspicious Remote Thread Creation
# amount 13449
# ['wineventlog:security_2004']
# ('06/22/2023:09:30:00', '06/22/2023:10:00:00') test Monitor for Additions to Firewall Rules
# amount 6546
# ['wineventlog:security_4625']
# ('06/22/2023:09:30:00', '06/22/2023:10:00:00') test Multiple Failed Logins from the Same Source
# amount 1
# ['xmlwineventlog:microsoft-windows-sysmon/operational_3']
# ('06/22/2023:09:30:00', '06/22/2023:10:00:00') test Multiple Network Connections to Same Port on External Hosts
# amount 1
# ['wineventlog:security_2005']
# ('06/22/2023:09:30:00', '06/22/2023:10:00:00') test Monitor for Changes to Firewall Rules
# amount 1
# ['wineventlog:security_4688']
# ('06/22/2023:09:30:00', '06/22/2023:10:00:00') test Monitor for Suspicious_Administrative Processes
# amount 1
# ['xmlwineventlog:microsoft-windows-sysmon/operational_8']
# ('06/22/2023:09:30:00', '06/22/2023:10:00:00') test Suspicious Remote Thread Creation
# amount 13449
# ['wineventlog:security_2004']
# ('06/22/2023:10:00:00', '06/22/2023:10:30:00') test Monitor for Additions to Firewall Rules
# amount 6546
# ['wineventlog:security_4625']
# ('06/22/2023:10:00:00', '06/22/2023:10:30:00') test Multiple Failed Logins from the Same Source
# amount 1
# ['xmlwineventlog:microsoft-windows-sysmon/operational_3']
# ('06/22/2023:10:00:00', '06/22/2023:10:30:00') test Multiple Network Connections to Same Port on External Hosts
# amount 1
# ['wineventlog:security_2005']
# ('06/22/2023:10:00:00', '06/22/2023:10:30:00') test Monitor for Changes to Firewall Rules
# amount 1
# ['wineventlog:security_4688']
# ('06/22/2023:10:00:00', '06/22/2023:10:30:00') test Monitor for Suspicious_Administrative Processes
# amount 1
# ['xmlwineventlog:microsoft-windows-sysmon/operational_8']
# ('06/22/2023:10:00:00', '06/22/2023:10:30:00') test Suspicious Remote Thread Creation
# amount 13449
# ['wineventlog:security_2004']
# ('06/22/2023:10:30:00', '06/22/2023:11:00:00') test Monitor for Additions to Firewall Rules
# amount 6546
# ['wineventlog:security_4625']
# ('06/22/2023:10:30:00', '06/22/2023:11:00:00') test Multiple Failed Logins from the Same Source
# amount 1
# ['xmlwineventlog:microsoft-windows-sysmon/operational_3']
# ('06/22/2023:10:30:00', '06/22/2023:11:00:00') test Multiple Network Connections to Same Port on External Hosts
# amount 1
# ['wineventlog:security_2005']
# ('06/22/2023:10:30:00', '06/22/2023:11:00:00') test Monitor for Changes to Firewall Rules
# amount 1
# ['wineventlog:security_4688']
# ('06/22/2023:10:30:00', '06/22/2023:11:00:00') test Monitor for Suspicious_Administrative Processes
# amount 1
# ['xmlwineventlog:microsoft-windows-sysmon/operational_8']
# ('06/22/2023:10:30:00', '06/22/2023:11:00:00') test Suspicious Remote Thread Creation
# amount 13449
# ['wineventlog:security_2004']
# ('06/22/2023:11:00:00', '06/22/2023:11:30:00') test Monitor for Additions to Firewall Rules
# amount 6546
# ['wineventlog:security_4625']
# ('06/22/2023:11:00:00', '06/22/2023:11:30:00') test Multiple Failed Logins from the Same Source
# amount 1
# ['xmlwineventlog:microsoft-windows-sysmon/operational_3']
# ('06/22/2023:11:00:00', '06/22/2023:11:30:00') test Multiple Network Connections to Same Port on External Hosts
# amount 1
# ['wineventlog:security_2005']
# ('06/22/2023:11:00:00', '06/22/2023:11:30:00') test Monitor for Changes to Firewall Rules
# amount 1
# ['wineventlog:security_4688']
# ('06/22/2023:11:00:00', '06/22/2023:11:30:00') test Monitor for Suspicious_Administrative Processes
# amount 1
# ['xmlwineventlog:microsoft-windows-sysmon/operational_8']
# ('06/22/2023:11:00:00', '06/22/2023:11:30:00') test Suspicious Remote Thread Creation
# amount 13449
# ['wineventlog:security_2004']
# ('06/22/2023:11:30:00', '06/22/2023:12:00:00') test Monitor for Additions to Firewall Rules
# amount 6546
# ['wineventlog:security_4625']
# ('06/22/2023:11:30:00', '06/22/2023:12:00:00') test Multiple Failed Logins from the Same Source
# amount 1
# ['xmlwineventlog:microsoft-windows-sysmon/operational_3']
# ('06/22/2023:11:30:00', '06/22/2023:12:00:00') test Multiple Network Connections to Same Port on External Hosts
# amount 1
# ['wineventlog:security_2005']
# ('06/22/2023:11:30:00', '06/22/2023:12:00:00') test Monitor for Changes to Firewall Rules
# amount 1
# ['wineventlog:security_4688']
# ('06/22/2023:11:30:00', '06/22/2023:12:00:00') test Monitor for Suspicious_Administrative Processes
# amount 1
# ['xmlwineventlog:microsoft-windows-sysmon/operational_8']
# ('06/22/2023:11:30:00', '06/22/2023:12:00:00') test Suspicious Remote Thread Creation
# amount 13449
# ['wineventlog:security_2004']
# ('06/22/2023:12:00:00', '06/22/2023:12:30:00') test Monitor for Additions to Firewall Rules
# amount 6546
# ['wineventlog:security_4625']
# ('06/22/2023:12:00:00', '06/22/2023:12:30:00') test Multiple Failed Logins from the Same Source
# amount 1
# ['xmlwineventlog:microsoft-windows-sysmon/operational_3']
# ('06/22/2023:12:00:00', '06/22/2023:12:30:00') test Multiple Network Connections to Same Port on External Hosts
# amount 1
# ['wineventlog:security_2005']
# ('06/22/2023:12:00:00', '06/22/2023:12:30:00') test Monitor for Changes to Firewall Rules
# amount 1
# ['wineventlog:security_4688']
# ('06/22/2023:12:00:00', '06/22/2023:12:30:00') test Monitor for Suspicious_Administrative Processes
# amount 1
# ['xmlwineventlog:microsoft-windows-sysmon/operational_8']
# ('06/22/2023:12:00:00', '06/22/2023:12:30:00') test Suspicious Remote Thread Creation
# amount 13449
# ['wineventlog:security_2004']
# ('06/22/2023:12:30:00', '06/22/2023:13:00:00') test Monitor for Additions to Firewall Rules
# amount 6546
# ['wineventlog:security_4625']
# ('06/22/2023:12:30:00', '06/22/2023:13:00:00') test Multiple Failed Logins from the Same Source
# amount 1
# ['xmlwineventlog:microsoft-windows-sysmon/operational_3']
# ('06/22/2023:12:30:00', '06/22/2023:13:00:00') test Multiple Network Connections to Same Port on External Hosts
# amount 1
# ['wineventlog:security_2005']
# ('06/22/2023:12:30:00', '06/22/2023:13:00:00') test Monitor for Changes to Firewall Rules
# amount 1
# ['wineventlog:security_4688']
# ('06/22/2023:12:30:00', '06/22/2023:13:00:00') test Monitor for Suspicious_Administrative Processes
# amount 1
# ['xmlwineventlog:microsoft-windows-sysmon/operational_8']
# ('06/22/2023:12:30:00', '06/22/2023:13:00:00') test Suspicious Remote Thread Creation
# amount 13449
# ['wineventlog:security_2004']
# ('06/22/2023:13:00:00', '06/22/2023:13:30:00') test Monitor for Additions to Firewall Rules
# amount 6546
# ['wineventlog:security_4625']
# ('06/22/2023:13:00:00', '06/22/2023:13:30:00') test Multiple Failed Logins from the Same Source
# amount 1
# ['xmlwineventlog:microsoft-windows-sysmon/operational_3']
# ('06/22/2023:13:00:00', '06/22/2023:13:30:00') test Multiple Network Connections to Same Port on External Hosts
# amount 1
# ['wineventlog:security_2005']
# ('06/22/2023:13:00:00', '06/22/2023:13:30:00') test Monitor for Changes to Firewall Rules
# amount 1
# ['wineventlog:security_4688']
# ('06/22/2023:13:00:00', '06/22/2023:13:30:00') test Monitor for Suspicious_Administrative Processes
# amount 1
# ['xmlwineventlog:microsoft-windows-sysmon/operational_8']
# ('06/22/2023:13:00:00', '06/22/2023:13:30:00') test Suspicious Remote Thread Creation
# amount 13449
# ['wineventlog:security_2004']
# ('06/22/2023:13:30:00', '06/22/2023:14:00:00') test Monitor for Additions to Firewall Rules
# amount 6546
# ['wineventlog:security_4625']
# ('06/22/2023:13:30:00', '06/22/2023:14:00:00') test Multiple Failed Logins from the Same Source
# amount 1
# ['xmlwineventlog:microsoft-windows-sysmon/operational_3']
# ('06/22/2023:13:30:00', '06/22/2023:14:00:00') test Multiple Network Connections to Same Port on External Hosts
# amount 1
# ['wineventlog:security_2005']
# ('06/22/2023:13:30:00', '06/22/2023:14:00:00') test Monitor for Changes to Firewall Rules
# amount 1
# ['wineventlog:security_4688']
# ('06/22/2023:13:30:00', '06/22/2023:14:00:00') test Monitor for Suspicious_Administrative Processes
# amount 1
# ['xmlwineventlog:microsoft-windows-sysmon/operational_8']
# ('06/22/2023:13:30:00', '06/22/2023:14:00:00') test Suspicious Remote Thread Creation
# amount 13449
# ['wineventlog:security_2004']
# ('06/22/2023:14:00:00', '06/22/2023:14:30:00') test Monitor for Additions to Firewall Rules
# amount 6546
# ['wineventlog:security_4625']
# ('06/22/2023:14:00:00', '06/22/2023:14:30:00') test Multiple Failed Logins from the Same Source
# amount 1
# ['xmlwineventlog:microsoft-windows-sysmon/operational_3']
# ('06/22/2023:14:00:00', '06/22/2023:14:30:00') test Multiple Network Connections to Same Port on External Hosts
# amount 1
# ['wineventlog:security_2005']
# ('06/22/2023:14:00:00', '06/22/2023:14:30:00') test Monitor for Changes to Firewall Rules
# amount 1
# ['wineventlog:security_4688']
# ('06/22/2023:14:00:00', '06/22/2023:14:30:00') test Monitor for Suspicious_Administrative Processes
# amount 1
# ['xmlwineventlog:microsoft-windows-sysmon/operational_8']
# ('06/22/2023:14:00:00', '06/22/2023:14:30:00') test Suspicious Remote Thread Creation
# amount 13449
# ['wineventlog:security_2004']
# ('06/22/2023:14:30:00', '06/22/2023:15:00:00') test Monitor for Additions to Firewall Rules
# amount 6546
# ['wineventlog:security_4625']
# ('06/22/2023:14:30:00', '06/22/2023:15:00:00') test Multiple Failed Logins from the Same Source
# amount 1
# ['xmlwineventlog:microsoft-windows-sysmon/operational_3']
# ('06/22/2023:14:30:00', '06/22/2023:15:00:00') test Multiple Network Connections to Same Port on External Hosts
# amount 1
# ['wineventlog:security_2005']
# ('06/22/2023:14:30:00', '06/22/2023:15:00:00') test Monitor for Changes to Firewall Rules
# amount 1
# ['wineventlog:security_4688']
# ('06/22/2023:14:30:00', '06/22/2023:15:00:00') test Monitor for Suspicious_Administrative Processes
# amount 1
# ['xmlwineventlog:microsoft-windows-sysmon/operational_8']
# ('06/22/2023:14:30:00', '06/22/2023:15:00:00') test Suspicious Remote Thread Creation
# amount 13449
# ['wineventlog:security_2004']
# ('06/22/2023:15:00:00', '06/22/2023:15:30:00') test Monitor for Additions to Firewall Rules
# amount 6546
# ['wineventlog:security_4625']
# ('06/22/2023:15:00:00', '06/22/2023:15:30:00') test Multiple Failed Logins from the Same Source
# amount 1
# ['xmlwineventlog:microsoft-windows-sysmon/operational_3']
# ('06/22/2023:15:00:00', '06/22/2023:15:30:00') test Multiple Network Connections to Same Port on External Hosts
# amount 1
# ['wineventlog:security_2005']
# ('06/22/2023:15:00:00', '06/22/2023:15:30:00') test Monitor for Changes to Firewall Rules
# amount 1
# ['wineventlog:security_4688']
# ('06/22/2023:15:00:00', '06/22/2023:15:30:00') test Monitor for Suspicious_Administrative Processes
# amount 1
# ['xmlwineventlog:microsoft-windows-sysmon/operational_8']
# ('06/22/2023:15:00:00', '06/22/2023:15:30:00') test Suspicious Remote Thread Creation
# amount 13449
# ['wineventlog:security_2004']
# ('06/22/2023:15:30:00', '06/22/2023:16:00:00') test Monitor for Additions to Firewall Rules
# amount 6546
# ['wineventlog:security_4625']
# ('06/22/2023:15:30:00', '06/22/2023:16:00:00') test Multiple Failed Logins from the Same Source
# amount 1
# ['xmlwineventlog:microsoft-windows-sysmon/operational_3']
# ('06/22/2023:15:30:00', '06/22/2023:16:00:00') test Multiple Network Connections to Same Port on External Hosts
# amount 1
# ['wineventlog:security_2005']
# ('06/22/2023:15:30:00', '06/22/2023:16:00:00') test Monitor for Changes to Firewall Rules
# amount 1
# ['wineventlog:security_4688']
# ('06/22/2023:15:30:00', '06/22/2023:16:00:00') test Monitor for Suspicious_Administrative Processes
# amount 1
# ['xmlwineventlog:microsoft-windows-sysmon/operational_8']
# ('06/22/2023:15:30:00', '06/22/2023:16:00:00') test Suspicious Remote Thread Creation
# amount 13449
# ['wineventlog:security_2004']
# ('06/22/2023:08:30:00', '06/22/2023:09:00:00') test_random_agent Monitor for Additions to Firewall Rules
# amount 14129
# ['wineventlog:security_4625']
# ('06/22/2023:08:30:00', '06/22/2023:09:00:00') test_random_agent Multiple Failed Logins from the Same Source
# amount 943
# ['xmlwineventlog:microsoft-windows-sysmon/operational_3']
# ('06/22/2023:08:30:00', '06/22/2023:09:00:00') test_random_agent Multiple Network Connections to Same Port on External Hosts
# amount 0
# ['wineventlog:security_2005']
# ('06/22/2023:08:30:00', '06/22/2023:09:00:00') test_random_agent Monitor for Changes to Firewall Rules
# amount 4820
# ['wineventlog:security_4688']
# ('06/22/2023:08:30:00', '06/22/2023:09:00:00') test_random_agent Monitor for Suspicious_Administrative Processes
# amount 106
# ['xmlwineventlog:microsoft-windows-sysmon/operational_8']
# ('06/22/2023:08:30:00', '06/22/2023:09:00:00') test_random_agent Suspicious Remote Thread Creation
# amount 0
# ['wineventlog:security_2004']
# ('06/22/2023:09:00:00', '06/22/2023:09:30:00') test_random_agent Monitor for Additions to Firewall Rules
# amount 17070
# ['wineventlog:security_4625']
# ('06/22/2023:09:00:00', '06/22/2023:09:30:00') test_random_agent Multiple Failed Logins from the Same Source
# amount 470
# ['xmlwineventlog:microsoft-windows-sysmon/operational_3']
# ('06/22/2023:09:00:00', '06/22/2023:09:30:00') test_random_agent Multiple Network Connections to Same Port on External Hosts
# amount 252
# ['wineventlog:security_2005']
# ('06/22/2023:09:00:00', '06/22/2023:09:30:00') test_random_agent Monitor for Changes to Firewall Rules
# amount 1169
# ['wineventlog:security_4688']
# ('06/22/2023:09:00:00', '06/22/2023:09:30:00') test_random_agent Monitor for Suspicious_Administrative Processes
# amount 127
# ['xmlwineventlog:microsoft-windows-sysmon/operational_8']
# ('06/22/2023:09:00:00', '06/22/2023:09:30:00') test_random_agent Suspicious Remote Thread Creation
# amount 909
# ['wineventlog:security_2004']
# ('06/22/2023:09:30:00', '06/22/2023:10:00:00') test_random_agent Monitor for Additions to Firewall Rules
# amount 7993
# ['wineventlog:security_4625']
# ('06/22/2023:09:30:00', '06/22/2023:10:00:00') test_random_agent Multiple Failed Logins from the Same Source
# amount 4214
# ['xmlwineventlog:microsoft-windows-sysmon/operational_3']
# ('06/22/2023:09:30:00', '06/22/2023:10:00:00') test_random_agent Multiple Network Connections to Same Port on External Hosts
# amount 186
# ['wineventlog:security_2005']
# ('06/22/2023:09:30:00', '06/22/2023:10:00:00') test_random_agent Monitor for Changes to Firewall Rules
# amount 3349
# ['wineventlog:security_4688']
# ('06/22/2023:09:30:00', '06/22/2023:10:00:00') test_random_agent Monitor for Suspicious_Administrative Processes
# amount 4106
# ['xmlwineventlog:microsoft-windows-sysmon/operational_8']
# ('06/22/2023:09:30:00', '06/22/2023:10:00:00') test_random_agent Suspicious Remote Thread Creation
# amount 148
# ['wineventlog:security_2004']
# ('06/22/2023:10:00:00', '06/22/2023:10:30:00') test_random_agent Monitor for Additions to Firewall Rules
# amount 2464
# ['wineventlog:security_4625']
# ('06/22/2023:10:00:00', '06/22/2023:10:30:00') test_random_agent Multiple Failed Logins from the Same Source
# amount 552
# ['xmlwineventlog:microsoft-windows-sysmon/operational_3']
# ('06/22/2023:10:00:00', '06/22/2023:10:30:00') test_random_agent Multiple Network Connections to Same Port on External Hosts
# amount 2293
# ['wineventlog:security_2005']
# ('06/22/2023:10:00:00', '06/22/2023:10:30:00') test_random_agent Monitor for Changes to Firewall Rules
# amount 8332
# ['wineventlog:security_4688']
# ('06/22/2023:10:00:00', '06/22/2023:10:30:00') test_random_agent Monitor for Suspicious_Administrative Processes
# amount 4542
# ['xmlwineventlog:microsoft-windows-sysmon/operational_8']
# ('06/22/2023:10:00:00', '06/22/2023:10:30:00') test_random_agent Suspicious Remote Thread Creation
# amount 1814
# ['wineventlog:security_2004']
# ('06/22/2023:10:30:00', '06/22/2023:11:00:00') test_random_agent Monitor for Additions to Firewall Rules
# amount 4230
# ['wineventlog:security_4625']
# ('06/22/2023:10:30:00', '06/22/2023:11:00:00') test_random_agent Multiple Failed Logins from the Same Source
# amount 554
# ['xmlwineventlog:microsoft-windows-sysmon/operational_3']
# ('06/22/2023:10:30:00', '06/22/2023:11:00:00') test_random_agent Multiple Network Connections to Same Port on External Hosts
# amount 1741
# ['wineventlog:security_2005']
# ('06/22/2023:10:30:00', '06/22/2023:11:00:00') test_random_agent Monitor for Changes to Firewall Rules
# amount 3198
# ['wineventlog:security_4688']
# ('06/22/2023:10:30:00', '06/22/2023:11:00:00') test_random_agent Monitor for Suspicious_Administrative Processes
# amount 8764
# ['xmlwineventlog:microsoft-windows-sysmon/operational_8']
# ('06/22/2023:10:30:00', '06/22/2023:11:00:00') test_random_agent Suspicious Remote Thread Creation
# amount 1509
# ['wineventlog:security_2004']
# ('06/22/2023:11:00:00', '06/22/2023:11:30:00') test_random_agent Monitor for Additions to Firewall Rules
# amount 9068
# ['wineventlog:security_4625']
# ('06/22/2023:11:00:00', '06/22/2023:11:30:00') test_random_agent Multiple Failed Logins from the Same Source
# amount 2864
# ['xmlwineventlog:microsoft-windows-sysmon/operational_3']
# ('06/22/2023:11:00:00', '06/22/2023:11:30:00') test_random_agent Multiple Network Connections to Same Port on External Hosts
# amount 190
# ['wineventlog:security_2005']
# ('06/22/2023:11:00:00', '06/22/2023:11:30:00') test_random_agent Monitor for Changes to Firewall Rules
# amount 6232
# ['wineventlog:security_4688']
# ('06/22/2023:11:00:00', '06/22/2023:11:30:00') test_random_agent Monitor for Suspicious_Administrative Processes
# amount 650
# ['xmlwineventlog:microsoft-windows-sysmon/operational_8']
# ('06/22/2023:11:00:00', '06/22/2023:11:30:00') test_random_agent Suspicious Remote Thread Creation
# amount 993
# ['wineventlog:security_2004']
# ('06/22/2023:11:30:00', '06/22/2023:12:00:00') test_random_agent Monitor for Additions to Firewall Rules
# amount 10953
# ['wineventlog:security_4625']
# ('06/22/2023:11:30:00', '06/22/2023:12:00:00') test_random_agent Multiple Failed Logins from the Same Source
# amount 3943
# ['xmlwineventlog:microsoft-windows-sysmon/operational_3']
# ('06/22/2023:11:30:00', '06/22/2023:12:00:00') test_random_agent Multiple Network Connections to Same Port on External Hosts
# amount 524
# ['wineventlog:security_2005']
# ('06/22/2023:11:30:00', '06/22/2023:12:00:00') test_random_agent Monitor for Changes to Firewall Rules
# amount 32
# ['wineventlog:security_4688']
# ('06/22/2023:11:30:00', '06/22/2023:12:00:00') test_random_agent Monitor for Suspicious_Administrative Processes
# amount 3785
# ['xmlwineventlog:microsoft-windows-sysmon/operational_8']
# ('06/22/2023:11:30:00', '06/22/2023:12:00:00') test_random_agent Suspicious Remote Thread Creation
# amount 760
# ['wineventlog:security_2004']
# ('06/22/2023:12:00:00', '06/22/2023:12:30:00') test_random_agent Monitor for Additions to Firewall Rules
# amount 14277
# ['wineventlog:security_4625']
# ('06/22/2023:12:00:00', '06/22/2023:12:30:00') test_random_agent Multiple Failed Logins from the Same Source
# amount 777
# ['xmlwineventlog:microsoft-windows-sysmon/operational_3']
# ('06/22/2023:12:00:00', '06/22/2023:12:30:00') test_random_agent Multiple Network Connections to Same Port on External Hosts
# amount 729
# ['wineventlog:security_2005']
# ('06/22/2023:12:00:00', '06/22/2023:12:30:00') test_random_agent Monitor for Changes to Firewall Rules
# amount 3828
# ['wineventlog:security_4688']
# ('06/22/2023:12:00:00', '06/22/2023:12:30:00') test_random_agent Monitor for Suspicious_Administrative Processes
# amount 185
# ['xmlwineventlog:microsoft-windows-sysmon/operational_8']
# ('06/22/2023:12:00:00', '06/22/2023:12:30:00') test_random_agent Suspicious Remote Thread Creation
# amount 201
# ['wineventlog:security_2004']
# ('06/22/2023:12:30:00', '06/22/2023:13:00:00') test_random_agent Monitor for Additions to Firewall Rules
# amount 6404
# ['wineventlog:security_4625']
# ('06/22/2023:12:30:00', '06/22/2023:13:00:00') test_random_agent Multiple Failed Logins from the Same Source
# amount 3010
# ['xmlwineventlog:microsoft-windows-sysmon/operational_3']
# ('06/22/2023:12:30:00', '06/22/2023:13:00:00') test_random_agent Multiple Network Connections to Same Port on External Hosts
# amount 1755
# ['wineventlog:security_2005']
# ('06/22/2023:12:30:00', '06/22/2023:13:00:00') test_random_agent Monitor for Changes to Firewall Rules
# amount 4564
# ['wineventlog:security_4688']
# ('06/22/2023:12:30:00', '06/22/2023:13:00:00') test_random_agent Monitor for Suspicious_Administrative Processes
# amount 3555
# ['xmlwineventlog:microsoft-windows-sysmon/operational_8']
# ('06/22/2023:12:30:00', '06/22/2023:13:00:00') test_random_agent Suspicious Remote Thread Creation
# amount 710
# ['wineventlog:security_2004']
# ('06/22/2023:13:00:00', '06/22/2023:13:30:00') test_random_agent Monitor for Additions to Firewall Rules
# amount 3424
# ['wineventlog:security_4625']
# ('06/22/2023:13:00:00', '06/22/2023:13:30:00') test_random_agent Multiple Failed Logins from the Same Source
# amount 386
# ['xmlwineventlog:microsoft-windows-sysmon/operational_3']
# ('06/22/2023:13:00:00', '06/22/2023:13:30:00') test_random_agent Multiple Network Connections to Same Port on External Hosts
# amount 34
# ['wineventlog:security_2005']
# ('06/22/2023:13:00:00', '06/22/2023:13:30:00') test_random_agent Monitor for Changes to Firewall Rules
# amount 15922
# ['wineventlog:security_4688']
# ('06/22/2023:13:00:00', '06/22/2023:13:30:00') test_random_agent Monitor for Suspicious_Administrative Processes
# amount 178
# ['xmlwineventlog:microsoft-windows-sysmon/operational_8']
# ('06/22/2023:13:00:00', '06/22/2023:13:30:00') test_random_agent Suspicious Remote Thread Creation
# amount 53
# ['wineventlog:security_2004']
# ('06/22/2023:13:30:00', '06/22/2023:14:00:00') test_random_agent Monitor for Additions to Firewall Rules
# amount 9091
# ['wineventlog:security_4625']
# ('06/22/2023:13:30:00', '06/22/2023:14:00:00') test_random_agent Multiple Failed Logins from the Same Source
# amount 1751
# ['xmlwineventlog:microsoft-windows-sysmon/operational_3']
# ('06/22/2023:13:30:00', '06/22/2023:14:00:00') test_random_agent Multiple Network Connections to Same Port on External Hosts
# amount 1111
# ['wineventlog:security_2005']
# ('06/22/2023:13:30:00', '06/22/2023:14:00:00') test_random_agent Monitor for Changes to Firewall Rules
# amount 5459
# ['wineventlog:security_4688']
# ('06/22/2023:13:30:00', '06/22/2023:14:00:00') test_random_agent Monitor for Suspicious_Administrative Processes
# amount 1212
# ['xmlwineventlog:microsoft-windows-sysmon/operational_8']
# ('06/22/2023:13:30:00', '06/22/2023:14:00:00') test_random_agent Suspicious Remote Thread Creation
# amount 1372
# ['wineventlog:security_2004']
# ('06/22/2023:14:00:00', '06/22/2023:14:30:00') test_random_agent Monitor for Additions to Firewall Rules
# amount 12172
# ['wineventlog:security_4625']
# ('06/22/2023:14:00:00', '06/22/2023:14:30:00') test_random_agent Multiple Failed Logins from the Same Source
# amount 3092
# ['xmlwineventlog:microsoft-windows-sysmon/operational_3']
# ('06/22/2023:14:00:00', '06/22/2023:14:30:00') test_random_agent Multiple Network Connections to Same Port on External Hosts
# amount 333
# ['wineventlog:security_2005']
# ('06/22/2023:14:00:00', '06/22/2023:14:30:00') test_random_agent Monitor for Changes to Firewall Rules
# amount 2806
# ['wineventlog:security_4688']
# ('06/22/2023:14:00:00', '06/22/2023:14:30:00') test_random_agent Monitor for Suspicious_Administrative Processes
# amount 909
# ['xmlwineventlog:microsoft-windows-sysmon/operational_8']
# ('06/22/2023:14:00:00', '06/22/2023:14:30:00') test_random_agent Suspicious Remote Thread Creation
# amount 685
# ['wineventlog:security_2004']
# ('06/22/2023:14:30:00', '06/22/2023:15:00:00') test_random_agent Monitor for Additions to Firewall Rules
# amount 1224
# ['wineventlog:security_4625']
# ('06/22/2023:14:30:00', '06/22/2023:15:00:00') test_random_agent Multiple Failed Logins from the Same Source
# amount 2235
# ['xmlwineventlog:microsoft-windows-sysmon/operational_3']
# ('06/22/2023:14:30:00', '06/22/2023:15:00:00') test_random_agent Multiple Network Connections to Same Port on External Hosts
# amount 449
# ['wineventlog:security_2005']
# ('06/22/2023:14:30:00', '06/22/2023:15:00:00') test_random_agent Monitor for Changes to Firewall Rules
# amount 6767
# ['wineventlog:security_4688']
# ('06/22/2023:14:30:00', '06/22/2023:15:00:00') test_random_agent Monitor for Suspicious_Administrative Processes
# amount 8276
# ['xmlwineventlog:microsoft-windows-sysmon/operational_8']
# ('06/22/2023:14:30:00', '06/22/2023:15:00:00') test_random_agent Suspicious Remote Thread Creation
# amount 1046
# ['wineventlog:security_2004']
# ('06/22/2023:15:00:00', '06/22/2023:15:30:00') test_random_agent Monitor for Additions to Firewall Rules
# amount 1915
# ['wineventlog:security_4625']
# ('06/22/2023:15:00:00', '06/22/2023:15:30:00') test_random_agent Multiple Failed Logins from the Same Source
# amount 223
# ['xmlwineventlog:microsoft-windows-sysmon/operational_3']
# ('06/22/2023:15:00:00', '06/22/2023:15:30:00') test_random_agent Multiple Network Connections to Same Port on External Hosts
# amount 23
# ['wineventlog:security_2005']
# ('06/22/2023:15:00:00', '06/22/2023:15:30:00') test_random_agent Monitor for Changes to Firewall Rules
# amount 17590
# ['wineventlog:security_4688']
# ('06/22/2023:15:00:00', '06/22/2023:15:30:00') test_random_agent Monitor for Suspicious_Administrative Processes
# amount 235
# ['xmlwineventlog:microsoft-windows-sysmon/operational_8']
# ('06/22/2023:15:00:00', '06/22/2023:15:30:00') test_random_agent Suspicious Remote Thread Creation
# amount 11
# ['wineventlog:security_2004']
# ('06/22/2023:15:30:00', '06/22/2023:16:00:00') test_random_agent Monitor for Additions to Firewall Rules
# amount 18603
# ['wineventlog:security_4625']
# ('06/22/2023:15:30:00', '06/22/2023:16:00:00') test_random_agent Multiple Failed Logins from the Same Source
# amount 413
# ['xmlwineventlog:microsoft-windows-sysmon/operational_3']
# ('06/22/2023:15:30:00', '06/22/2023:16:00:00') test_random_agent Multiple Network Connections to Same Port on External Hosts
# amount 110
# ['wineventlog:security_2005']
# ('06/22/2023:15:30:00', '06/22/2023:16:00:00') test_random_agent Monitor for Changes to Firewall Rules
# amount 625
# ['wineventlog:security_4688']
# ('06/22/2023:15:30:00', '06/22/2023:16:00:00') test_random_agent Monitor for Suspicious_Administrative Processes
# amount 126
# ['xmlwineventlog:microsoft-windows-sysmon/operational_8']
# ('06/22/2023:15:30:00', '06/22/2023:16:00:00') test_random_agent Suspicious Remote Thread Creation
# amount 120
# ['wineventlog:security_2004']
# ('06/22/2023:08:30:00', '06/22/2023:09:00:00') test_passive_agent Monitor for Additions to Firewall Rules
# amount 0
# ['wineventlog:security_4625']
# ('06/22/2023:08:30:00', '06/22/2023:09:00:00') test_passive_agent Multiple Failed Logins from the Same Source
# amount 0
# ['xmlwineventlog:microsoft-windows-sysmon/operational_3']
# ('06/22/2023:08:30:00', '06/22/2023:09:00:00') test_passive_agent Multiple Network Connections to Same Port on External Hosts
# amount 0
# ['wineventlog:security_2005']
# ('06/22/2023:08:30:00', '06/22/2023:09:00:00') test_passive_agent Monitor for Changes to Firewall Rules
# amount 0
# ['wineventlog:security_4688']
# ('06/22/2023:08:30:00', '06/22/2023:09:00:00') test_passive_agent Monitor for Suspicious_Administrative Processes
# amount 0
# ['xmlwineventlog:microsoft-windows-sysmon/operational_8']
# ('06/22/2023:08:30:00', '06/22/2023:09:00:00') test_passive_agent Suspicious Remote Thread Creation
# amount 0
# ['wineventlog:security_2004']
# ('06/22/2023:09:00:00', '06/22/2023:09:30:00') test_passive_agent Monitor for Additions to Firewall Rules
# amount 0
# ['wineventlog:security_4625']
# ('06/22/2023:09:00:00', '06/22/2023:09:30:00') test_passive_agent Multiple Failed Logins from the Same Source
# amount 0
# ['xmlwineventlog:microsoft-windows-sysmon/operational_3']
# ('06/22/2023:09:00:00', '06/22/2023:09:30:00') test_passive_agent Multiple Network Connections to Same Port on External Hosts
# amount 0
# ['wineventlog:security_2005']
# ('06/22/2023:09:00:00', '06/22/2023:09:30:00') test_passive_agent Monitor for Changes to Firewall Rules
# amount 0
# ['wineventlog:security_4688']
# ('06/22/2023:09:00:00', '06/22/2023:09:30:00') test_passive_agent Monitor for Suspicious_Administrative Processes
# amount 0
# ['xmlwineventlog:microsoft-windows-sysmon/operational_8']
# ('06/22/2023:09:00:00', '06/22/2023:09:30:00') test_passive_agent Suspicious Remote Thread Creation
# amount 0
# ['wineventlog:security_2004']
# ('06/22/2023:09:30:00', '06/22/2023:10:00:00') test_passive_agent Monitor for Additions to Firewall Rules
# amount 0
# ['wineventlog:security_4625']
# ('06/22/2023:09:30:00', '06/22/2023:10:00:00') test_passive_agent Multiple Failed Logins from the Same Source
# amount 0
# ['xmlwineventlog:microsoft-windows-sysmon/operational_3']
# ('06/22/2023:09:30:00', '06/22/2023:10:00:00') test_passive_agent Multiple Network Connections to Same Port on External Hosts
# amount 0
# ['wineventlog:security_2005']
# ('06/22/2023:09:30:00', '06/22/2023:10:00:00') test_passive_agent Monitor for Changes to Firewall Rules
# amount 0
# ['wineventlog:security_4688']
# ('06/22/2023:09:30:00', '06/22/2023:10:00:00') test_passive_agent Monitor for Suspicious_Administrative Processes
# amount 0
# ['xmlwineventlog:microsoft-windows-sysmon/operational_8']
# ('06/22/2023:09:30:00', '06/22/2023:10:00:00') test_passive_agent Suspicious Remote Thread Creation
# amount 0
# ['wineventlog:security_2004']
# ('06/22/2023:10:00:00', '06/22/2023:10:30:00') test_passive_agent Monitor for Additions to Firewall Rules
# amount 0
# ['wineventlog:security_4625']
# ('06/22/2023:10:00:00', '06/22/2023:10:30:00') test_passive_agent Multiple Failed Logins from the Same Source
# amount 0
# ['xmlwineventlog:microsoft-windows-sysmon/operational_3']
# ('06/22/2023:10:00:00', '06/22/2023:10:30:00') test_passive_agent Multiple Network Connections to Same Port on External Hosts
# amount 0
# ['wineventlog:security_2005']
# ('06/22/2023:10:00:00', '06/22/2023:10:30:00') test_passive_agent Monitor for Changes to Firewall Rules
# amount 0
# ['wineventlog:security_4688']
# ('06/22/2023:10:00:00', '06/22/2023:10:30:00') test_passive_agent Monitor for Suspicious_Administrative Processes
# amount 0
# ['xmlwineventlog:microsoft-windows-sysmon/operational_8']
# ('06/22/2023:10:00:00', '06/22/2023:10:30:00') test_passive_agent Suspicious Remote Thread Creation
# amount 0
# ['wineventlog:security_2004']
# ('06/22/2023:10:30:00', '06/22/2023:11:00:00') test_passive_agent Monitor for Additions to Firewall Rules
# amount 0
# ['wineventlog:security_4625']
# ('06/22/2023:10:30:00', '06/22/2023:11:00:00') test_passive_agent Multiple Failed Logins from the Same Source
# amount 0
# ['xmlwineventlog:microsoft-windows-sysmon/operational_3']
# ('06/22/2023:10:30:00', '06/22/2023:11:00:00') test_passive_agent Multiple Network Connections to Same Port on External Hosts
# amount 0
# ['wineventlog:security_2005']
# ('06/22/2023:10:30:00', '06/22/2023:11:00:00') test_passive_agent Monitor for Changes to Firewall Rules
# amount 0
# ['wineventlog:security_4688']
# ('06/22/2023:10:30:00', '06/22/2023:11:00:00') test_passive_agent Monitor for Suspicious_Administrative Processes
# amount 0
# ['xmlwineventlog:microsoft-windows-sysmon/operational_8']
# ('06/22/2023:10:30:00', '06/22/2023:11:00:00') test_passive_agent Suspicious Remote Thread Creation
# amount 0
# ['wineventlog:security_2004']
# ('06/22/2023:11:00:00', '06/22/2023:11:30:00') test_passive_agent Monitor for Additions to Firewall Rules
# amount 0
# ['wineventlog:security_4625']
# ('06/22/2023:11:00:00', '06/22/2023:11:30:00') test_passive_agent Multiple Failed Logins from the Same Source
# amount 0
# ['xmlwineventlog:microsoft-windows-sysmon/operational_3']
# ('06/22/2023:11:00:00', '06/22/2023:11:30:00') test_passive_agent Multiple Network Connections to Same Port on External Hosts
# amount 0
# ['wineventlog:security_2005']
# ('06/22/2023:11:00:00', '06/22/2023:11:30:00') test_passive_agent Monitor for Changes to Firewall Rules
# amount 0
# ['wineventlog:security_4688']
# ('06/22/2023:11:00:00', '06/22/2023:11:30:00') test_passive_agent Monitor for Suspicious_Administrative Processes
# amount 0
# ['xmlwineventlog:microsoft-windows-sysmon/operational_8']
# ('06/22/2023:11:00:00', '06/22/2023:11:30:00') test_passive_agent Suspicious Remote Thread Creation
# amount 0
# ['wineventlog:security_2004']
# ('06/22/2023:11:30:00', '06/22/2023:12:00:00') test_passive_agent Monitor for Additions to Firewall Rules
# amount 0
# ['wineventlog:security_4625']
# ('06/22/2023:11:30:00', '06/22/2023:12:00:00') test_passive_agent Multiple Failed Logins from the Same Source
# amount 0
# ['xmlwineventlog:microsoft-windows-sysmon/operational_3']
# ('06/22/2023:11:30:00', '06/22/2023:12:00:00') test_passive_agent Multiple Network Connections to Same Port on External Hosts
# amount 0
# ['wineventlog:security_2005']
# ('06/22/2023:11:30:00', '06/22/2023:12:00:00') test_passive_agent Monitor for Changes to Firewall Rules
# amount 0
# ['wineventlog:security_4688']
# ('06/22/2023:11:30:00', '06/22/2023:12:00:00') test_passive_agent Monitor for Suspicious_Administrative Processes
# amount 0
# ['xmlwineventlog:microsoft-windows-sysmon/operational_8']
# ('06/22/2023:11:30:00', '06/22/2023:12:00:00') test_passive_agent Suspicious Remote Thread Creation
# amount 0
# ['wineventlog:security_2004']
# ('06/22/2023:12:00:00', '06/22/2023:12:30:00') test_passive_agent Monitor for Additions to Firewall Rules
# amount 0
# ['wineventlog:security_4625']
# ('06/22/2023:12:00:00', '06/22/2023:12:30:00') test_passive_agent Multiple Failed Logins from the Same Source
# amount 0
# ['xmlwineventlog:microsoft-windows-sysmon/operational_3']
# ('06/22/2023:12:00:00', '06/22/2023:12:30:00') test_passive_agent Multiple Network Connections to Same Port on External Hosts
# amount 0
# ['wineventlog:security_2005']
# ('06/22/2023:12:00:00', '06/22/2023:12:30:00') test_passive_agent Monitor for Changes to Firewall Rules
# amount 0
# ['wineventlog:security_4688']
# ('06/22/2023:12:00:00', '06/22/2023:12:30:00') test_passive_agent Monitor for Suspicious_Administrative Processes
# amount 0
# ['xmlwineventlog:microsoft-windows-sysmon/operational_8']
# ('06/22/2023:12:00:00', '06/22/2023:12:30:00') test_passive_agent Suspicious Remote Thread Creation
# amount 0
# ['wineventlog:security_2004']
# ('06/22/2023:12:30:00', '06/22/2023:13:00:00') test_passive_agent Monitor for Additions to Firewall Rules
# amount 0
# ['wineventlog:security_4625']
# ('06/22/2023:12:30:00', '06/22/2023:13:00:00') test_passive_agent Multiple Failed Logins from the Same Source
# amount 0
# ['xmlwineventlog:microsoft-windows-sysmon/operational_3']
# ('06/22/2023:12:30:00', '06/22/2023:13:00:00') test_passive_agent Multiple Network Connections to Same Port on External Hosts
# amount 0
# ['wineventlog:security_2005']
# ('06/22/2023:12:30:00', '06/22/2023:13:00:00') test_passive_agent Monitor for Changes to Firewall Rules
# amount 0
# ['wineventlog:security_4688']
# ('06/22/2023:12:30:00', '06/22/2023:13:00:00') test_passive_agent Monitor for Suspicious_Administrative Processes
# amount 0
# ['xmlwineventlog:microsoft-windows-sysmon/operational_8']
# ('06/22/2023:12:30:00', '06/22/2023:13:00:00') test_passive_agent Suspicious Remote Thread Creation
# amount 0
# ['wineventlog:security_2004']
# ('06/22/2023:13:00:00', '06/22/2023:13:30:00') test_passive_agent Monitor for Additions to Firewall Rules
# amount 0
# ['wineventlog:security_4625']
# ('06/22/2023:13:00:00', '06/22/2023:13:30:00') test_passive_agent Multiple Failed Logins from the Same Source
# amount 0
# ['xmlwineventlog:microsoft-windows-sysmon/operational_3']
# ('06/22/2023:13:00:00', '06/22/2023:13:30:00') test_passive_agent Multiple Network Connections to Same Port on External Hosts
# amount 0
# ['wineventlog:security_2005']
# ('06/22/2023:13:00:00', '06/22/2023:13:30:00') test_passive_agent Monitor for Changes to Firewall Rules
# amount 0
# ['wineventlog:security_4688']
# ('06/22/2023:13:00:00', '06/22/2023:13:30:00') test_passive_agent Monitor for Suspicious_Administrative Processes
# amount 0
# ['xmlwineventlog:microsoft-windows-sysmon/operational_8']
# ('06/22/2023:13:00:00', '06/22/2023:13:30:00') test_passive_agent Suspicious Remote Thread Creation
# amount 0
# ['wineventlog:security_2004']
# ('06/22/2023:13:30:00', '06/22/2023:14:00:00') test_passive_agent Monitor for Additions to Firewall Rules
# amount 0
# ['wineventlog:security_4625']
# ('06/22/2023:13:30:00', '06/22/2023:14:00:00') test_passive_agent Multiple Failed Logins from the Same Source
# amount 0
# ['xmlwineventlog:microsoft-windows-sysmon/operational_3']
# ('06/22/2023:13:30:00', '06/22/2023:14:00:00') test_passive_agent Multiple Network Connections to Same Port on External Hosts
# amount 0
# ['wineventlog:security_2005']
# ('06/22/2023:13:30:00', '06/22/2023:14:00:00') test_passive_agent Monitor for Changes to Firewall Rules
# amount 0
# ['wineventlog:security_4688']
# ('06/22/2023:13:30:00', '06/22/2023:14:00:00') test_passive_agent Monitor for Suspicious_Administrative Processes
# amount 0
# ['xmlwineventlog:microsoft-windows-sysmon/operational_8']
# ('06/22/2023:13:30:00', '06/22/2023:14:00:00') test_passive_agent Suspicious Remote Thread Creation
# amount 0
# ['wineventlog:security_2004']
# ('06/22/2023:14:00:00', '06/22/2023:14:30:00') test_passive_agent Monitor for Additions to Firewall Rules
# amount 0
# ['wineventlog:security_4625']
# ('06/22/2023:14:00:00', '06/22/2023:14:30:00') test_passive_agent Multiple Failed Logins from the Same Source
# amount 0
# ['xmlwineventlog:microsoft-windows-sysmon/operational_3']
# ('06/22/2023:14:00:00', '06/22/2023:14:30:00') test_passive_agent Multiple Network Connections to Same Port on External Hosts
# amount 0
# ['wineventlog:security_2005']
# ('06/22/2023:14:00:00', '06/22/2023:14:30:00') test_passive_agent Monitor for Changes to Firewall Rules
# amount 0
# ['wineventlog:security_4688']
# ('06/22/2023:14:00:00', '06/22/2023:14:30:00') test_passive_agent Monitor for Suspicious_Administrative Processes
# amount 0
# ['xmlwineventlog:microsoft-windows-sysmon/operational_8']
# ('06/22/2023:14:00:00', '06/22/2023:14:30:00') test_passive_agent Suspicious Remote Thread Creation
# amount 0
# ['wineventlog:security_2004']
# ('06/22/2023:14:30:00', '06/22/2023:15:00:00') test_passive_agent Monitor for Additions to Firewall Rules
# amount 0
# ['wineventlog:security_4625']
# ('06/22/2023:14:30:00', '06/22/2023:15:00:00') test_passive_agent Multiple Failed Logins from the Same Source
# amount 0
# ['xmlwineventlog:microsoft-windows-sysmon/operational_3']
# ('06/22/2023:14:30:00', '06/22/2023:15:00:00') test_passive_agent Multiple Network Connections to Same Port on External Hosts
# amount 0
# ['wineventlog:security_2005']
# ('06/22/2023:14:30:00', '06/22/2023:15:00:00') test_passive_agent Monitor for Changes to Firewall Rules
# amount 0
# ['wineventlog:security_4688']
# ('06/22/2023:14:30:00', '06/22/2023:15:00:00') test_passive_agent Monitor for Suspicious_Administrative Processes
# amount 0
# ['xmlwineventlog:microsoft-windows-sysmon/operational_8']
# ('06/22/2023:14:30:00', '06/22/2023:15:00:00') test_passive_agent Suspicious Remote Thread Creation
# amount 0
# ['wineventlog:security_2004']
# ('06/22/2023:15:00:00', '06/22/2023:15:30:00') test_passive_agent Monitor for Additions to Firewall Rules
# amount 0
# ['wineventlog:security_4625']
# ('06/22/2023:15:00:00', '06/22/2023:15:30:00') test_passive_agent Multiple Failed Logins from the Same Source
# amount 0
# ['xmlwineventlog:microsoft-windows-sysmon/operational_3']
# ('06/22/2023:15:00:00', '06/22/2023:15:30:00') test_passive_agent Multiple Network Connections to Same Port on External Hosts
# amount 0
# ['wineventlog:security_2005']
# ('06/22/2023:15:00:00', '06/22/2023:15:30:00') test_passive_agent Monitor for Changes to Firewall Rules
# amount 0
# ['wineventlog:security_4688']
# ('06/22/2023:15:00:00', '06/22/2023:15:30:00') test_passive_agent Monitor for Suspicious_Administrative Processes
# amount 0
# ['xmlwineventlog:microsoft-windows-sysmon/operational_8']
# ('06/22/2023:15:00:00', '06/22/2023:15:30:00') test_passive_agent Suspicious Remote Thread Creation
# amount 0
# ['wineventlog:security_2004']
# ('06/22/2023:15:30:00', '06/22/2023:16:00:00') test_passive_agent Monitor for Additions to Firewall Rules
# amount 0
# ['wineventlog:security_4625']
# ('06/22/2023:15:30:00', '06/22/2023:16:00:00') test_passive_agent Multiple Failed Logins from the Same Source
# amount 0
# ['xmlwineventlog:microsoft-windows-sysmon/operational_3']
# ('06/22/2023:15:30:00', '06/22/2023:16:00:00') test_passive_agent Multiple Network Connections to Same Port on External Hosts
# amount 0
# ['wineventlog:security_2005']
# ('06/22/2023:15:30:00', '06/22/2023:16:00:00') test_passive_agent Monitor for Changes to Firewall Rules
# amount 0
# ['wineventlog:security_4688']
# ('06/22/2023:15:30:00', '06/22/2023:16:00:00') test_passive_agent Monitor for Suspicious_Administrative Processes
# amount 0
# ['xmlwineventlog:microsoft-windows-sysmon/operational_8']
# ('06/22/2023:15:30:00', '06/22/2023:16:00:00') test_passive_agent Suspicious Remote Thread Creation
# amount 0

# %%
alt.Chart(time_rules_energy_df).mark_line(color='green', point=True).encode(
    x='index',
    y='duration',
    color='method',
    row='rule_name'

).properties(
    title='Energy consumption of the DRL method vs the baseline methods',
)
# Out:
# alt.Chart(...)

# %%
import matplotlib.pyplot as plt

rule_names = time_rules_energy_df['rule_name'].unique()
methods = time_rules_energy_df['method'].unique()
n_rows = len(rule_names)
n_cols = len(methods)

# Function to add line breaks to longer labels
def add_line_breaks(text, max_length=30):
    words = text.split()
    lines = []
    current_line = []
    current_length = 0

    for word in words:
        if current_length + len(word) + len(current_line) - 1 > max_length:  # + len(current_line) - 1 for spaces
            lines.append(' '.join(current_line))
            current_length = 0
            current_line = []
        current_line.append(word)
        current_length += len(word)

    lines.append(' '.join(current_line))
    return '\n'.join(lines)

# Apply the function to the rule names
formatted_rule_names = [add_line_breaks(rule) for rule in rule_names]

fig, axs = plt.subplots(n_rows, n_cols, figsize=(15, 15), constrained_layout=True)

# Setting column titles for methods
for ax, col in zip(axs[0], methods):
    ax.set_title(col)

# get y_min y_maxx y2_min y2_max
y_min, y_max = time_rules_energy_df['duration'].min(), time_rules_energy_df['duration'].max()
y2_min, y2_max = time_rules_energy_df['action_amount'].min(), 1.5*time_rules_energy_df['action_amount'].max()

# Iterate over each subplot and plot the data
for row, rule_name in enumerate(rule_names):
    for col, method in enumerate(methods):
        ax1 = axs[row, col]
        
        # Filter data for the current method and rule_name
        filtered_data = time_rules_energy_df[(time_rules_energy_df['method'] == method) & 
                                             (time_rules_energy_df['rule_name'] == rule_name)].sort_values(by=['index'])
        
        # Plot the first data (energy) on the primary y-axis
        ax1.plot(filtered_data['index'], filtered_data['duration'], color='green', label='duration')
        ax1.set_ylabel('duration', color='green')
        ax1.tick_params(axis='y', labelcolor='green')
        ax1.set_ylim(y_min, y_max)
        
        # Create a secondary y-axis for the subplot
        ax2 = ax1.twinx()
        
        # Plot the second data (action_amount) on the secondary y-axis
        ax2.plot(filtered_data['index'], filtered_data['action_amount'], color='blue', label='action_amount')
        ax2.set_ylabel('Action Amount', color='blue')
        ax2.tick_params(axis='y', labelcolor='blue')
        ax2.set_ylim(y2_min, y2_max)
        
        # Set formatted rule_name as the y-label for the first column, without rotation
        if col == 0:
            ax1.set_ylabel(formatted_rule_names[row], size='large', color='black')

# Set an overall title for the entire figure
plt.suptitle("duration and Action Amount for Different Methods and Rules", y=1.03, fontsize=16)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_3942/3817362666.py:69: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %%
relevant_log_types
# Out:
# ['xmlwineventlog:microsoft-windows-sysmon/operational_8']

# %%
alt.Chart(time_rules_energy_df.sort_values(by=['energy'], ascending=False)).mark_line(color='green', point=True).encode(
    x=alt.X('action_amount', sort=alt.EncodingSortField(field="energy", op="sum", order='ascending')),
    y='energy',
    color=alt.Color('rule_name', sort='-y', scale=alt.Scale(scheme='category20')),

)
# Out:
# alt.Chart(...)

# %%
base = alt.Chart(time_rules_energy_df).encode(x='index')

# Chart for energy
e = base.mark_line(color='green').encode(
    y=alt.Y('energy', axis=alt.Axis(title='Energy', orient='left'))
)

# Chart for action amount with its own y-axis on the right
a = base.mark_line(color='blue').encode(
    y=alt.Y('action_amount', axis=alt.Axis(title='Action Amount', orient='right'))
)

# Combine the charts and facet them
chart = (e + a).facet(
    column='method',
    row='rule_name'
).resolve_scale(
    y='independent'
).properties(
    title='Energy consumption of the DRL method vs the baseline methods'
)

chart
# Out:
# alt.FacetChart(...)

# %%
import re
CPU_TDP = 200

path = '/home/shouei/GreenSecurity-FirstExperiment/SplunkResearch/VMware, Inc. Linux 3.10.0-1160.88.1.el7.x86_64/Splunk Enterprise SIEM/Power Saver Plan/One Scan'
last = 454
num_of_measurements = 16
rng = range(last-num_of_measurements+1, last+1 )
dirs = {f'Measurement {i}'for i in rng}
measurement_dirs = sorted([d for d in os.listdir(path) if d in dirs])
# measurement_dirs = sorted([d for d in os.listdir(path) if d.startswith('Measurement')])
dfs=[]
action_list = []
time_field = 'Time(sec)'
for measurement_dir in measurement_dirs:
    measurement_path = os.path.join(path, measurement_dir)
    rules_enegry_path = os.path.join(measurement_path, 'rules_energy.csv')
    rules_energy_df = pd.read_csv(rules_enegry_path)
    with open(os.path.join(measurement_path, 'action.txt'), 'r') as f:
        action = f.read()
    # transform the action string to a list of integers
    action = [i.strip('\n').strip(' ') for i in re.split(',| ',action[1:-1])]
    action = [int(i) for i in action if i != '']
    action_list.append(action)     
    if rules_energy_df.empty:
        continue
    print(measurement_dir)
    # create a new column for the time interval
    rules_energy_df[time_field] = pd.to_datetime(rules_energy_df[time_field])
    # Get start time
    start_time = rules_energy_df[time_field].min()
    rules_energy_df = rules_energy_df.sort_values(by=['name', time_field])
    # get difference between each time interval in seconds grouped by name
    rules_energy_df['delta_time'] = rules_energy_df.groupby('name')[time_field].diff().dt.total_seconds().fillna(0)
    # create a new column for the integral of the cpu using the trapezoidal rule
    # grouped_rules_energy_df = rules_energy_df.groupby('name').apply(lambda g: integrate.simpson(g['CPU(%)'], x=g['delta_time']))
    # grouped_rules_energy_df = grouped_rules_energy_df.reset_index().rename(columns={0: 'cpu_integral'})
    rules_energy_df['CPU(W)'] = rules_energy_df['CPU(%)'] * CPU_TDP / 100
    rules_energy_df['CPU(J)'] = rules_energy_df['CPU(W)'] * rules_energy_df['delta_time']
    grouped_rules_enegry_df = rules_energy_df.groupby('name')['CPU(J)'].sum().reset_index()
    # create a chart for the cpu usage using altair
    grouped_rules_enegry_df['measurement'] = measurement_dir
    dfs.append(grouped_rules_enegry_df)
action_df = pd.DataFrame(action_list, columns=log_types_str)
action_df['measurement'] = measurement_dirs
final_df = pd.concat(dfs)
# Out:
# Measurement 439
# Measurement 440
# Measurement 441
# Measurement 442
# Measurement 443
# Measurement 444
# Measurement 445
# Measurement 446
# Measurement 447
# Measurement 448
# Measurement 449
# Measurement 450
# Measurement 451
# Measurement 452
# Measurement 453
# Measurement 454

# %%
rules_energy_df.groupby('name')[time_field].diff().dt.total_seconds().fillna(0)
# Out:
# 37    0.000000
# 38    0.350979
# 39    0.376344
# 40    0.262398
# 41    0.230555
# 42    0.213279
# 43    0.149717
# 44    0.149262
# 45    0.142408
# 46    0.141534
# 47    0.130617
# 48    0.135719
# 49    0.130892
# 50    0.130981
# 51    0.131114
# 52    0.131661
# 14    0.000000
# 15    0.350979
# 16    0.376344
# 17    0.262398
# 18    0.230555
# 19    0.213279
# 20    0.149717
# 21    0.149262
# 22    0.142408
# 23    0.141534
# 24    0.130617
# 25    0.135719
# 26    0.130892
# 27    0.130981
# 28    0.131114
# 29    0.131661
# 30    0.134456
# 31    0.110339
# 32    0.090784
# 33    0.090137
# 34    0.116036
# 35    0.131244
# 36    0.148410
# 0     0.000000
# 1     0.093803
# 2     0.097629
# 3     0.114057
# 4     0.112766
# 5     0.118372
# 6     0.147915
# 7     0.106610
# 8     0.209148
# 9     0.356126
# 10    0.350979
# 11    0.376344
# 12    0.262398
# 13    0.230555
# Name: Time(sec), dtype: float64

# %%
# merge helper df with final df
final_df_with_action = pd.merge(final_df, action_df, left_on='measurement', right_on='measurement')
final_df_with_action['action'] =pd.Series([0]*len(final_df_with_action))
for measurement_dir in measurement_dirs:
    if final_df_with_action[final_df_with_action['measurement'] == measurement_dir].empty:
        continue
    if final_df_with_action[final_df_with_action['measurement'] == measurement_dir].loc[:,log_types_str].iloc[0].sum() > 0:
        final_df_with_action.loc[final_df_with_action['measurement'] == measurement_dir, 'action'] = 1

# %%
unique_log_types = {x for y in logtypes_by_rule_dict.values() for x in y}
print(len(unique_log_types))
unique_log_types
# Out:
# 28
# {'wineventlog:application_1000',
#  'wineventlog:security_1100',
#  'wineventlog:security_1102',
#  'wineventlog:security_2004',
#  'wineventlog:security_2005',
#  'wineventlog:security_4624',
#  'wineventlog:security_4625',
#  'wineventlog:security_4634',
#  'wineventlog:security_4657',
#  'wineventlog:security_4663',
#  'wineventlog:security_4688',
#  'wineventlog:security_4720',
#  'wineventlog:security_4728',
#  'wineventlog:security_4732',
#  'wineventlog:security_4756',
#  'wineventlog:security_5140',
#  'wineventlog:security_7045',
#  'wineventlog:system_104',
#  'wineventlog:system_1074',
#  'wineventlog:system_6008',
#  'wineventlog:system_7040',
#  'xmlwineventlog:microsoft-windows-sysmon/operational_11',
#  'xmlwineventlog:microsoft-windows-sysmon/operational_12',
#  'xmlwineventlog:microsoft-windows-sysmon/operational_13',
#  'xmlwineventlog:microsoft-windows-sysmon/operational_14',
#  'xmlwineventlog:microsoft-windows-sysmon/operational_16',
#  'xmlwineventlog:microsoft-windows-sysmon/operational_3',
#  'xmlwineventlog:microsoft-windows-sysmon/operational_8'}

# %%
sums = []
for rule, measurement in final_df_with_action[['name', 'measurement']].values:
    try:
        sums.append(final_df_with_action[(final_df_with_action.name == rule)&(final_df_with_action.measurement == measurement)][logtypes_by_rule_dict[rule.lower()]].sum(axis=1).values[0])
    except:
        sums.append(0)
final_df_with_action['relevant_logs_addition'] = sums

# %%
final_df_with_action
# Out:
#                                                  name      CPU(J)  \
# 0                     Modification of Executable File  120.371748
# 1   Multiple Network Connections to Same Port on E...  150.353172
# 2                             New Local Admin Account   47.898942
# 3                     Modification of Executable File  120.503789
# 4   Multiple Network Connections to Same Port on E...  153.978820
# 5                             New Local Admin Account   43.542498
# 6                     Modification of Executable File  129.968372
# 7   Multiple Network Connections to Same Port on E...  168.066588
# 8                             New Local Admin Account   55.170376
# 9                     Modification of Executable File  138.870881
# 10  Multiple Network Connections to Same Port on E...  176.871861
# 11                            New Local Admin Account   41.843433
# 12                    Modification of Executable File  110.105407
# 13  Multiple Network Connections to Same Port on E...  137.943981
# 14                            New Local Admin Account   56.787862
# 15                    Modification of Executable File  112.788503
# 16  Multiple Network Connections to Same Port on E...  162.254137
# 17                            New Local Admin Account   61.269330
# 18                    Modification of Executable File  127.374333
# 19  Multiple Network Connections to Same Port on E...  155.389919
# 20                            New Local Admin Account   65.687919
# 21                    Modification of Executable File  121.226876
# 22  Multiple Network Connections to Same Port on E...  135.992671
# 23                            New Local Admin Account   47.107800
# 24                    Modification of Executable File  124.195076
# 25  Multiple Network Connections to Same Port on E...  170.021937
# 26                            New Local Admin Account   59.156518
# 27                    Modification of Executable File  115.571201
# 28    Monitor for Suspicious/Administrative Processes   33.607778
# 29  Multiple Network Connections to Same Port on E...  151.776117
# 30                            New Local Admin Account   36.555878
# 31                    Modification of Executable File  118.951220
# 32  Multiple Network Connections to Same Port on E...  151.007966
# 33                            New Local Admin Account   42.393463
# 34                    Modification of Executable File  140.268434
# 35  Multiple Network Connections to Same Port on E...  180.622935
# 36                            New Local Admin Account   62.426349
# 37                    Modification of Executable File  143.707447
# 38  Multiple Network Connections to Same Port on E...  178.233461
# 39                            New Local Admin Account   60.524127
# 40                    Modification of Executable File  116.476236
# 41  Multiple Network Connections to Same Port on E...  156.858505
# 42                            New Local Admin Account   39.445065
# 43                    Modification of Executable File  153.348233
# 44  Multiple Network Connections to Same Port on E...  161.872423
# 45                            New Local Admin Account   65.900606
# 46                    Modification of Executable File  110.499985
# 47  Multiple Network Connections to Same Port on E...  151.246229
# 48                            New Local Admin Account   51.297957
#
#         measurement  xmlwineventlog:microsoft-windows-sysmon/operational_8  \
# 0   Measurement 439                                                  0
# 1   Measurement 439                                                  0
# 2   Measurement 439                                                  0
# 3   Measurement 440                                                122
# 4   Measurement 440                                                122
# 5   Measurement 440                                                122
# 6   Measurement 441                                                  0
# 7   Measurement 441                                                  0
# 8   Measurement 441                                                  0
# 9   Measurement 442                                                935
# 10  Measurement 442                                                935
# 11  Measurement 442                                                935
# 12  Measurement 443                                                  0
# 13  Measurement 443                                                  0
# 14  Measurement 443                                                  0
# 15  Measurement 444                                                538
# 16  Measurement 444                                                538
# 17  Measurement 444                                                538
# 18  Measurement 445                                                  0
# 19  Measurement 445                                                  0
# 20  Measurement 445                                                  0
# 21  Measurement 446                                                924
# 22  Measurement 446                                                924
# 23  Measurement 446                                                924
# 24  Measurement 447                                                  0
# 25  Measurement 447                                                  0
# 26  Measurement 447                                                  0
# 27  Measurement 448                                                827
# 28  Measurement 448                                                827
# 29  Measurement 448                                                827
# 30  Measurement 448                                                827
# 31  Measurement 449                                                  0
# 32  Measurement 449                                                  0
# 33  Measurement 449                                                  0
# 34  Measurement 450                                                179
# 35  Measurement 450                                                179
# 36  Measurement 450                                                179
# 37  Measurement 451                                                  0
# 38  Measurement 451                                                  0
# 39  Measurement 451                                                  0
# 40  Measurement 452                                                967
# 41  Measurement 452                                                967
# 42  Measurement 452                                                967
# 43  Measurement 453                                                  0
# 44  Measurement 453                                                  0
# 45  Measurement 453                                                  0
# 46  Measurement 454                                                 34
# 47  Measurement 454                                                 34
# 48  Measurement 454                                                 34
#
#     wineventlog:security_2005  wineventlog:security_4624  \
# 0                           0                          0
# 1                           0                          0
# 2                           0                          0
# 3                         760                          4
# 4                         760                          4
# 5                         760                          4
# 6                           0                          0
# 7                           0                          0
# 8                           0                          0
# 9                         118                        857
# 10                        118                        857
# 11                        118                        857
# 12                          0                          0
# 13                          0                          0
# 14                          0                          0
# 15                        417                        852
# 16                        417                        852
# 17                        417                        852
# 18                          0                          0
# 19                          0                          0
# 20                          0                          0
# 21                        747                        374
# 22                        747                        374
# 23                        747                        374
# 24                          0                          0
# 25                          0                          0
# 26                          0                          0
# 27                        832                        896
# 28                        832                        896
# 29                        832                        896
# 30                        832                        896
# 31                          0                          0
# 32                          0                          0
# 33                          0                          0
# 34                        189                        831
# 35                        189                        831
# 36                        189                        831
# 37                          0                          0
# 38                          0                          0
# 39                          0                          0
# 40                        590                        238
# 41                        590                        238
# 42                        590                        238
# 43                          0                          0
# 44                          0                          0
# 45                          0                          0
# 46                        707                        998
# 47                        707                        998
# 48                        707                        998
#
#     wineventlog:security_4756  \
# 0                           0
# 1                           0
# 2                           0
# 3                         698
# 4                         698
# 5                         698
# 6                           0
# 7                           0
# 8                           0
# 9                         210
# 10                        210
# 11                        210
# 12                          0
# 13                          0
# 14                          0
# 15                        298
# 16                        298
# 17                        298
# 18                          0
# 19                          0
# 20                          0
# 21                        585
# 22                        585
# 23                        585
# 24                          0
# 25                          0
# 26                          0
# 27                        536
# 28                        536
# 29                        536
# 30                        536
# 31                          0
# 32                          0
# 33                          0
# 34                        201
# 35                        201
# 36                        201
# 37                          0
# 38                          0
# 39                          0
# 40                        858
# 41                        858
# 42                        858
# 43                          0
# 44                          0
# 45                          0
# 46                        323
# 47                        323
# 48                        323
#
#     xmlwineventlog:microsoft-windows-sysmon/operational_3  \
# 0                                                   0
# 1                                                   0
# 2                                                   0
# 3                                                  92
# 4                                                  92
# 5                                                  92
# 6                                                   0
# 7                                                   0
# 8                                                   0
# 9                                                 232
# 10                                                232
# 11                                                232
# 12                                                  0
# 13                                                  0
# 14                                                  0
# 15                                                239
# 16                                                239
# 17                                                239
# 18                                                  0
# 19                                                  0
# 20                                                  0
# 21                                                267
# 22                                                267
# 23                                                267
# 24                                                  0
# 25                                                  0
# 26                                                  0
# 27                                                 96
# 28                                                 96
# 29                                                 96
# 30                                                 96
# 31                                                  0
# 32                                                  0
# 33                                                  0
# 34                                                858
# 35                                                858
# 36                                                858
# 37                                                  0
# 38                                                  0
# 39                                                  0
# 40                                                399
# 41                                                399
# 42                                                399
# 43                                                  0
# 44                                                  0
# 45                                                  0
# 46                                                397
# 47                                                397
# 48                                                397
#
#     xmlwineventlog:microsoft-windows-sysmon/operational_14  \
# 0                                                   0
# 1                                                   0
# 2                                                   0
# 3                                                 990
# 4                                                 990
# 5                                                 990
# 6                                                   0
# 7                                                   0
# 8                                                   0
# 9                                                  82
# 10                                                 82
# 11                                                 82
# 12                                                  0
# 13                                                  0
# 14                                                  0
# 15                                                117
# 16                                                117
# 17                                                117
# 18                                                  0
# 19                                                  0
# 20                                                  0
# 21                                                197
# 22                                                197
# 23                                                197
# 24                                                  0
# 25                                                  0
# 26                                                  0
# 27                                                682
# 28                                                682
# 29                                                682
# 30                                                682
# 31                                                  0
# 32                                                  0
# 33                                                  0
# 34                                                901
# 35                                                901
# 36                                                901
# 37                                                  0
# 38                                                  0
# 39                                                  0
# 40                                                 31
# 41                                                 31
# 42                                                 31
# 43                                                  0
# 44                                                  0
# 45                                                  0
# 46                                                 63
# 47                                                 63
# 48                                                 63
#
#     wineventlog:security_1102  ...  \
# 0                           0  ...
# 1                           0  ...
# 2                           0  ...
# 3                         715  ...
# 4                         715  ...
# 5                         715  ...
# 6                           0  ...
# 7                           0  ...
# 8                           0  ...
# 9                         949  ...
# 10                        949  ...
# 11                        949  ...
# 12                          0  ...
# 13                          0  ...
# 14                          0  ...
# 15                        403  ...
# 16                        403  ...
# 17                        403  ...
# 18                          0  ...
# 19                          0  ...
# 20                          0  ...
# 21                        433  ...
# 22                        433  ...
# 23                        433  ...
# 24                          0  ...
# 25                          0  ...
# 26                          0  ...
# 27                        797  ...
# 28                        797  ...
# 29                        797  ...
# 30                        797  ...
# 31                          0  ...
# 32                          0  ...
# 33                          0  ...
# 34                          5  ...
# 35                          5  ...
# 36                          5  ...
# 37                          0  ...
# 38                          0  ...
# 39                          0  ...
# 40                        416  ...
# 41                        416  ...
# 42                        416  ...
# 43                          0  ...
# 44                          0  ...
# 45                          0  ...
# 46                        729  ...
# 47                        729  ...
# 48                        729  ...
#
#     xmlwineventlog:microsoft-windows-sysmon/operational_11  \
# 0                                                   0
# 1                                                   0
# 2                                                   0
# 3                                                 411
# 4                                                 411
# 5                                                 411
# 6                                                   0
# 7                                                   0
# 8                                                   0
# 9                                                 281
# 10                                                281
# 11                                                281
# 12                                                  0
# 13                                                  0
# 14                                                  0
# 15                                                818
# 16                                                818
# 17                                                818
# 18                                                  0
# 19                                                  0
# 20                                                  0
# 21                                                433
# 22                                                433
# 23                                                433
# 24                                                  0
# 25                                                  0
# 26                                                  0
# 27                                                351
# 28                                                351
# 29                                                351
# 30                                                351
# 31                                                  0
# 32                                                  0
# 33                                                  0
# 34                                                982
# 35                                                982
# 36                                                982
# 37                                                  0
# 38                                                  0
# 39                                                  0
# 40                                                667
# 41                                                667
# 42                                                667
# 43                                                  0
# 44                                                  0
# 45                                                  0
# 46                                                684
# 47                                                684
# 48                                                684
#
#     wineventlog:security_4634  wineventlog:security_4663  \
# 0                           0                          0
# 1                           0                          0
# 2                           0                          0
# 3                         811                        285
# 4                         811                        285
# 5                         811                        285
# 6                           0                          0
# 7                           0                          0
# 8                           0                          0
# 9                         976                        395
# 10                        976                        395
# 11                        976                        395
# 12                          0                          0
# 13                          0                          0
# 14                          0                          0
# 15                         62                        978
# 16                         62                        978
# 17                         62                        978
# 18                          0                          0
# 19                          0                          0
# 20                          0                          0
# 21                        390                        765
# 22                        390                        765
# 23                        390                        765
# 24                          0                          0
# 25                          0                          0
# 26                          0                          0
# 27                        397                        282
# 28                        397                        282
# 29                        397                        282
# 30                        397                        282
# 31                          0                          0
# 32                          0                          0
# 33                          0                          0
# 34                         44                        226
# 35                         44                        226
# 36                         44                        226
# 37                          0                          0
# 38                          0                          0
# 39                          0                          0
# 40                        180                        837
# 41                        180                        837
# 42                        180                        837
# 43                          0                          0
# 44                          0                          0
# 45                          0                          0
# 46                        477                        597
# 47                        477                        597
# 48                        477                        597
#
#     wineventlog:system_104  wineventlog:security_4720  \
# 0                        0                          0
# 1                        0                          0
# 2                        0                          0
# 3                       38                        272
# 4                       38                        272
# 5                       38                        272
# 6                        0                          0
# 7                        0                          0
# 8                        0                          0
# 9                      322                        572
# 10                     322                        572
# 11                     322                        572
# 12                       0                          0
# 13                       0                          0
# 14                       0                          0
# 15                     973                        128
# 16                     973                        128
# 17                     973                        128
# 18                       0                          0
# 19                       0                          0
# 20                       0                          0
# 21                     263                        536
# 22                     263                        536
# 23                     263                        536
# 24                       0                          0
# 25                       0                          0
# 26                       0                          0
# 27                     463                        716
# 28                     463                        716
# 29                     463                        716
# 30                     463                        716
# 31                       0                          0
# 32                       0                          0
# 33                       0                          0
# 34                     313                        731
# 35                     313                        731
# 36                     313                        731
# 37                       0                          0
# 38                       0                          0
# 39                       0                          0
# 40                     437                        275
# 41                     437                        275
# 42                     437                        275
# 43                       0                          0
# 44                       0                          0
# 45                       0                          0
# 46                     344                        398
# 47                     344                        398
# 48                     344                        398
#
#     wineventlog:security_4625  wineventlog:security_4732  \
# 0                           0                          0
# 1                           0                          0
# 2                           0                          0
# 3                         373                        503
# 4                         373                        503
# 5                         373                        503
# 6                           0                          0
# 7                           0                          0
# 8                           0                          0
# 9                          93                        694
# 10                         93                        694
# 11                         93                        694
# 12                          0                          0
# 13                          0                          0
# 14                          0                          0
# 15                        625                        874
# 16                        625                        874
# 17                        625                        874
# 18                          0                          0
# 19                          0                          0
# 20                          0                          0
# 21                        776                        658
# 22                        776                        658
# 23                        776                        658
# 24                          0                          0
# 25                          0                          0
# 26                          0                          0
# 27                        463                        487
# 28                        463                        487
# 29                        463                        487
# 30                        463                        487
# 31                          0                          0
# 32                          0                          0
# 33                          0                          0
# 34                        891                         87
# 35                        891                         87
# 36                        891                         87
# 37                          0                          0
# 38                          0                          0
# 39                          0                          0
# 40                        546                         55
# 41                        546                         55
# 42                        546                         55
# 43                          0                          0
# 44                          0                          0
# 45                          0                          0
# 46                        956                        607
# 47                        956                        607
# 48                        956                        607
#
#     xmlwineventlog:microsoft-windows-sysmon/operational_16  action  \
# 0                                                   0            0
# 1                                                   0            0
# 2                                                   0            0
# 3                                                 850            1
# 4                                                 850            1
# 5                                                 850            1
# 6                                                   0            0
# 7                                                   0            0
# 8                                                   0            0
# 9                                                 130            1
# 10                                                130            1
# 11                                                130            1
# 12                                                  0            0
# 13                                                  0            0
# 14                                                  0            0
# 15                                                695            1
# 16                                                695            1
# 17                                                695            1
# 18                                                  0            0
# 19                                                  0            0
# 20                                                  0            0
# 21                                                436            1
# 22                                                436            1
# 23                                                436            1
# 24                                                  0            0
# 25                                                  0            0
# 26                                                  0            0
# 27                                                974            1
# 28                                                974            1
# 29                                                974            1
# 30                                                974            1
# 31                                                  0            0
# 32                                                  0            0
# 33                                                  0            0
# 34                                                692            1
# 35                                                692            1
# 36                                                692            1
# 37                                                  0            0
# 38                                                  0            0
# 39                                                  0            0
# 40                                                601            1
# 41                                                601            1
# 42                                                601            1
# 43                                                  0            0
# 44                                                  0            0
# 45                                                  0            0
# 46                                                581            1
# 47                                                581            1
# 48                                                581            1
#
#     relevant_logs_addition
# 0                        0
# 1                        0
# 2                        0
# 3                      411
# 4                       92
# 5                      775
# 6                        0
# 7                        0
# 8                        0
# 9                      281
# 10                     232
# 11                    1266
# 12                       0
# 13                       0
# 14                       0
# 15                     818
# 16                     239
# 17                    1002
# 18                       0
# 19                       0
# 20                       0
# 21                     433
# 22                     267
# 23                    1194
# 24                       0
# 25                       0
# 26                       0
# 27                     351
# 28                     103
# 29                      96
# 30                    1203
# 31                       0
# 32                       0
# 33                       0
# 34                     982
# 35                     858
# 36                     818
# 37                       0
# 38                       0
# 39                       0
# 40                     667
# 41                     399
# 42                     330
# 43                       0
# 44                       0
# 45                       0
# 46                     684
# 47                     397
# 48                    1005
#
# [49 rows x 33 columns]

# %%
chart = alt.Chart(final_df_with_action).mark_line(point=True).encode(
y=alt.Y('CPU(J):Q', axis=alt.Axis(title='CPU energy (J)')),
# row=alt.Column('name:N', header=alt.Header(orient='top', labelFontSize=20)),
color=alt.Color('name:N'),
x=alt.X('relevant_logs_addition:Q', axis=alt.Axis(title=None))
).properties(
title=f'CPU Energy Consumption'
)

chart
# Out:
# alt.Chart(...)

# %%
chart = alt.Chart(final_df_with_action).mark_bar().encode(
y=alt.Y('cpu_integral:Q', axis=alt.Axis(title='CPU Integral')),
row=alt.Column('name:N', header=alt.Header(orient='top', labelFontSize=20)),
color=alt.Color('relevant_logs_addition:Q'),
x=alt.X('measurement:N', axis=alt.Axis(title=None))
).properties(
title=f'CPU Integral'
)

chart
# with alt.data_transformers.enable('default'):
#     chart.save(f'{measurement_path}/graph/cpu_integral.png', engine="altair_saver")
# chart.save(f'{measurement_path}/graphs/cpu_integral.html', embed_options={'renderer':'svg'})
# Out:
# alt.Chart(...)

# %%
results = []
for rule in final_df['name'].unique():
    rule_logtypes = [f"{logtype[0].lower().replace('*', '')}_{logtype[1]}" for logtype in section_logtypes[rule]]
    rule_logtypes = [x.replace('\"', '') for x in rule_logtypes]
    try:
        tmp = final_df_with_action[final_df_with_action['name']==rule][rule_logtypes]
    except:
        tmp = pd.DataFrame()
    results.append(tmp)
logtypes_df = pd.concat(results, axis=1).sort_index()

logtypes_final_df = pd.merge(final_df, logtypes_df, left_index=True, right_index=True)

# %%
logtypes_final_df['added_logs'] = logtypes_final_df.drop(columns=['name','cpu_integral','measurement']).sum(axis=1).astype(np.float64)
logtypes_final_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 logtypes_final_df['added_logs'] = logtypes_final_df.drop(columns=['name','cpu_integral','measurement']).sum(axis=1).astype(np.float64)
#       2 logtypes_final_df
#
# File ~/anaconda3/envs/py38/lib/python3.8/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/py38/lib/python3.8/site-packages/pandas/core/frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
#    5260     errors: IgnoreRaise = "raise",
#    5261 ) -> DataFrame | None:
#    5262     """
#    5263     Drop specified labels from rows or columns.
#    5264
#    (...)
#    5397             weight  1.0     0.8
#    5398     """
# -> 5399     return super().drop(
#    5400         labels=labels,
#    5401         axis=axis,
#    5402         index=index,
#    5403         columns=columns,
#    5404         level=level,
#    5405         inplace=inplace,
#    5406         errors=errors,
#    5407     )
#
# File ~/anaconda3/envs/py38/lib/python3.8/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/py38/lib/python3.8/site-packages/pandas/core/generic.py:4505, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503 for axis, labels in axes.items():
#    4504     if labels is not None:
# -> 4505         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4507 if inplace:
#    4508     self._update_inplace(obj)
#
# File ~/anaconda3/envs/py38/lib/python3.8/site-packages/pandas/core/generic.py:4546, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4544         new_axis = axis.drop(labels, level=level, errors=errors)
#    4545     else:
# -> 4546         new_axis = axis.drop(labels, errors=errors)
#    4547     indexer = axis.get_indexer(new_axis)
#    4549 # Case for non-unique axis
#    4550 else:
#
# File ~/anaconda3/envs/py38/lib/python3.8/site-packages/pandas/core/indexes/base.py:6934, in Index.drop(self, labels, errors)
#    6932 if mask.any():
#    6933     if errors != "ignore":
# -> 6934         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6935     indexer = indexer[~mask]
#    6936 return self.delete(indexer)
#
# KeyError: "['cpu_integral'] not found in axis"

# %%
chart = alt.Chart(logtypes_final_df).mark_point().encode(
y=alt.Y('cpu_integral:Q', axis=alt.Axis(title='CPU Integral')),
row=alt.Column('name:N', header=alt.Header(orient='top', labelFontSize=20)),
x=alt.X('added_logs:Q', axis=alt.Axis(title=None))
).properties(
title=f'CPU Integral'
)
chart
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/anaconda3/envs/py38/lib/python3.8/site-packages/altair/vegalite/v5/api.py:2513, in Chart.to_dict(self, *args, **kwargs)
#    2511     copy.data = core.InlineData(values=[{}])
#    2512     return super(Chart, copy).to_dict(*args, **kwargs)
# -> 2513 return super().to_dict(*args, **kwargs)
#
# File ~/anaconda3/envs/py38/lib/python3.8/site-packages/altair/vegalite/v5/api.py:831, in TopLevelMixin.to_dict(self, *args, **kwargs)
#     829 copy = self.copy(deep=False)  # type: ignore[attr-defined]
#     830 original_data = getattr(copy, "data", Undefined)
# --> 831 copy.data = _prepare_data(original_data, context)
#     833 if original_data is not Undefined:
#     834     context["data"] = original_data
#
# File ~/anaconda3/envs/py38/lib/python3.8/site-packages/altair/vegalite/v5/api.py:100, in _prepare_data(data, context)
#      98 # convert dataframes  or objects with __geo_interface__ to dict
#      99 elif isinstance(data, pd.DataFrame) or hasattr(data, "__geo_interface__"):
# --> 100     data = _pipe(data, data_transformers.get())
#     102 # convert string input to a URLData
#     103 elif isinstance(data, str):
#
# File ~/anaconda3/envs/py38/lib/python3.8/site-packages/toolz/functoolz.py:628, in pipe(data, *funcs)
#     608 """ Pipe a value through a sequence of functions
#     609
#     610 I.e. ``pipe(data, f, g, h)`` is equivalent to ``h(g(f(data)))``
#    (...)
#     625     thread_last
#     626 """
#     627 for func in funcs:
# --> 628     data = func(data)
#     629 return data
#
# File ~/anaconda3/envs/py38/lib/python3.8/site-packages/toolz/functoolz.py:304, in curry.__call__(self, *args, **kwargs)
#     302 def __call__(self, *args, **kwargs):
#     303     try:
# --> 304         return self._partial(*args, **kwargs)
#     305     except TypeError as exc:
#     306         if self._should_curry(args, kwargs, exc):
#
# File ~/anaconda3/envs/py38/lib/python3.8/site-packages/altair/vegalite/data.py:19, in default_data_transformer(data, max_rows)
#      17 @curried.curry
#      18 def default_data_transformer(data, max_rows=5000):
# ---> 19     return curried.pipe(data, limit_rows(max_rows=max_rows), to_values)
#
# File ~/anaconda3/envs/py38/lib/python3.8/site-packages/toolz/functoolz.py:628, in pipe(data, *funcs)
#     608 """ Pipe a value through a sequence of functions
#     609
#     610 I.e. ``pipe(data, f, g, h)`` is equivalent to ``h(g(f(data)))``
#    (...)
#     625     thread_last
#     626 """
#     627 for func in funcs:
# --> 628     data = func(data)
#     629 return data
#
# File ~/anaconda3/envs/py38/lib/python3.8/site-packages/toolz/functoolz.py:304, in curry.__call__(self, *args, **kwargs)
#     302 def __call__(self, *args, **kwargs):
#     303     try:
# --> 304         return self._partial(*args, **kwargs)
#     305     except TypeError as exc:
#     306         if self._should_curry(args, kwargs, exc):
#
# File ~/anaconda3/envs/py38/lib/python3.8/site-packages/altair/utils/data.py:160, in to_values(data)
#     158     return {"values": data}
#     159 elif isinstance(data, pd.DataFrame):
# --> 160     data = sanitize_dataframe(data)
#     161     return {"values": data.to_dict(orient="records")}
#     162 elif isinstance(data, dict):
#
# File ~/anaconda3/envs/py38/lib/python3.8/site-packages/altair/utils/core.py:390, in sanitize_dataframe(df)
#     386 elif np.issubdtype(dtype, np.floating):
#     387     # For floats, convert to Python float: np.float is not JSON serializable
#     388     # Also convert NaN/inf values to null, as they are not JSON serializable
#     389     col = df[col_name]
# --> 390     bad_values = col.isnull() | np.isinf(col)
#     391     df[col_name] = col.astype(object).where(~bad_values, None)
#     392 elif dtype == object:
#     393     # Convert numpy arrays saved as objects to lists
#     394     # Arrays are not JSON serializable
#
# File ~/anaconda3/envs/py38/lib/python3.8/site-packages/pandas/core/generic.py:2113, in NDFrame.__array_ufunc__(self, ufunc, method, *inputs, **kwargs)
#    2109 @final
#    2110 def __array_ufunc__(
#    2111     self, ufunc: np.ufunc, method: str, *inputs: Any, **kwargs: Any
#    2112 ):
# -> 2113     return arraylike.array_ufunc(self, ufunc, method, *inputs, **kwargs)
#
# File ~/anaconda3/envs/py38/lib/python3.8/site-packages/pandas/core/arraylike.py:410, in array_ufunc(self, ufunc, method, *inputs, **kwargs)
#     405 if method == "__call__" and not kwargs:
#     406     # for np.<ufunc>(..) calls
#     407     # kwargs cannot necessarily be handled block-by-block, so only
#     408     # take this path if there are no kwargs
#     409     mgr = inputs[0]._mgr
# --> 410     result = mgr.apply(getattr(ufunc, method))
#     411 else:
#     412     # otherwise specific ufunc methods (eg np.<ufunc>.accumulate(..))
#     413     # Those can have an axis keyword and thus can't be called block-by-block
#     414     result = default_array_ufunc(inputs[0], ufunc, method, *inputs, **kwargs)
#
# File ~/anaconda3/envs/py38/lib/python3.8/site-packages/pandas/core/internals/managers.py:350, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     348 try:
#     349     if callable(f):
# --> 350         applied = b.apply(f, **kwargs)
#     351     else:
#     352         applied = getattr(b, f)(**kwargs)
#
# File ~/anaconda3/envs/py38/lib/python3.8/site-packages/pandas/core/internals/blocks.py:351, in Block.apply(self, func, **kwargs)
#     345 @final
#     346 def apply(self, func, **kwargs) -> list[Block]:
#     347     """
#     348     apply the function to my values; return a block if we are not
#     349     one
#     350     """
# --> 351     result = func(self.values, **kwargs)
#     353     return self._split_op_result(result)
#
# TypeError: ufunc 'isinf' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# alt.Chart(...)

# %%
# load alert status
# load current distribution
alert_status_list = []
current_distribution_list = []
for measurement_dir in measurement_dirs:
    measurement_path = os.path.join(path, measurement_dir)
    alert_status_path = os.path.join(measurement_path, 'alerts_status.json')
    current_distribution_path = os.path.join(measurement_path, 'current_distribution.json')
    with open(alert_status_path, 'r') as f:
        alert_status = json.load(f)['results']
    with open(current_distribution_path, 'r') as f:
        current_distribution = json.load(f)
    alert_status_list.append(alert_status)
    current_distribution_list.append(current_distribution)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Define figure and axes
fig, ax = plt.subplots()
amount = 50

# Plot second dataframe on the same axis
df2 = pd.DataFrame(index=current_distribution_list[1].keys(), data=current_distribution_list[1].values(), columns=['Current Distribution'])
df2.index = df2.index.str.lower()
df2 = df2.reset_index().groupby('index').sum()
df2.drop(index='total_count').sort_values(by='Current Distribution', ascending=False).head(amount).plot(kind='bar', ax=ax, color='r', label='Current Distribution', alpha=0.5)

# Plot first dataframe on the defined axis
df1 = pd.DataFrame(index=current_distribution_list[0].keys(), data=current_distribution_list[0].values(), columns=['Wanted Distribution'])
df1.index = df1.index.str.lower()
df1 = df1.reset_index().groupby('index').sum()
df1.drop(index='total_count').sort_values(by='Wanted Distribution', ascending=False).head(amount).plot(kind='bar', ax=ax, color='b', label='Wanted Distribution', alpha=0.5)


# Add title and legend
plt.title('Wanted vs Current Log Types Distribution')
plt.legend()

# If needed, rotate x-axis ticks
ax.tick_params(axis='x', which='both', labelsize=5)

plt.show()

# %%
diff = (df2['Current Distribution']-df1['Wanted Distribution']).drop(index='total_count').sort_values(ascending=False)
diff[diff>0].head(amount).plot(kind='bar', figsize=(20, 10), title='Difference between current distribution and wanted distribution')
# Out:
# <Axes: title={'center': 'Difference between current distribution and wanted distribution'}, xlabel='index'>

# %%
pd.DataFrame(alert_status_list[0]).groupby('savedsearch_name').count()
# Out:
#                            sid  count
# savedsearch_name
# An Account Was Logged off  100    100

# %%
rules_enegry_df[rules_enegry_df['name'] == 'An Account Was Logged off']
# Out:
#        Unnamed: 0                  Time(sec)   PID    PNAME  CPU(%)  \
# 10587       10587 2023-07-27 21:19:01.808572  3128  splunkd   19.10
# 10593       10593 2023-07-27 21:19:02.156383  3128  splunkd   22.98
# 10599       10599 2023-07-27 21:19:02.394416  3128  splunkd    0.00
# 10605       10605 2023-07-27 21:19:02.708890  3128  splunkd    0.00
# 10611       10611 2023-07-27 21:19:03.052606  3128  splunkd    0.00
# ...           ...                        ...   ...      ...     ...
# 15093       15093 2023-07-27 21:23:58.186701  3128  splunkd    0.00
# 15099       15099 2023-07-27 21:23:58.599016  3128  splunkd    0.00
# 15105       15105 2023-07-27 21:23:59.000894  3128  splunkd    0.00
# 15111       15111 2023-07-27 21:23:59.397442  3128  splunkd    0.00
# 15117       15117 2023-07-27 21:23:59.877248  3128  splunkd    0.00
#
#        NUM THREADS  MEMORY(MB)  MEMORY(%)  READ_IO(#)  WRITE_IO(#)  \
# 10587           10      85.816       0.54           0            0
# 10593            7      97.625       0.61         702          656
# 10599            7      97.625       0.61           0            0
# 10605            7      97.625       0.61           1            0
# 10611            7      97.625       0.61           0            0
# ...            ...         ...        ...         ...          ...
# 15093            8     133.996       0.84           1            1
# 15099            8     133.996       0.84           0            0
# 15105            8     133.996       0.84           0            0
# 15111            8     133.996       0.84           0            0
# 15117            8     133.996       0.84           0            0
#
#        READ_IO(KB)  WRITE_IO(KB)  PAGE_FAULTS                       name  \
# 10587          0.0           0.0         3864  An Account Was Logged off
# 10593          0.0         428.0         6118  An Account Was Logged off
# 10599          0.0           0.0            0  An Account Was Logged off
# 10605          0.0           0.0            0  An Account Was Logged off
# 10611          0.0           0.0            0  An Account Was Logged off
# ...            ...           ...          ...                        ...
# 15093          0.0           0.0            0  An Account Was Logged off
# 15099          0.0           0.0            0  An Account Was Logged off
# 15105          0.0           0.0            0  An Account Was Logged off
# 15111          0.0           0.0            0  An Account Was Logged off
# 15117          0.0           0.0            0  An Account Was Logged off
#
#                                                      sid   pid  \
# 10587  scheduler__shouei__search__RMD5d3ffad2ce4319cc...  3128
# 10593  scheduler__shouei__search__RMD5d3ffad2ce4319cc...  3128
# 10599  scheduler__shouei__search__RMD5d3ffad2ce4319cc...  3128
# 10605  scheduler__shouei__search__RMD5d3ffad2ce4319cc...  3128
# 10611  scheduler__shouei__search__RMD5d3ffad2ce4319cc...  3128
# ...                                                  ...   ...
# 15093  scheduler__shouei__search__RMD5d3ffad2ce4319cc...  3128
# 15099  scheduler__shouei__search__RMD5d3ffad2ce4319cc...  3128
# 15105  scheduler__shouei__search__RMD5d3ffad2ce4319cc...  3128
# 15111  scheduler__shouei__search__RMD5d3ffad2ce4319cc...  3128
# 15117  scheduler__shouei__search__RMD5d3ffad2ce4319cc...  3128
#
#                                    time  run_duration  delta_time
# 10587  2023-07-28 00:20:31.483000+03:00         3.012    0.000000
# 10593  2023-07-28 00:20:31.483000+03:00         3.012    0.347811
# 10599  2023-07-28 00:20:31.483000+03:00         3.012    0.585844
# 10605  2023-07-28 00:20:31.483000+03:00         3.012    0.900318
# 10611  2023-07-28 00:20:31.483000+03:00         3.012    1.244034
# ...                                 ...           ...         ...
# 15093  2023-07-28 00:20:31.483000+03:00         3.012  296.378129
# 15099  2023-07-28 00:20:31.483000+03:00         3.012  296.790444
# 15105  2023-07-28 00:20:31.483000+03:00         3.012  297.192322
# 15111  2023-07-28 00:20:31.483000+03:00         3.012  297.588870
# 15117  2023-07-28 00:20:31.483000+03:00         3.012  298.068676
#
# [756 rows x 19 columns]

# %%
charts[1]
# Out:
# alt.Chart(...)

# %% [markdown]
# Merge when the rules running one after an other with a delay

# %% [markdown]
# Merge when all the rules running in the same time

# %%
relevant_processes_pid_names_grouped_dict = {}
relevant_processes_pid_names_mean_windows_dict = {}
relevant_names_inegral_dict = {}
path = '/home/shouei/GreenSecurity-FirstExperiment/VMware, Inc. Linux 3.10.0-1160.88.1.el7.x86_64/Splunk Enterprise SIEM/Power Saver Plan/One Scan'

# path = fr"../../Repositories/GreenSecurity-FirstExperiment/Dell Inc. Linux 5.15.0-70-generic/Splunk Enterprise SIEM/Power Saver Plan/One Scan/"
for measurment_name in measurement_dirs:
    pid_1_times = set(exp_dfs[measurment_name].groupby('pid').count().dropna().index)
    name_1_times = exp_dfs[measurment_name].where(lambda x: x.pid.isin(pid_1_times))[['name','pid']]
    relevant_processes = dfs[measurment_name].where(lambda x: x.PID.isin(pid_1_times))
    relevant_processes_pid_names = pd.merge(relevant_processes, name_1_times, left_on='PID', right_on='pid')
    
    # Get start time
    start_time = relevant_processes_pid_names['Time(sec)'].min()
    # Calculate delta time in seconds
    relevant_processes_pid_names['delta_time'] = (relevant_processes_pid_names['Time(sec)'] - start_time).dt.total_seconds()
    print(len(relevant_processes_pid_names)/relevant_processes_pid_names['delta_time'].max())
    #####Create a chart########
    # Create the dropdown menu selection
    name_selection = alt.selection_multi(fields=['name'], bind='legend')
    # Define the chart
    chart = alt.Chart(relevant_processes_pid_names).mark_line(interpolate='linear').encode(
            alt.Y("CPU(%):Q"),
            alt.X(f"delta_time:Q"),
            alt.Color('name:N', scale=alt.Scale(scheme='category20')),
            opacity=alt.condition(name_selection, alt.value(1), alt.value(0.1))
        ).properties(
            width=1500,
            height=500
        ).add_selection(name_selection).configure_legend(
            orient='bottom',
            labelLimit=10000,
            columns=4,
            labelFontSize=15
        )
    with alt.data_transformers.enable('default'):
        chart.save(f"{path}/{measurment_name}/graphs/interactive_line.html")
    ##########################
    
    #####Create a chart########
    rule_chart = alt.Chart(relevant_processes_pid_names).mark_rule(strokeDash=[5, 5]).encode(
    x='min(Time(sec)):T',color='name'
    )

    c2 = alt.Chart(relevant_processes_pid_names).mark_line(interpolate='linear').encode(
            alt.Y("CPU(%):Q"),
            alt.X(f"Time(sec):T"),
        ).properties(
            width=1000,
            height=500
        )
    mean_chart = alt.Chart(relevant_processes_pid_names).mark_rule(color='red', strokeDash=[5, 5]).encode(
        y='mean(CPU(%)):Q'
    )

    chart2 = (c2+rule_chart+mean_chart).configure_legend(
                labelLimit=10000,
                labelFontSize=15
            )
    with alt.data_transformers.enable('default'):
        chart2.save(f"{path}/{measurment_name}/graphs/total_cpu.html")
    ##########################
    
    relevant_processes_pid_names_grouped = relevant_processes_pid_names.groupby('name').mean()
    relevant_processes_pid_names_grouped_dict[measurment_name] = relevant_processes_pid_names_grouped
    #integral by name of cpu over time
    relevant_names_inegral_dict[measurment_name] = relevant_processes_pid_names.groupby('name').apply(lambda g: integrate.trapz(g['CPU(%)'], x=g['delta_time']))

    
    # # Define the time window size in minutes
    # time_window_size = 1
    # last_sec = int(np.ceil(relevant_processes_pid_names['delta_time'].max()))
    # # Create an empty column to store the mean values
    # relevant_processes_pid_names['mean_col'] = pd.Series()
    # relevant_processes_pid_names['time_window'] = pd.Series()

    # # Iterate over the time series data, and calculate the mean for each time window
    # for i in range(last_sec):
    #     start_time = i
    #     end_time = start_time + time_window_size
    #     window_data = relevant_processes_pid_names[(relevant_processes_pid_names['delta_time'] >= start_time) & (relevant_processes_pid_names['delta_time'] < end_time)]
    #     mean_values = window_data.groupby('name')['CPU(%)'].mean()
    #     for name in mean_values.index:
    #         relevant_processes_pid_names.loc[window_data[window_data['name']==name].index, 'mean_col'] = mean_values[mean_values.index==name][0]
    #         relevant_processes_pid_names.loc[window_data[window_data['name']==name].index, 'time_window'] = i
    
    relevant_processes_pid_names_mean_windows_dict[measurment_name] = relevant_processes_pid_names
# Out:
# 0.5359004292260336
# /home/shouei/anaconda3/envs/py38/lib/python3.8/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'selection_multi' is deprecated.  Use 'selection_point'
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# /home/shouei/anaconda3/envs/py38/lib/python3.8/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'add_selection' is deprecated. Use 'add_params' instead.
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# /tmp/ipykernel_27109/1033965186.py:64: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   relevant_processes_pid_names_grouped = relevant_processes_pid_names.groupby('name').mean()
# /home/shouei/anaconda3/envs/py38/lib/python3.8/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'selection_multi' is deprecated.  Use 'selection_point'
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# /home/shouei/anaconda3/envs/py38/lib/python3.8/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'add_selection' is deprecated. Use 'add_params' instead.
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# 1.21280086132766
# /tmp/ipykernel_27109/1033965186.py:64: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   relevant_processes_pid_names_grouped = relevant_processes_pid_names.groupby('name').mean()
# /home/shouei/anaconda3/envs/py38/lib/python3.8/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'selection_multi' is deprecated.  Use 'selection_point'
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# /home/shouei/anaconda3/envs/py38/lib/python3.8/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'add_selection' is deprecated. Use 'add_params' instead.
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# 2.285388620921543
# /tmp/ipykernel_27109/1033965186.py:64: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   relevant_processes_pid_names_grouped = relevant_processes_pid_names.groupby('name').mean()
# /home/shouei/anaconda3/envs/py38/lib/python3.8/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'selection_multi' is deprecated.  Use 'selection_point'
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# /home/shouei/anaconda3/envs/py38/lib/python3.8/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'add_selection' is deprecated. Use 'add_params' instead.
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# 4.056956413913548
# /tmp/ipykernel_27109/1033965186.py:64: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   relevant_processes_pid_names_grouped = relevant_processes_pid_names.groupby('name').mean()
# /home/shouei/anaconda3/envs/py38/lib/python3.8/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'selection_multi' is deprecated.  Use 'selection_point'
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# /home/shouei/anaconda3/envs/py38/lib/python3.8/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'add_selection' is deprecated. Use 'add_params' instead.
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# 3.339743747407611
# /tmp/ipykernel_27109/1033965186.py:64: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   relevant_processes_pid_names_grouped = relevant_processes_pid_names.groupby('name').mean()
# /home/shouei/anaconda3/envs/py38/lib/python3.8/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'selection_multi' is deprecated.  Use 'selection_point'
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# /home/shouei/anaconda3/envs/py38/lib/python3.8/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'add_selection' is deprecated. Use 'add_params' instead.
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# 5.089862516146461
# /tmp/ipykernel_27109/1033965186.py:64: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   relevant_processes_pid_names_grouped = relevant_processes_pid_names.groupby('name').mean()
# /home/shouei/anaconda3/envs/py38/lib/python3.8/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'selection_multi' is deprecated.  Use 'selection_point'
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# /home/shouei/anaconda3/envs/py38/lib/python3.8/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'add_selection' is deprecated. Use 'add_params' instead.
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# 0.39431788230838805
# /tmp/ipykernel_27109/1033965186.py:64: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   relevant_processes_pid_names_grouped = relevant_processes_pid_names.groupby('name').mean()
# /home/shouei/anaconda3/envs/py38/lib/python3.8/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'selection_multi' is deprecated.  Use 'selection_point'
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# /home/shouei/anaconda3/envs/py38/lib/python3.8/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'add_selection' is deprecated. Use 'add_params' instead.
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# 1.1417154205510107
# /tmp/ipykernel_27109/1033965186.py:64: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   relevant_processes_pid_names_grouped = relevant_processes_pid_names.groupby('name').mean()
# /home/shouei/anaconda3/envs/py38/lib/python3.8/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'selection_multi' is deprecated.  Use 'selection_point'
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# /home/shouei/anaconda3/envs/py38/lib/python3.8/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'add_selection' is deprecated. Use 'add_params' instead.
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# 2.6193778406982773
# /tmp/ipykernel_27109/1033965186.py:64: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   relevant_processes_pid_names_grouped = relevant_processes_pid_names.groupby('name').mean()
# /home/shouei/anaconda3/envs/py38/lib/python3.8/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'selection_multi' is deprecated.  Use 'selection_point'
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# /home/shouei/anaconda3/envs/py38/lib/python3.8/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'add_selection' is deprecated. Use 'add_params' instead.
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# 3.673095300180463
# /tmp/ipykernel_27109/1033965186.py:64: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   relevant_processes_pid_names_grouped = relevant_processes_pid_names.groupby('name').mean()
# /home/shouei/anaconda3/envs/py38/lib/python3.8/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'selection_multi' is deprecated.  Use 'selection_point'
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# /home/shouei/anaconda3/envs/py38/lib/python3.8/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'add_selection' is deprecated. Use 'add_params' instead.
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# 3.6134186917275453
# /tmp/ipykernel_27109/1033965186.py:64: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   relevant_processes_pid_names_grouped = relevant_processes_pid_names.groupby('name').mean()
# /home/shouei/anaconda3/envs/py38/lib/python3.8/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'selection_multi' is deprecated.  Use 'selection_point'
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# /home/shouei/anaconda3/envs/py38/lib/python3.8/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'add_selection' is deprecated. Use 'add_params' instead.
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# 6.348101642474566
# /tmp/ipykernel_27109/1033965186.py:64: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   relevant_processes_pid_names_grouped = relevant_processes_pid_names.groupby('name').mean()

# %%
import itertools


times = ['12', '24', '36', '48', '60', '72']
field_state = ['disable', 'enable']
# num_of_experiments = 6
# create all the permutations of the times and field_state as concatinated strings
durations = [f"{field} {time}" for time, field in itertools.product(field_state, times)]
durations
# Out:
# ['12 disable',
#  '24 disable',
#  '36 disable',
#  '48 disable',
#  '60 disable',
#  '72 disable',
#  '12 enable',
#  '24 enable',
#  '36 enable',
#  '48 enable',
#  '60 enable',
#  '72 enable']

# %%
# pid_df = pd.DataFrame([[k]+s for k, v in pids[curr_measurement].items() for s in v], columns=['name', 'sid', 'pid', 'time', 'run_duration']) 
# pid_df.time = pd.to_datetime(pid_df.time)
# # group by time with 10 minutes interval and take the min value of each group
# pid_df.groupby(pd.Grouper(key='time', freq='10min')).min().index
# # pid_df.groupby('time').min()

# %%
def get_searches_times(pid_dict):
    pid_df = pd.DataFrame([[k]+s[:4] for k, v in pid_dict.items() for s in v], columns=['name', 'sid', 'pid', 'time', 'run_duration'])        
    pid_df.time = pd.to_datetime(pid_df.time)
    # group by time with 10 minutes interval and take the min value of each group
    search_times = pid_df.groupby(pd.Grouper(key='time', freq='10min')).min().index
    return pid_df, search_times

# %%
import subprocess
import datetime
import concurrent.futures
import json
os.makedirs("logs_types_info", exist_ok=True)
if not os.path.exists(f'logs_types_info/logs_len_list_{rng[0]}_{rng[-1]}.json'):
    dirs = {f'Measurement {i}' for i in rng}
    logs_len_list = {}
    j = rng[0]
    last_j = rng[-1]+1
    def run_command(command):
        cmd = subprocess.run(command, shell=True, capture_output=True, text=True)
        output = cmd.stdout
        print(output)
        # Parse the output to get the number.
        # num = int(output.split('\n')[2].strip()) if len(output.split('\n')) > 2 else output
        res_dict = {}
        if len(cmd.stdout.split('\n')) > 2:
            for row in cmd.stdout.split('\n')[2:-1]:
                row = row.split()
                source = row[0]
                event_code = row[1]
                count = row[2]
                total_count = row[3]
                res_dict[f"{source} {event_code}"] = int(count)
            res_dict['total_count'] = int(total_count)
        return res_dict

    with concurrent.futures.ThreadPoolExecutor() as executor:
        future_to_command = {}
        # for state in field_state:
        for time in times:
            curr_measurement = f"Measurement {j}"
            path = fr"./VMware, Inc. Linux 3.10.0-1160.88.1.el7.x86_64/Splunk Enterprise SIEM/Power Saver Plan/One Scan/{curr_measurement}"
            # convert pids values to df
            pid_df, search_times = get_searches_times(pids[curr_measurement])
            end_time = "06/15/2023:08:00:00"
            # end_time = datetime.datetime.strptime(end_time, '%m/%d/%Y:%H:%M:%S')
            start_time = time
            start_time = (datetime.datetime.strptime(end_time, '%m/%d/%Y:%H:%M:%S') - datetime.timedelta(hours=int(start_time.split('h')[0]))).strftime('%m/%d/%Y:%H:%M:%S')
            command = f'echo sH231294| sudo -S -E env "PATH=$PATH" splunk search "index=main (earliest="{start_time}" latest="{end_time}")|stats count by source EventCode | eventstats sum(count) as totalCount" -maxout 0 -auth shouei:sH231294'
            print(command)
            future_to_command[executor.submit(run_command, command)] = (command, time)   

            j += 1
            if j == last_j:                
                break
        for future in concurrent.futures.as_completed(future_to_command):
            command, time = future_to_command[future]
            try:
                data = future.result()
            except Exception as exc:
                print(f'{command} generated an exception: {exc}')
            else:
                logs_len_list[time] = data
    # save the logs_len_list to a json file
    with open(f'logs_types_info/logs_len_list_{rng[0]}_{rng[-1]}.json', 'w') as f:
        json.dump(logs_len_list, f)
else: 
    # load the logs_len_list from a json file
    with open(f'logs_len_list_{rng[0]}_{rng[-1]}.json', 'r') as f:
        logs_len_list = json.load(f)

# %%
# Out:
# Log entry successfully sent to Splunk.
# /home/shouei/anaconda3/envs/py38/lib/python3.8/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '132.72.81.150'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
# # give permissions to the logs.csv file in measurement 48
# path = fr"./VMware, Inc. Linux 3.10.0-1160.88.1.el7.x86_64/Splunk Enterprise SIEM/Power Saver Plan/One Scan/Measurement 48"
# command = f'echo sH231294| sudo -S -E env "PATH=$PATH" chmod 777 "{path}/logs.csv"'
# subprocess.run(command, shell=True)

# %%
import pytz


dirs = {f'Measurement {i}'for i in rng}
integral_list = []
j = rng[0]
i = 0
for state in field_state:
    for time in times:
        # for i in range(num_of_experiments):
        curr_measurement = f"Measurement {j}"
        path = fr"./VMware, Inc. Linux 3.10.0-1160.88.1.el7.x86_64/Splunk Enterprise SIEM/Power Saver Plan/One Scan/{curr_measurement}"
        pid_df, search_times = get_searches_times(pids[curr_measurement])
        g_pid_df = pid_df.groupby(['name', pd.Grouper(key='time', freq='10min')]).min().reset_index()
        for rule_name, val in pids[curr_measurement].items():
            curr_df = relevant_processes_pid_names_mean_windows_dict[curr_measurement]
            curr_df = curr_df[(curr_df['name']==rule_name)]
            if curr_df.empty:
                print(curr_measurement, rule_name)
                continue
            curr_df.loc[:, 'Time(sec)'] = curr_df['Time(sec)'].dt.to_pydatetime()
            curr_df.loc[:, 'Time(sec)'] = curr_df['Time(sec)'].dt.tz_localize('UTC')
            # define the first time of the world
            # date_time = datetime.datetime.fromtimestamp(0, tz=datetime.timezone.utc)
            # s_times = g_pid_df[g_pid_df.name==rule_name].dropna()[['time', 'pid']]
            for v in val:
                # print(j, i)
                # convert v[3] (str date) to datetime in utc
                date_time = datetime.datetime.strptime(v[4], '%Y-%m-%d %H:%M:%S')
                jerusalem = pytz.timezone('Asia/Jerusalem')
                date_time = jerusalem.localize(date_time)
                date_time = date_time.astimezone(pytz.UTC)
                # date_time = datetime.datetime.strptime(v[2], '%Y-%m-%d %H:%M:%S.%f IDT')
                
                # date_time = date_time.replace(hour=date_time.hour-3)
                
                # target_timezone = pytz.timezone('UTC')
                # date_time = date_time.astimezone(target_timezone)
                duration = datetime.timedelta(seconds=v[3])
                name_integral = {}
                pid = v[1]
                # s_time = s_times[s_times.pid==pid].time.values[0]
                df_section = curr_df[(curr_df['pid']==pid)]

                df_section = df_section[(df_section['Time(sec)']>date_time)&(df_section['Time(sec)']<=date_time+duration)]
                if df_section.empty:
                    print(curr_measurement, rule_name, v)
                    continue
                bug = df_section[df_section['WRITE_IO(KB)']<0]
                df_section = df_section.drop(bug.index)
                # if not bug.empty:
                #     print(df_section)
                #     df_section = df_section.loc[:bug.index[0]-1]
                #     print(df_section)
                # df_section['delta_diff'] = df_section['delta_time'].diff()
                # df_section.drop(df_section[df_section['delta_diff']>10].index, inplace=True)
                # df_section = curr_df[(curr_df['Time(sec)']>date_time)]
                # min_date_time = df_section['Time(sec)'].min()
                # df_section = df_section[(df_section['Time(sec)']<=min_date_time+duration)]
                integral_cpu= integrate.simpson(df_section['CPU(%)'], x=df_section['delta_time'])
                disk_w_q= df_section['WRITE_IO(#)'].sum()
                disk_r_q= df_section['READ_IO(#)'].sum()
                disk_w_k= df_section['WRITE_IO(KB)'].sum()
                disk_r_k= df_section['READ_IO(KB)'].sum()
                # integral_disk_w_q= integrate.simpson(df_section['WRITE_IO(#)'], x=df_section['delta_time'])
                # integral_disk_r_q= integrate.simpson(df_section['READ_IO(#)'], x=df_section['delta_time'])
                # integral_disk_w_k= integrate.simpson(df_section['WRITE_IO(KB)'], x=df_section['delta_time'])
                # integral_disk_r_k= integrate.simpson(df_section['READ_IO(KB)'], x=df_section['delta_time'])
                # name_integral[name] = (integral, logs_len_list[i])
                integral_list.append((integral_cpu,disk_w_q,disk_r_q,disk_w_k,disk_r_k, logs_len_list[time]['total_count'], v[3], time, curr_measurement, state, rule_name, pid))
                # date_time = df_section['Time(sec)'].max()
                i += 1
                # print(min_date_time, duration, date_time)
        j += 1

# %%
# list comprehnsion to get the amount of searches
[len([x for v in pids[f'Measurement {i}'].values() for x in v]) for i in rng]

# [x  for x in v for r,v in pids[m].items()  for m in measurement_dirs]
# Out:
# [318, 290, 270, 309, 227, 234, 217, 264, 302, 283, 263, 317]

# %%
df = pd.DataFrame(integral_list, columns=['integral_cpu','disk_w_q','disk_r_q','disk_w_k','disk_r_k','logs_number', 'duration', 'time_range', 'measurment_num', 'state', 'rule_name','pid'])
df = df[df['logs_number'] != '']
# df['normalized_integral'] = df['integral']/df['logs_number']
df
# Out:
#       integral_cpu  disk_w_q  disk_r_q  disk_w_k  disk_r_k  logs_number  \
# 0        12.572504       354       628      80.0       0.0        70872
# 1        26.971412       355       457      80.0       0.0        70872
# 2         9.068992       293       228      72.0       0.0        70872
# 3        20.843032       354       390      80.0       0.0        70872
# 4        13.607788       355       679      80.0       0.0        70872
# ...            ...       ...       ...       ...       ...          ...
# 3273   3795.762498      1058     51688    2900.0       8.0      1204791
# 3274   3854.057007      1065     51690    2944.0       0.0      1204791
# 3275   4000.983685       842     51357    2860.0       0.0      1204791
# 3276   4063.221131      1060     51687    2920.0      44.0      1204791
# 3277   4173.573858      1131     51766    2996.0      24.0      1204791
#
#       duration time_range   measurment_num    state  \
# 0        1.769         12  Measurement 133  disable
# 1        1.951         12  Measurement 133  disable
# 2        1.999         12  Measurement 133  disable
# 3        1.816         12  Measurement 133  disable
# 4        2.005         12  Measurement 133  disable
# ...        ...        ...              ...      ...
# 3273   175.280         72  Measurement 144   enable
# 3274   178.582         72  Measurement 144   enable
# 3275   177.376         72  Measurement 144   enable
# 3276   176.013         72  Measurement 144   enable
# 3277   180.530         72  Measurement 144   enable
#
#                                     rule_name    pid
# 0         Monitor for Suspicious Network IP’s  29061
# 1         Monitor for Suspicious Network IP’s  14409
# 2         Monitor for Suspicious Network IP’s  31740
# 3         Monitor for Suspicious Network IP’s  16671
# 4         Monitor for Suspicious Network IP’s  23787
# ...                                       ...    ...
# 3273  Monitor for Additions to Firewall Rules  32455
# 3274  Monitor for Additions to Firewall Rules  15719
# 3275  Monitor for Additions to Firewall Rules  31759
# 3276  Monitor for Additions to Firewall Rules  16466
# 3277  Monitor for Additions to Firewall Rules   1201
#
# [3278 rows x 12 columns]

# %%
logs_len_dfs = []
for k in logs_len_list:
    source_event_df = pd.DataFrame.from_dict(logs_len_list[k],orient='index', columns=['count']).iloc[:-1]
    source_event_df = source_event_df.reset_index().rename({'index':'source_event'}, axis=1)
    source_event_df[['source','event_code']] = pd.DataFrame(source_event_df['source_event'].apply(lambda x: x.split()).tolist())
    # delete the the lines that are not numbers
    source_event_df = source_event_df[source_event_df['event_code'].str.isnumeric()]
    source_event_df['event_code'] = source_event_df['event_code'].astype(int)
    source_event_df[['source_type','log_name']] = pd.DataFrame(source_event_df['source'].apply(lambda x: x.split(':')).tolist())
    source_event_df['time_range'] = k
    logs_len_dfs.append(source_event_df)
logs_len_df = pd.concat(logs_len_dfs)

# %%
source_event_df['event_code']
# Out:
# 0          0
# 1          1
# 2       1000
# 3      10000
# 4      10001
#        ...
# 247        3
# 248        4
# 249        5
# 250        6
# 251        8
# Name: event_code, Length: 248, dtype: int64

# %%
alt.Chart(logs_len_df).mark_line().encode(
    alt.X('time_range:N'),
    alt.Y('mean(count):Q'),
    alt.Color('log_name:N', scale=alt.Scale(scheme='category10')),
).properties(
    width=600,
    height=300
)
# Out:
# alt.Chart(...)

# %%
logs_len_df
# Out:
#                                           source_event  count  \
# 0                            WinEventLog:Application 0   1927
# 1                            WinEventLog:Application 1   1113
# 2                         WinEventLog:Application 1000     39
# 3                        WinEventLog:Application 10000    550
# 4                        WinEventLog:Application 10001    231
# ..                                                 ...    ...
# 247  XmlWinEventLog:Microsoft-Windows-Sysmon/Operat...  25983
# 248  XmlWinEventLog:Microsoft-Windows-Sysmon/Operat...      8
# 249  XmlWinEventLog:Microsoft-Windows-Sysmon/Operat...   3439
# 250  XmlWinEventLog:Microsoft-Windows-Sysmon/Operat...     63
# 251  XmlWinEventLog:Microsoft-Windows-Sysmon/Operat...   4199
#
#                                                 source  event_code  \
# 0                              WinEventLog:Application           0
# 1                              WinEventLog:Application           1
# 2                              WinEventLog:Application        1000
# 3                              WinEventLog:Application       10000
# 4                              WinEventLog:Application       10001
# ..                                                 ...         ...
# 247  XmlWinEventLog:Microsoft-Windows-Sysmon/Operat...           3
# 248  XmlWinEventLog:Microsoft-Windows-Sysmon/Operat...           4
# 249  XmlWinEventLog:Microsoft-Windows-Sysmon/Operat...           5
# 250  XmlWinEventLog:Microsoft-Windows-Sysmon/Operat...           6
# 251  XmlWinEventLog:Microsoft-Windows-Sysmon/Operat...           8
#
#         source_type                              log_name time_range
# 0       WinEventLog                           Application         48
# 1       WinEventLog                           Application         48
# 2       WinEventLog                           Application         48
# 3       WinEventLog                           Application         48
# 4       WinEventLog                           Application         48
# ..              ...                                   ...        ...
# 247  XmlWinEventLog  Microsoft-Windows-Sysmon/Operational         24
# 248             NaN                                   NaN         24
# 249             NaN                                   NaN         24
# 250             NaN                                   NaN         24
# 251             NaN                                   NaN         24
#
# [1887 rows x 7 columns]

# %%
alt.Chart(logs_len_df[logs_len_df['log_name']=='Microsoft-Windows-Sysmon/Operational']).mark_arc().encode(
    alt.Color('event_code:N', scale=alt.Scale(scheme='category10')),
    alt.Theta('mean(count):Q'),
)
# Out:
# alt.Chart(...)

# %%
sysmon_logs_amount = logs_len_df[logs_len_df['log_name']=='Microsoft-Windows-Sysmon/Operational'].groupby(['time_range','event_code']).sum().reset_index()
sysmon_logs_amount
# Out:
# /tmp/ipykernel_23522/2944168146.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sysmon_logs_amount = logs_len_df[logs_len_df['log_name']=='Microsoft-Windows-Sysmon/Operational'].groupby(['time_range','event_code']).sum().reset_index()
#    time_range  event_code  count
# 0          12           1   5045
# 1          12           2     25
# 2          12           3    870
# 3          12           4      3
# 4          12          11   3546
# ..        ...         ...    ...
# 66         72          16   2615
# 67         72          98    119
# 68         72         255     12
# 69         72        8020     27
# 70         72        8033      6
#
# [71 rows x 3 columns]

# %%
sysmon_logs_amount
# Out:
#    time_range  event_code  count
# 0          12           1   5045
# 1          12           2     25
# 2          12           3    870
# 3          12           4      3
# 4          12          11   3546
# ..        ...         ...    ...
# 66         72          16   2615
# 67         72          98    119
# 68         72         255     12
# 69         72        8020     27
# 70         72        8033      6
#
# [71 rows x 3 columns]

# %%
Detected_Registry_Modification_df = df[df['rule_name']=='Detected Registry Modification']
Detected_Registry_Modification_df = Detected_Registry_Modification_df.merge(sysmon_logs_amount, on='time_range')
Detected_Registry_Modification_df['normalized_integral_cpu'] = Detected_Registry_Modification_df['integral_cpu']/Detected_Registry_Modification_df['count']

# %%
Detected_Registry_Modification_df
# Out:
#       integral_cpu  disk_w_q  disk_r_q  disk_w_k  disk_r_k  logs_number  \
# 0        55.057886       161      7832      84.0       0.0        70872
# 1        55.057886       161      7832      84.0       0.0        70872
# 2        55.057886       161      7832      84.0       0.0        70872
# 3        55.057886       161      7832      84.0       0.0        70872
# 4        55.057886       161      7832      84.0       0.0        70872
# ...            ...       ...       ...       ...       ...          ...
# 1404   3736.499355       859     66293    4000.0       0.0      1204791
# 1405   3736.499355       859     66293    4000.0       0.0      1204791
# 1406   3736.499355       859     66293    4000.0       0.0      1204791
# 1407   3736.499355       859     66293    4000.0       0.0      1204791
# 1408   3736.499355       859     66293    4000.0       0.0      1204791
#
#       duration time_range   measurment_num    state  \
# 0        4.077         12  Measurement 133  disable
# 1        4.077         12  Measurement 133  disable
# 2        4.077         12  Measurement 133  disable
# 3        4.077         12  Measurement 133  disable
# 4        4.077         12  Measurement 133  disable
# ...        ...        ...              ...      ...
# 1404   173.381         72  Measurement 144   enable
# 1405   173.381         72  Measurement 144   enable
# 1406   173.381         72  Measurement 144   enable
# 1407   173.381         72  Measurement 144   enable
# 1408   173.381         72  Measurement 144   enable
#
#                            rule_name    pid  event_code  count  \
# 0     Detected Registry Modification  16772           1   5045
# 1     Detected Registry Modification  16772           2     25
# 2     Detected Registry Modification  16772           3    870
# 3     Detected Registry Modification  16772           4      3
# 4     Detected Registry Modification  16772          11   3546
# ...                              ...    ...         ...    ...
# 1404  Detected Registry Modification  31570          16   2615
# 1405  Detected Registry Modification  31570          98    119
# 1406  Detected Registry Modification  31570         255     12
# 1407  Detected Registry Modification  31570        8020     27
# 1408  Detected Registry Modification  31570        8033      6
#
#       normalized_integral_cpu
# 0                    0.010913
# 1                    2.202315
# 2                    0.063285
# 3                   18.352629
# 4                    0.015527
# ...                       ...
# 1404                 1.428872
# 1405                31.399154
# 1406               311.374946
# 1407               138.388865
# 1408               622.749892
#
# [1409 rows x 15 columns]

# %%
Detected_Registry_Modification_df['normalized_integral_cpu'].describe()
# Out:
# count    1409.000000
# mean       53.854973
# std       120.111778
# min         0.005702
# 25%         0.044199
# 50%         0.738422
# 75%        26.713951
# max       684.534746
# Name: normalized_integral_cpu, dtype: float64

# %%
# show 10 lines of df
pd.set_option('display.max_rows', 50)
df.groupby(['rule_name']).mean().max()
# df.groupby(['rule_name','time_range','state']).count().describe()
# Out:
# /tmp/ipykernel_23522/1114261591.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['rule_name']).mean().max()
# integral_cpu      1867.109740
# disk_w_q          3305.041667
# disk_r_q         30296.758333
# disk_w_k        154128.100000
# disk_r_k            16.840336
# logs_number     643671.312000
# duration            84.352059
# pid              17137.033058
# dtype: float64

# %%
# alt scatters chart of df, shape is time range, x is duration, y is integral, color is rule name and columns is state
alt.Chart(df).mark_circle().encode(
    alt.X('mean(disk_r_k):Q'),
    # alt.X('duration:Q'),
    alt.Y('mean(integral_cpu):Q'),
    alt.Size('mean(duration):Q'),
    alt.Color('rule_name:N', scale=alt.Scale(scheme='category20')),
    # alt.Shape('state:N'),
    alt.Tooltip(['rule_name']),
).properties(
    width=600,
    height=200,
    title='CPU vs Disk KB'
).configure_legend(
    labelLimit=10000,
    labelFontSize=10
)
# Out:
# alt.Chart(...)

# %%
# alt scatters chart of df, shape is time range, x is duration, y is integral, color is rule name and columns is state
alt.Chart(df).mark_circle(size=20).encode(
    alt.X('mean(disk_r_q):Q'),
    # alt.X('duration:Q'),
    alt.Y('mean(integral_cpu):Q'),
    alt.Size('mean(duration):Q'),
    alt.Color('rule_name:N', scale=alt.Scale(scheme='category20')),
    # alt.Shape('state:N'),
    alt.Tooltip(['rule_name']),
).properties(
    width=600,
    height=200,
    title='CPU vs Disk #'
).configure_legend(
    labelLimit=10000,
    labelFontSize=10
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(df).mark_bar().encode(
    alt.Y("sum(disk_r_k):Q", title='Disk read by KB'),
    alt.X(f"time_range:N"),
    # alt.Column('rule_name:N'),
    alt.Color('rule_name:N', scale=alt.Scale(scheme='category20')),
    # column='time_range:N'
).properties(
    width=300,
    height=300,
    title='Disk read by KB'
).configure_legend(
    labelLimit=10000,
    labelFontSize=10
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(df).mark_bar().encode(
    alt.Y("mean(disk_r_q):Q"),
    alt.X(f"time_range:N"),
    # alt.Column('rule_name:N'),
    alt.Color('rule_name:N', scale=alt.Scale(scheme='category20')),
    # column='time_range:N'
).properties(
    width=300,
    height=300,
    title='Disk #'
).configure_legend(
    labelLimit=10000,
    labelFontSize=10
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(df).mark_bar().encode(
    alt.Y("mean(integral_cpu):Q", title='CPU Usage (Integral over time)'),
    alt.X(f"time_range:N"),
    # alt.Column('rule_name:N'),
    alt.Color('rule_name:N', scale=alt.Scale(scheme='category20')),
    # column='time_range:N'
).properties(
    width=300,
    height=300,
    title='CPU Integral'
).configure_legend(
    labelLimit=10000,
    labelFontSize=10
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(df).mark_bar().encode(
    alt.Y("mean(integral):Q"),
    alt.X(f"state:N"),
    alt.Row('rule_name:N'),
    # alt.Color('rule_name:N', scale=alt.Scale(scheme='category20')),
    column='time_range:N'
).properties(
    width=100,
    height=300
).configure_legend(
    labelLimit=10000,
    labelFontSize=10
)
# Out:
# alt.Chart(...)

# %%
# step = 1

# dirs = {f'Measurement {i}'for i in rng}
# for i in rng:
#     if i == step:
#         break
#     first_measurment = f'Measurement {i}'
#     sec_measurment = f'Measurement {i+step}'
#     first_relevant_processes_pid_names = relevant_processes_pid_names_mean_windows_dict[first_measurment]
#     sec_relevant_processes_pid_names = relevant_processes_pid_names_mean_windows_dict[sec_measurment]
    
#     rule_chart_first = alt.Chart(first_relevant_processes_pid_names).mark_rule(strokeDash=[5, 5]).encode(
#         x='min(delta_time):Q',color='name'
#     )

#     c2_first = alt.Chart(first_relevant_processes_pid_names).mark_line(interpolate='linear').encode(
#             alt.Y("CPU(%):Q"),
#             alt.X(f"delta_time:Q"),
#         ).properties(
#             width=1000,
#             height=500
#         )
#     mean_chart_first = alt.Chart(first_relevant_processes_pid_names).mark_rule(color='blue', strokeDash=[5, 5]).encode(
#         y='mean(CPU(%)):Q'
#     )
#     rule_chart_sec = alt.Chart(sec_relevant_processes_pid_names).mark_rule(strokeDash=[5, 5]).encode(
#         x='min(delta_time):Q',color='name'
#     )

#     c2_sec = alt.Chart(sec_relevant_processes_pid_names).mark_line(color='red',interpolate='linear').encode(
#             alt.Y("CPU(%):Q"),
#             alt.X(f"delta_time:Q"),
#         ).properties(
#             width=1000,
#             height=500
#         )
#     mean_chart_sec = alt.Chart(sec_relevant_processes_pid_names).mark_rule(color='red', strokeDash=[5, 5]).encode(
#         y='mean(CPU(%)):Q'
#     )
#     with alt.data_transformers.enable('default'):
#         (c2_first+rule_chart_first+mean_chart_first+c2_sec+rule_chart_sec+mean_chart_sec).configure_legend(
#                 labelLimit=10000,
#                 labelFontSize=15
#             ).save(f"{path}/{measurment_name}/graphs/compare_cpu.html")

# %%
# # create histogram with mean rule
# hist = alt.Chart(first_relevant_processes_pid_names).mark_bar(color='red', opacity=0.2).encode(
#     alt.X('CPU(%)', bin=alt.Bin(step=0.2)),
#     y='count()'
# )

# mean_rule = alt.Chart(first_relevant_processes_pid_names).mark_rule(color='red').encode(
#     x='mean(CPU(%))'
# )
# # create histogram with mean rule
# hist_sec = alt.Chart(sec_relevant_processes_pid_names).mark_bar(color='green', opacity=0.2).encode(
#     alt.X('CPU(%)', bin=alt.Bin(step=0.2)),
#     y='count()'
# )

# mean_rule_sec = alt.Chart(sec_relevant_processes_pid_names).mark_rule(color='green').encode(
#     x='mean(CPU(%))'
# )

# # combine the two charts
# # combine the two charts and add a legend
# chart = alt.layer(hist, mean_rule, hist_sec, mean_rule_sec).properties(
#     title='Histogram of CPU',
#     width=500,
#     height=300
# )
# chart.configure_axis(
#     gridOpacity=0.5
# ).configure_view(
#     strokeWidth=0
# ).configure_title(
#     fontSize=20,
#     fontWeight='bold'
# ).configure_legend(
#     title=None,
#     labelFontSize=15
# )

# %%
# relevant_processes_pid_names.apply(lambda g: integrate.trapz(g['CPU(%)'], x=g['delta_time']), axis=1)

# %%
# # concatenate the three data frames along the columns axis
# merged_df_line = pd.concat([x.groupby(['name','time_window'])[['mean_col']].mean() for x in relevant_processes_pid_names_mean_windows_dict.values()], axis=1)
# durations = [1,2,3,4]
# num_of_different_durations = len([x for x in durations])
# # select even and odd columns from the 'CPU(%)' columns
# mean_std_df_line = pd.concat([merged_df_line.iloc[:, i::num_of_different_durations].agg(['mean', 'std'], axis=1).add_suffix('_'+str(durations[i])) for i in range(num_of_different_durations)], axis=1)
# # mean_std_df.iloc[:, 0:2].columns = mean_std_df.iloc[:, 0:2].add_suffix('_odd').columns
# # mean_std_df.iloc[:, 2:4].columns = mean_std_df.iloc[:, 2:4].add_suffix('_even').columns
# # print the final dataframe
# # mean_std_df_line.fillna(0, inplace=True)
# mean_std_df_line

# %%
# mean_df_line = mean_std_df_line[[x for x in mean_std_df_line.columns if x.startswith('mean')]].reset_index().melt(var_name='duration',id_vars='time_window')
# std_df_line =mean_std_df_line[[x for x in mean_std_df_line.columns if x.startswith('std')]].reset_index().melt(var_name='duration',id_vars='time_window')
# mean_df_line[['kind', 'duration']] = mean_df_line.duration.str.split('_', expand=True)
# std_df_line[['kind', 'duration']] = std_df_line.duration.str.split('_', expand=True)

# %%
# df_merged_mean_std = pd.merge(mean_df_line, std_df_line, on=['time_window', 'duration'])
# df_merged_mean_std

# %%
# # reshape dataframe using pivot
# df_pivot = df_merged_mean_std.pivot(index=['time_window', 'duration'], columns=['kind_x','kind_y'], values=['value_x', 'value_y']).reset_index()

# # rename columns
# df_pivot.columns = ['time_window', 'duration', 'mean', 'std']

# print(df_pivot)

# %%
# df_pivot['minus_std'] = df_pivot['mean'] + (-1) * df_pivot['std']
# df_pivot['pluse_std'] = df_pivot['mean'] + df_pivot['std']

# %%
# name_selection = alt.selection_multi(fields=['duration'], bind='legend')
# lines = alt.Chart(df_pivot).mark_line().encode(
#             alt.Y("mean:Q",title='Mean CPU(%)'),
#             alt.X(f"time_window:Q"),
#             alt.Color('duration:N'),
#             opacity=alt.condition(name_selection, alt.value(1), alt.value(0.1)),
#         ).transform_filter(
#     'isValid(datum.mean)'
# )

# # Create the shaded area for the standard deviation
# band = alt.Chart(df_pivot).mark_errorband().encode(
#     alt.Y("pluse_std:Q"),
#     alt.Y2("minus_std:Q"),
#     alt.X(f"time_window:Q"),
#     alt.Color('duration:N'),
#     opacity=alt.condition(name_selection, alt.value(0.2), alt.value(0.02)),
#     # yError="std:Q"
# )
# final_chart = (lines + band).properties(
#             width=1500,
#             height=500,
#             title="Mean and Std CPU usage along the time over 4 duration"
#         ).add_selection(name_selection).configure_legend(
#             labelLimit=10000,
#             columns=4,
#             labelFontSize=15
#         )

# %%
# with alt.data_transformers.enable('default'):
#     final_chart.save(f"interactive_line_all.html")

# %% [markdown]
# Merge when all the experiments were ran for the same duration

# %%
# # concatenate the three data frames along the columns axis
# merged_df = pd.concat([x[['CPU(%)']] for x in relevant_processes_pid_names_grouped_dict.values()], axis=1)
# # compute the mean along the index axis
# mean_std_df = merged_df.agg(['mean', 'std'],axis=1)
# print(f"Num of rules: {len(mean_std_df)}")
# mean_std_df
# Out:
# Num of rules: 4
#                                         mean       std
# name
# Increase in # of Hosts Logged int  11.153397  8.899271
# New Local Admin Account             8.048684  5.914846
# User Login with Local Credentials  12.492465  7.349813
# Windows Event Log Clearing Events   8.724837  6.269769

# %% [markdown]
# Merge between the same duration

# %%
# concatenate the three data frames along the columns axis
merged_df = pd.concat([x[['CPU(%)']] for x in relevant_processes_pid_names_grouped_dict.values()], axis=1)
# num_of_different_durations = len([x for x in durations])
# select even and odd columns from the 'CPU(%)' columns
cpus = []
for j, state in enumerate(field_state):
    for k, time in enumerate(times):
        cpus.extend([merged_df.iloc[:, (((i+1)*(j+1)*(k+1)-1) for i in range(num_of_experiments))].agg(['mean', 'std'], axis=1).add_suffix('_'+str(time)+' '+str(state))])
mean_std_df = pd.concat(cpus, axis=1)
# mean_std_df = pd.concat([merged_df.iloc[:, i::num_of_experiments*2].agg(['mean', 'std'], axis=1).add_suffix('_'+str(times[i])) for i in range(times)], axis=1)
# mean_std_df.iloc[:, 0:2].columns = mean_std_df.iloc[:, 0:2].add_suffix('_odd').columns
# mean_std_df.iloc[:, 2:4].columns = mean_std_df.iloc[:, 2:4].add_suffix('_even').columns
# print the final dataframe
mean_std_df
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[116], line 8
#       6 for j, state in enumerate(field_state):
#       7     for k, time in enumerate(times):
# ----> 8         cpus.extend([merged_df.iloc[:, (((i+1)*(j+1)*(k+1)-1) for i in range(num_of_experiments))].agg(['mean', 'std'], axis=1).add_suffix('_'+str(time)+' '+str(state))])
#       9 mean_std_df = pd.concat(cpus, axis=1)
#      10 # mean_std_df = pd.concat([merged_df.iloc[:, i::num_of_experiments*2].agg(['mean', 'std'], axis=1).add_suffix('_'+str(times[i])) for i in range(times)], axis=1)
#      11 # mean_std_df.iloc[:, 0:2].columns = mean_std_df.iloc[:, 0:2].add_suffix('_odd').columns
#      12 # mean_std_df.iloc[:, 2:4].columns = mean_std_df.iloc[:, 2:4].add_suffix('_even').columns
#      13 # print the final dataframe
#
# File ~/anaconda3/envs/py38/lib/python3.8/site-packages/pandas/core/indexing.py:1067, in _LocationIndexer.__getitem__(self, key)
#    1065     if self._is_scalar_access(key):
#    1066         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067     return self._getitem_tuple(key)
#    1068 else:
#    1069     # we by definition only have the 0th axis
#    1070     axis = self.axis or 0
#
# File ~/anaconda3/envs/py38/lib/python3.8/site-packages/pandas/core/indexing.py:1563, in _iLocIndexer._getitem_tuple(self, tup)
#    1561 def _getitem_tuple(self, tup: tuple):
# -> 1563     tup = self._validate_tuple_indexer(tup)
#    1564     with suppress(IndexingError):
#    1565         return self._getitem_lowerdim(tup)
#
# File ~/anaconda3/envs/py38/lib/python3.8/site-packages/pandas/core/indexing.py:873, in _LocationIndexer._validate_tuple_indexer(self, key)
#     871 for i, k in enumerate(key):
#     872     try:
# --> 873         self._validate_key(k, i)
#     874     except ValueError as err:
#     875         raise ValueError(
#     876             "Location based indexing can only have "
#     877             f"[{self._valid_types}] types"
#     878         ) from err
#
# File ~/anaconda3/envs/py38/lib/python3.8/site-packages/pandas/core/indexing.py:1481, in _iLocIndexer._validate_key(self, key, axis)
#    1479     # check that the key does not exceed the maximum size of the index
#    1480     if len(arr) and (arr.max() >= len_axis or arr.min() < -len_axis):
# -> 1481         raise IndexError("positional indexers are out-of-bounds")
#    1482 else:
#    1483     raise ValueError(f"Can only index by location with a [{self._valid_types}]")
#
# IndexError: positional indexers are out-of-bounds

# %%
mean_df =  mean_std_df.iloc[:, 0::2]
std_df = mean_std_df.iloc[:, 1::2]

# %%
# split name column to duration and state
mean_df = mean_df.T.reset_index()
std_df = std_df.T.reset_index()
mean_df[['duration', 'state']] = mean_df['index'].str.split(' ', expand=True)
std_df[['duration', 'state']] = std_df['index'].str.split(' ', expand=True)

# %%
# plot stacked bar chat with mean and std for each duration and state
mean_df = mean_df.drop(columns=['index'])
std_df = std_df.drop(columns=['index'])
mean_df = mean_df.set_index(['duration', 'state'])
std_df = std_df.set_index(['duration', 'state'])
mean_df = mean_df.stack().reset_index()
std_df = std_df.stack().reset_index()
mean_df.columns = ['duration', 'state', 'rule', 'value']
std_df.columns = ['duration', 'state', 'rule', 'value']
mean_df['rule'] = mean_df['rule'].str.strip('_mean')
std_df['rule'] = std_df['rule'].str.strip('_std')

# %%
alt.Chart(mean_df).mark_bar().encode(
    alt.Y("value:Q"),
    alt.X(f"state:N"),
    alt.Color('rule:N', scale=alt.Scale(scheme='category20')),
    column='duration:N'
).properties(
    width=100,
    height=300
)
# Out:
# alt.Chart(...)

# %%
# Set up the figure
# fig, ax = plt.subplots()
# df_to_plot = mean_std_df.reset_index().fillna(0)
# df_to_plot['std_15'] = df_to_plot['std_15'].astype(float)
# df_to_plot['std_30'] = df_to_plot['std_30'].astype(float)
# Plot the bars with error bars
for i in range(len(field_state)):  
    # ax = mean_std_df.reset_index()[["name"]+mean_cols].plot(x="name", kind="bar",capsize=4, rot=0, figsize=(20,9))
    ax = mean_df.iloc[:, len(times)*i:len(times)*(i+1)].reset_index().plot(x="duration", yerr=std_df.iloc[:, len(times)*i:len(times)*(i+1)].T.values, kind="bar", ,capsize=4, rot=0, figsize=(20,9))
    # ax.bar(mean_std_df.reset_index()['name'], mean_std_df.reset_index()[['mean_0','mean_1']], capsize=5)
    # plt.rcParams["figure.figsize"] = (20, 9)
    # Add axis labels and title
    ax.set_xlabel('Rule Name')
    ax.set_ylabel('Mean CPU(%)')
    ax.set_title('Bar chart with standard deviation error bars')
    # Rotate x-axis labels
    plt.xticks(rotation=45, ha='right')

    # Show the plot
    plt.show()

# %%
relevant_processes_pid_names.groupby('name').apply(lambda g: integrate.trapz(g['CPU(%)'], x=g['delta_time']))
# Out:
# name
# Increase in # of Hosts Logged int    139.540020
# New Local Admin Account               32.323367
# User Login with Local Credentials    208.340708
# Windows Event Log Clearing Events     40.679437
# dtype: float64

# %%
relevant_processes_pid_names.values
# Out:
# array([[Timestamp('2023-06-08 12:40:00.751596800+0000', tz='UTC'), 3666,
#         'splunkd', ..., 'Windows Event Log Clearing Events', 3666, 0.0],
#        [Timestamp('2023-06-08 12:40:00.934272256+0000', tz='UTC'), 3666,
#         'splunkd', ..., 'Windows Event Log Clearing Events', 3666,
#         0.182675456],
#        [Timestamp('2023-06-08 12:40:01.099630080+0000', tz='UTC'), 3666,
#         'splunkd', ..., 'Windows Event Log Clearing Events', 3666,
#         0.34803328],
#        ...,
#        [Timestamp('2023-06-08 12:40:12.189276416+0000', tz='UTC'), 4090,
#         'splunkd', ..., 'User Login with Local Credentials', 4090,
#         11.437679616],
#        [Timestamp('2023-06-08 12:40:12.252651264+0000', tz='UTC'), 4090,
#         'splunkd', ..., 'User Login with Local Credentials', 4090,
#         11.501054464],
#        [Timestamp('2023-06-08 12:40:12.327145984+0000', tz='UTC'), 4090,
#         'splunkd', ..., 'User Login with Local Credentials', 4090,
#         11.575549184]], dtype=object)

# %%
# concatenate the three data frames along the columns axis
merged_df = pd.concat([x for x in relevant_names_inegral_dict.values()], axis=1)
durations = [1]
num_of_different_durations = len([x for x in durations])
# select even and odd columns from the 'CPU(%)' columns
mean_std_df = pd.concat([merged_df.iloc[:, i::num_of_different_durations].agg(['mean', 'std'], axis=1).add_suffix('_'+str(durations[i])) for i in range(num_of_different_durations)], axis=1)
# mean_std_df.iloc[:, 0:2].columns = mean_std_df.iloc[:, 0:2].add_suffix('_odd').columns
# mean_std_df.iloc[:, 2:4].columns = mean_std_df.iloc[:, 2:4].add_suffix('_even').columns
# print the final dataframe
mean_std_df
# Out:
#                                        mean_1      std_1
# name
# Increase in # of Hosts Logged int  120.438259  21.381184
# New Local Admin Account             34.747182   2.299977
# User Login with Local Credentials  196.260893  39.319405
# Windows Event Log Clearing Events   38.973061   5.370882

# %%
# Set up the figure
# fig, ax = plt.subplots()
# df_to_plot = mean_std_df.reset_index().fillna(0)
# df_to_plot['std_15'] = df_to_plot['std_15'].astype(float)
# df_to_plot['std_30'] = df_to_plot['std_30'].astype(float)
# Plot the bars with error bars
mean_cols = [f"mean_{i}" for i in durations]
std_cols = [f"std_{i}" for i in durations]
ax = mean_std_df.reset_index()[["name"]+mean_cols].plot(x="name", yerr=mean_std_df[std_cols].T.values, kind="bar", rot=0, capsize=4, figsize=(20,9))
# ax.bar(mean_std_df.reset_index()['name'], mean_std_df.reset_index()[['mean_0','mean_1']], capsize=5)
# plt.rcParams["figure.figsize"] = (20, 9)
# Add axis labels and title
ax.set_xlabel('Rule Name')
ax.set_ylabel('Mean Integral')
ax.set_title('Integral of CPU over Time (Mean and Std)')
# Rotate x-axis labels
plt.xticks(rotation=45, ha='right')

# Show the plot
plt.show()

# %%
df.integral[0]
# Out:
# {'Windows Event Log Clearing Events': 39.66785027467283,
#  'New Local Admin Account': 35.41175174419554,
#  'Increase in # of Hosts Logged int': 111.11761702284639,
#  'User Login with Local Credentials': 172.57471908326698}

# %%
sum_df = df
sum_df['sum_integral'] = df.integral.apply(lambda x: sum(x.values()))

# %%
sum_df
# Out:
#                                             integral    duration  \
# 0  {'Windows Event Log Clearing Events': 39.66785...   enable_24
# 1  {'New Local Admin Account': 32.91334126636185,...   enable_48
# 2  {'Windows Event Log Clearing Events': 43.79784...  disable_24
# 3  {'Windows Event Log Clearing Events': 40.90465...  disable_48
#
#    measurment_num   kind  logs_number  sum_integral
# 0  Measurement 22   lite           76    358.771938
# 1  Measurement 23   lite           40    447.093561
# 2  Measurement 24  heavy           97    332.294769
# 3  Measurement 25  heavy            4    418.795795

# %%
df_group = sum_df.groupby(['duration','kind']).agg(['mean','std'])
df_group.columns = df_group.columns.to_flat_index()
df_group = df_group.reset_index()
df_group.columns = ['duration', 'kind','logs_number_mean','logs_number_std','sum_integral_mean','sum_integral_std']
df_group
# Out:
# /tmp/ipykernel_5789/3215586396.py:1: FutureWarning: ['integral', 'measurment_num'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df_group = sum_df.groupby(['duration','kind']).agg(['mean','std'])
#      duration   kind  logs_number_mean  logs_number_std  sum_integral_mean  \
# 0  disable_24  heavy              97.0              NaN         332.294769
# 1  disable_48  heavy               4.0              NaN         418.795795
# 2   enable_24   lite              76.0              NaN         358.771938
# 3   enable_48   lite              40.0              NaN         447.093561
#
#    sum_integral_std
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN

# %%
df_group['logs_number_std2'] = df_group['logs_number_mean']-df_group.logs_number_std/2
df_group['logs_number_std'] = df_group['logs_number_mean']+df_group.logs_number_std/2
df_group['sum_integral_std2'] = df_group['sum_integral_mean']-df_group.sum_integral_std/2
df_group['sum_integral_std'] = df_group['sum_integral_mean']+df_group.sum_integral_std/2
df_group
# Out:
#      duration   kind  logs_number_mean  logs_number_std  sum_integral_mean  \
# 0  disable_24  heavy              97.0              NaN         332.294769
# 1  disable_48  heavy               4.0              NaN         418.795795
# 2   enable_24   lite              76.0              NaN         358.771938
# 3   enable_48   lite              40.0              NaN         447.093561
#
#    sum_integral_std  logs_number_std2  sum_integral_std2
# 0               NaN               NaN                NaN
# 1               NaN               NaN                NaN
# 2               NaN               NaN                NaN
# 3               NaN               NaN                NaN

# %%
line = alt.Chart(df_group).mark_line(point=True).encode(
            alt.Y("sum_integral_mean:Q",title='Sum CPU(%) Integral over Time'),
            alt.X(f"logs_number_mean:Q",title='Count of ingested logs quantity'),
        ).properties(
    width=1000,
    height=400,
    title=''
)
line
# Out:
# alt.Chart(...)

# %%
x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 x
#
# NameError: name 'x' is not defined

# %%
sum_df
# Out:
#                                             integral    duration  \
# 0  {'Windows Event Log Clearing Events': 39.66785...   enable_24
# 1  {'New Local Admin Account': 32.91334126636185,...   enable_48
# 2  {'Windows Event Log Clearing Events': 43.79784...  disable_24
# 3  {'Windows Event Log Clearing Events': 40.90465...  disable_48
#
#    measurment_num   kind  logs_number  sum_integral
# 0  Measurement 22   lite           76    358.771938
# 1  Measurement 23   lite           40    447.093561
# 2  Measurement 24  heavy           97    332.294769
# 3  Measurement 25  heavy            4    418.795795

# %%
x = sum_df.pivot_table(columns=['kind'], index=['logs_number','duration'], values='sum_integral').reset_index().groupby('duration').agg(['mean','std']).fillna(0)
x.columns = x.columns.to_flat_index()
x.columns = ['logs_number_mean','logs_number_std','heavy_sum_integral_mean','heavy_sum_integral_std','lite_sum_integral_mean','lite_sum_integral_std']

# %%
x.plot(x='logs_number_mean',y=['lite_sum_integral_mean', 'heavy_sum_integral_mean'], yerr=x[['lite_sum_integral_std', 'heavy_sum_integral_std']], capsize=40)
# Out:
# <Axes: xlabel='logs_number_mean'>

# %%
import altair as alt

# Melt the dataframe to long format
df_long = df_group.melt(id_vars=['duration', 'kind'])

# Define the base chart with faceting
base_chart = alt.Chart(df_long).mark_line(point=True).encode(
    alt.Y('value:Q', title='Mean and Standard Deviation'),
    alt.X('logs_number:Q'),
    alt.Color('kind:N'),
    facet=alt.Facet('stat:N', title=None, columns=2),
)

# Add error bars to each panel
error_bars_chart = base_chart.mark_errorbar().encode(
    y='value:Q',
    yError='stderr:Q',
)

# Calculate the standard error of the mean for each group
stderr = df_group.groupby(['duration', 'kind']).agg('std') / df_group.groupby(['duration', 'kind']).agg('count')

# Layer the error bars on top of the base chart
chart = (base_chart + error_bars_chart).transform_calculate(
    stderr=alt.datum['std'] / alt.datum['count']**0.5
).properties(
    title='Mean and Standard Deviation with Error Bars'
)

chart.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[57], line 24
#      21 stderr = df_group.groupby(['duration', 'kind']).agg('std') / df_group.groupby(['duration', 'kind']).agg('count')
#      23 # Layer the error bars on top of the base chart
# ---> 24 chart = (base_chart + error_bars_chart).transform_calculate(
#      25     stderr=alt.datum['std'] / alt.datum['count']**0.5
#      26 ).properties(
#      27     title='Mean and Standard Deviation with Error Bars'
#      28 )
#      30 chart.show()
#
# File ~/anaconda3/envs/py38/lib/python3.8/site-packages/altair/vegalite/v5/api.py:955, in TopLevelMixin.__add__(self, other)
#     953 if not isinstance(other, TopLevelMixin):
#     954     raise ValueError("Only Chart objects can be layered.")
# --> 955 return layer(self, other)
#
# File ~/anaconda3/envs/py38/lib/python3.8/site-packages/altair/vegalite/v5/api.py:3053, in layer(*charts, **kwargs)
#    3051 def layer(*charts, **kwargs):
#    3052     """layer multiple charts"""
# -> 3053     return LayerChart(layer=charts, **kwargs)
#
# File ~/anaconda3/envs/py38/lib/python3.8/site-packages/altair/vegalite/v5/api.py:2973, in LayerChart.__init__(self, data, layer, **kwargs)
#    2971 for spec in layer:
#    2972     _check_if_valid_subspec(spec, "LayerChart")
# -> 2973     _check_if_can_be_layered(spec)
#    2974 super(LayerChart, self).__init__(data=data, layer=list(layer), **kwargs)
#    2975 self.data, self.layer = _combine_subchart_data(self.data, self.layer)
#
# File ~/anaconda3/envs/py38/lib/python3.8/site-packages/altair/vegalite/v5/api.py:2595, in _check_if_can_be_layered(spec)
#    2593     for channel in ["row", "column", "facet"]:
#    2594         if _get(encoding, channel) is not Undefined:
# -> 2595             raise ValueError(
#    2596                 "Faceted charts cannot be layered. Instead, layer the charts before faceting."
#    2597             )
#    2598 if isinstance(spec, (Chart, LayerChart)):
#    2599     return
#
# ValueError: Faceted charts cannot be layered. Instead, layer the charts before faceting.

# %%
df.groupby(['duration','kind']).plot(x='logs_number', y='integral',kind='bar')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/anaconda3/envs/py38/lib/python3.8/site-packages/pandas/core/groupby/groupby.py:1558, in GroupBy.apply(self, func, *args, **kwargs)
#    1557 try:
# -> 1558     result = self._python_apply_general(f, self._selected_obj)
#    1559 except TypeError:
#    1560     # gh-20949
#    1561     # try again, with .apply acting as a filtering
#    (...)
#    1565     # fails on *some* columns, e.g. a numeric operation
#    1566     # on a string grouper column
#
# File ~/anaconda3/envs/py38/lib/python3.8/site-packages/pandas/core/groupby/groupby.py:1610, in GroupBy._python_apply_general(self, f, data, not_indexed_same, is_transform, is_agg)
#    1582 """
#    1583 Apply function f in python space
#    1584
#    (...)
#    1608     data after applying f
#    1609 """
# -> 1610 values, mutated = self.grouper.apply(f, data, self.axis)
#    1611 if not_indexed_same is None:
#
# File ~/anaconda3/envs/py38/lib/python3.8/site-packages/pandas/core/groupby/ops.py:839, in BaseGrouper.apply(self, f, data, axis)
#     838 group_axes = group.axes
# --> 839 res = f(group)
#     840 if not mutated and not _is_indexed_like(res, group_axes, axis):
#
# File ~/anaconda3/envs/py38/lib/python3.8/site-packages/pandas/core/groupby/groupby.py:603, in GroupByPlot.__call__.<locals>.f(self)
#     602 def f(self):
# --> 603     return self.plot(*args, **kwargs)
#
# File ~/anaconda3/envs/py38/lib/python3.8/site-packages/pandas/plotting/_core.py:1000, in PlotAccessor.__call__(self, *args, **kwargs)
#     998             data.columns = label_name
# -> 1000 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~/anaconda3/envs/py38/lib/python3.8/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#
# File ~/anaconda3/envs/py38/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:450, in MPLPlot.generate(self)
#     449 self._args_adjust()
# --> 450 self._compute_plot_data()
#     451 self._setup_subplots()
#
# File ~/anaconda3/envs/py38/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:635, in MPLPlot._compute_plot_data(self)
#     634 if is_empty:
# --> 635     raise TypeError("no numeric data to plot")
#     637 self.data = numeric_data.apply(self._convert_to_ndarray)
#
# TypeError: no numeric data to plot
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 df.groupby(['duration','kind']).plot(x='logs_number', y='integral',kind='bar')
#
# File ~/anaconda3/envs/py38/lib/python3.8/site-packages/pandas/core/groupby/groupby.py:606, in GroupByPlot.__call__(self, *args, **kwargs)
#     603     return self.plot(*args, **kwargs)
#     605 f.__name__ = "plot"
# --> 606 return self._groupby.apply(f)
#
# File ~/anaconda3/envs/py38/lib/python3.8/site-packages/pandas/core/groupby/groupby.py:1569, in GroupBy.apply(self, func, *args, **kwargs)
#    1559     except TypeError:
#    1560         # gh-20949
#    1561         # try again, with .apply acting as a filtering
#    (...)
#    1565         # fails on *some* columns, e.g. a numeric operation
#    1566         # on a string grouper column
#    1568         with self._group_selection_context():
# -> 1569             return self._python_apply_general(f, self._selected_obj)
#    1571 return result
#
# File ~/anaconda3/envs/py38/lib/python3.8/site-packages/pandas/core/groupby/groupby.py:1610, in GroupBy._python_apply_general(self, f, data, not_indexed_same, is_transform, is_agg)
#    1573 @final
#    1574 def _python_apply_general(
#    1575     self,
#    (...)
#    1580     is_agg: bool = False,
#    1581 ) -> NDFrameT:
#    1582     """
#    1583     Apply function f in python space
#    1584
#    (...)
#    1608         data after applying f
#    1609     """
# -> 1610     values, mutated = self.grouper.apply(f, data, self.axis)
#    1611     if not_indexed_same is None:
#    1612         not_indexed_same = mutated or self.mutated
#
# File ~/anaconda3/envs/py38/lib/python3.8/site-packages/pandas/core/groupby/ops.py:839, in BaseGrouper.apply(self, f, data, axis)
#     837 # group might be modified
#     838 group_axes = group.axes
# --> 839 res = f(group)
#     840 if not mutated and not _is_indexed_like(res, group_axes, axis):
#     841     mutated = True
#
# File ~/anaconda3/envs/py38/lib/python3.8/site-packages/pandas/core/groupby/groupby.py:603, in GroupByPlot.__call__.<locals>.f(self)
#     602 def f(self):
# --> 603     return self.plot(*args, **kwargs)
#
# File ~/anaconda3/envs/py38/lib/python3.8/site-packages/pandas/plotting/_core.py:1000, in PlotAccessor.__call__(self, *args, **kwargs)
#     997             label_name = label_kw or data.columns
#     998             data.columns = label_name
# -> 1000 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~/anaconda3/envs/py38/lib/python3.8/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~/anaconda3/envs/py38/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:450, in MPLPlot.generate(self)
#     448 def generate(self) -> None:
#     449     self._args_adjust()
# --> 450     self._compute_plot_data()
#     451     self._setup_subplots()
#     452     self._make_plot()
#
# File ~/anaconda3/envs/py38/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:635, in MPLPlot._compute_plot_data(self)
#     633 # no non-numeric frames or series allowed
#     634 if is_empty:
# --> 635     raise TypeError("no numeric data to plot")
#     637 self.data = numeric_data.apply(self._convert_to_ndarray)
#
# TypeError: no numeric data to plot

# %%
import requests
from time import sleep

# Define the Splunk URL and login credentials
url = "https://132.72.81.185:8089/servicesNS/shoueii/splunkawssecuritymon/saved/searches/"
username = "shoueii"
password = "sH231294"

# Define the list of scheduled search names to enable/disable
searches_to_enable = ['aws_detect_cloudtrail_trail_deleted Clone1', 'aws_detect_cloudwatch_log_group_delete Clone1', 'aws_detect_cloudwatch_log_stream_delete Clone1', 'aws_detect_ec2_instances_run Clone1', 'aws_detect_ec2_vpc_flow_config_deleted Clone1', 'aws_detect_ecr_image_auth_token_get Clone1']
searches_to_disable = ['aws_detect_iam_user_deleted Clone', 'aws_detect_iam_user_created Clone', 'aws_detect_iam_new_policy_version_assignment Clone', 'aws_detect_iam_group_added_with_user_from_ec2 Clone', 'aws_detect_ecr_new_repo_image_create Clone', 'aws_detect_ec2_ssh_public_key_addition Clone']


for search_name in searches_to_enable:
    # Define the headers and payload for the request
    headers = {"Content-type": "application/json"}
    payload = {"disabled": 0}

    # Make the request to update the scheduled search
    response = requests.post(
        url + search_name + "/",
        headers=headers,
        auth=(username, password),
        data=payload,
        verify=False,
    )
    sleep(2)
    # Check the response status code
    if response.status_code == 200:
        print("Scheduled search updated successfully")
    else:
        print("Error updating scheduled search")
        print(response.content)
    

# Loop through the list of searches to disable and disable them
for search_name in searches_to_disable:
   # Define the headers and payload for the request
    headers = {"Content-type": "application/json"}
    payload = {"disabled": 1}

    # Make the request to update the scheduled search
    response = requests.post(
        url + search_name + "/",
        headers=headers,
        auth=(username, password),
        data=payload,
        verify=False,
    )

    # Check the response status code
    if response.status_code == 200:
        print("Scheduled search updated successfully")
    else:
        print("Error updating scheduled search")
        print(response.content)
# Out:
# /home/green-sec/miniconda3/lib/python3.10/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# Scheduled search updated successfully
# /home/green-sec/miniconda3/lib/python3.10/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# Scheduled search updated successfully
# /home/green-sec/miniconda3/lib/python3.10/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# Scheduled search updated successfully
# /home/green-sec/miniconda3/lib/python3.10/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# Scheduled search updated successfully
# /home/green-sec/miniconda3/lib/python3.10/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# Scheduled search updated successfully
# /home/green-sec/miniconda3/lib/python3.10/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# Scheduled search updated successfully
# /home/green-sec/miniconda3/lib/python3.10/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# Scheduled search updated successfully
# /home/green-sec/miniconda3/lib/python3.10/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# Scheduled search updated successfully
# /home/green-sec/miniconda3/lib/python3.10/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# Scheduled search updated successfully
# /home/green-sec/miniconda3/lib/python3.10/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# Scheduled search updated successfully
# /home/green-sec/miniconda3/lib/python3.10/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# Scheduled search updated successfully
# Scheduled search updated successfully
# /home/green-sec/miniconda3/lib/python3.10/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
import altair as alt
import pandas as pd
alt.data_transformers.enable('csv')
# Out:
# DataTransformerRegistry.enable('csv')

# %%
import altair as alt
import pandas as pd
df = pd.read_csv('data_summary.csv')
df_dtsplunk = df[df['host']=='dt-splunk']
df = df[df['host']!='dt-splunk']
# create stacked bar chart with x axis tilted 45 degrees
chart = alt.Chart(df).mark_bar().encode(
    alt.X('host:N', title='Host name'),
    alt.Y('count:Q', title='Logs count'),
    alt.Color('sourcetype:N', title='Log sourcetype'),
).properties(
    width=1500,
    height=300,
    title='24 hours Logs count per host and sourcetype'
).configure_axis(
    labelFontSize=8,
    titleFontSize=20,
    labelAngle=45
)
chart
# Out:
# alt.Chart(...)

# %%
df = pd.read_csv('eventtype_host.csv')
# create stacked bar chart with x axis tilted 45 degrees
chart = alt.Chart(df).mark_bar().encode(
    alt.X('host:N', title='Host name'),
    alt.Y('count:Q', title='Logs count'),
    alt.Color('eventtype:N', title='Log eventtype'),
).properties(
    width=1500,
    height=300,
    title='Last week Logs count per host and eventtype'
).configure_axis(
    labelFontSize=8,
    titleFontSize=20,
    labelAngle=45
)
chart
# Out:
# alt.Chart(...)

# %%
df
# Out:
# Empty DataFrame
# Columns: [eventtype, host, count]
# Index: []

# %%
# find all the hosts that starts with 'dt'
df = pd.read_csv('eventtype_host.csv')
df = df[df['host'].str.startswith('DT')]
# create stacked bar chart with x axis tilted 45 degrees
chart = alt.Chart(df).mark_bar().encode(
    alt.X('host:N', title='Host name'),
    alt.Y('count:Q', title='Logs count'),
).properties(
    width=1500,
    height=300,
    title='One week Logs count per host and sourcetype'
).configure_axis(
    labelFontSize=8,
    titleFontSize=20,
    labelAngle=45
)
chart
# Out:
# alt.Chart(...)

# %%
df = pd.read_csv('eventtype_hour_30.csv')
df.hour = pd.to_datetime(df.hour)
# create stacked bar chart with x axis tilted 45 degrees
chart = alt.Chart(df).mark_bar().encode(
    alt.X('hours(hour):T', title='Hour'),
    alt.Y('count:Q', title='Logs count'),
    alt.Color('eventtype:N', title='Log event type',sort=alt.SortField(field='count', order='descending')),
)
# add rule lines for sign the days
rule = alt.Chart(df).mark_rule(color='red', strokeDash=[5, 5]).encode(
    x='day:T'
).transform_timeunit(
    day='yearmonthdate(hour)'
)
(chart).properties(
    width=1500,
    height=300,
    title='Last month Logs count per event type'
).configure_axis(
    labelFontSize=15,
    titleFontSize=20,
    labelAngle=45
)
# Out:
# alt.Chart(...)

# %%
df = pd.read_csv('eventtype_hour_30.csv')
df.hour = pd.to_datetime(df.hour)
# create stacked bar chart with x axis tilted 45 degrees
chart = alt.Chart(df).mark_bar().encode(
    alt.X('day(hour):T', title='Day'),
    alt.Y('mean(count):Q', title='Logs count'),
    alt.Color('eventtype:N', title='Log event type',sort=alt.SortField(field='count', order='descending')),
)
# add rule lines for sign the days
rule = alt.Chart(df).mark_rule(color='red', strokeDash=[5, 5]).encode(
    x='day:T'
).transform_timeunit(
    day='yearmonthdate(hour)'
)
(chart).properties(
    width=1500,
    height=300,
    title='Last month Logs count per event type'
).configure_axis(
    labelFontSize=15,
    titleFontSize=20,
    labelAngle=45
)
# Out:
# alt.Chart(...)

# %%
df
# Out:
#                          eventtype                hour  count
# 0      endpoint_services_processes 2023-04-23 00:00:00    430
# 1      endpoint_services_processes 2023-04-23 01:00:00    626
# 2      endpoint_services_processes 2023-04-23 02:00:00    533
# 3      endpoint_services_processes 2023-04-23 03:00:00    839
# 4      endpoint_services_processes 2023-04-23 04:00:00    739
# ...                            ...                 ...    ...
# 16402                    winsystem 2023-05-23 19:00:00   2200
# 16403                    winsystem 2023-05-23 20:00:00   1379
# 16404                    winsystem 2023-05-23 21:00:00    102
# 16405                    winsystem 2023-05-23 22:00:00    200
# 16406                    winsystem 2023-05-23 23:00:00     16
#
# [16407 rows x 3 columns]

# %%
chart = alt.Chart(df).mark_line().encode(
    alt.X('yearmonthdate(hour):T', title='Hour'),
    alt.Y('mean(count):Q', title='Logs count'),
    alt.Color('eventtype:N', title='Log event type'),
)
# add rule lines for sign the days
rule = alt.Chart(df).mark_rule(color='red', strokeDash=[3, 3]).encode(
    x='day:T'
).transform_timeunit(
    day='yearmonthdate(hour)'
)
(chart+rule).properties(
    width=1500,
    height=300,
    title='Last month Logs count per event type'
).configure_axis(
    labelFontSize=15,
    titleFontSize=20,
    labelAngle=45
)
# Out:
# alt.LayerChart(...)

# %%
df[df.hour.dt.hour==7].groupby('eventtype').sum().sort_values('count', ascending=False)
# Out:
# /tmp/ipykernel_30871/2909946745.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df[df.hour.dt.hour==7].groupby('eventtype').sum().sort_values('count', ascending=False)
#                                   count
# eventtype
# endpoint_services_processes      700636
# windows_event_signature          700636
# wineventlog_windows              481102
# winsec                           314056
# wineventlog_security             314056
# ms-sysmon-regmod                 219265
# windows_account_management       127190
# wineventlog_system               100351
# winsystem                        100351
# windows_security_change           68404
# winapp                            66695
# wineventlog_application           66695
# windows_system_update             50075
# windows_security_authentication   47615
# windows_logon_success             47185
# windows_special_privileges        46170
# windows_security_change_account    8720
# windows_logoff                     8651
# windows_endpoint_services          5748
# windows_time_sync                  5209
# windows_logon_explicit              895
# windows_logon_failure               430
# windows_endpoint_processes          264
# windows_process_new                 246
# windows_system_update_status         66
# windows_security_access_removed      36
# windows_security_access_granted      36
# windows_account_password_set         29
# windows_account_modified             29
# windows_process_token                18
# windows_security_change_audit        15
# windows_audit_errors                 15
# windows_audit_log_stopped             3

# %%
# make pie chart from dt splunk
pie_chart = alt.Chart(df[df.hour.dt.hour==7]).mark_arc().encode(
    alt.Theta('count:Q', title='Logs count'),
    alt.Color('eventtype:N', title='Log eventtype',sort=alt.SortField(field='count', order='descending')),
).properties(
    width=800,
    height=800,
    title='Last month 7 am count per sourcetype'
)
pie_chart
# Out:
# alt.Chart(...)

# %%
# make pie chart from dt splunk
df = pd.read_csv('eventtype_source.csv')
chart = alt.Chart(df).mark_bar().encode(
    alt.Color('eventtype:N', title='Log eventtype'),
    alt.Y('count:Q', title='Logs count'),
    alt.X('source:N', title='source'),
).properties(
    width=1000,
    height=800,
    title='Last week DT-Splunk host Logs count per eventtype'
).configure_axis(
    labelFontSize=15,
    titleFontSize=20,
    labelAngle=45
).configure_legend(
    labelFontSize=15
)
chart
# Out:
# alt.Chart(...)

# %%
# make pie chart from dt splunk
pie_chart = alt.Chart(df_dtsplunk).mark_arc().encode(
    alt.Theta('count:Q', title='Logs count'),
    alt.Color('sourcetype:N', title='Log sourcetype',sort=alt.SortField(field='count', order='descending')),
).properties(
    width=600,
    height=500,
    title='24 hours DT-Splunk host Logs count per sourcetype'
)
pie_chart
# Out:
# alt.Chart(...)

# %%
hosts = pd.read_csv('last_2_weeks_hosts.csv')

# %%
hosts.host = hosts.host.str.lower()
hosts.sort_values('host', ascending=True)
# cancel show all the df config
alt.data_transformers.disable_max_rows()
# Out:
# DataTransformerRegistry.enable('csv')

# %%
df.user.unique()
# Out:
# array(['CYB301-4$', 'Guest', 'LOCAL SERVICE', 'NETWORK SERVICE',
#        'NOT_TRANSLATED', 'SYSTEM', 'tigranb', 'yevsikov', 'Administrator',
#        'CYB301-ATAM-20$', 'D77C167F-2E40-48BC-B64A-E12FAD864D2F',
#        'DefaultAccount', 'WDAGUtilityAccount', 'muralidh',
#        'CYB301-ATAM-21$', '-', 'DT-117-01$', 'DWM-1', 'UMFD-0', 'UMFD-1',
#        'idodah', 'DT-AWS-NEO4J-2$', 'DT-CTI-DRL$', 'DT-IT$', 'R18-ILYA$',
#        'adinr', 'bsrelan', 'nicolayg', 'DT-JAIDIP$', 'DT-O2$', 'salitsl',
#        'DT-O5$', 'vitals', 'yehudith', 'yehudith@bgu-users', 'DT-O7$',
#        'DWM-2', 'UMFD-2', 'admin', 'yovell', 'DT-PRINT$', 'Eitan',
#        'dvaleria', 'freidiya', 'ilialey', 'ANONYMOUS LOGON', 'DT-WDS$',
#        'peledf@bgu.ac.il', 'DTS12-VM1$', 'SQLSERVERAGENT', 'DTS12-VM2$',
#        'MSSQLServerOLAPService', 'ISE-MGMT$', 'LB-003-1$', 'LB-003-10$',
#        'LB-003-11$', 'LB-003-12$', 'LB-003-13$', 'LB-003-14$',
#        'LB-003-15$', 'LB-003-16$', 'LB-003-17$', 'LB-003-18$',
#        'LB-003-19$', 'LB-003-2$', 'LB-003-20$', 'LB-003-21$',
#        'LB-003-22$', 'LB-003-25$', 'LB-003-26$', '654', 'LB-003-27$', '`',
#        'LB-003-29$', 'LB-003-3$', 'omerad', 'v cvv', 'LB-003-30$',
#        'LB-003-31$', 'LB-003-4$', 'LB-003-5$', 'LB-003-6$', 'DWM-3',
#        'LB-003-7$', 'UMFD-3', 'tomtal', 'LB-003-8$', 'LB-003-9$',
#        'avamit', 'LB-101-1$', 'LB-101-10$', 'LB-101-11$', 'LB-101-12$',
#        'LB-101-14$', 'LB-101-15$', 'LB-101-16$', 'LB-101-17$',
#        'LB-101-18$', 'LB-101-19$', 'LB-101-2$', 'LB-101-20$', 'DWM-6',
#        'DWM-7', 'LB-101-21$', 'UMFD-5', 'UMFD-6', 'UMFD-7', 'nadavrav',
#        'LB-101-22$', 'LB-101-23$', 'LB-101-24$', 'LB-101-25$',
#        'LB-101-26$', 'LB-101-27$', 'LB-101-28$', 'LB-101-29$',
#        'LB-101-3$', 'LB-101-30$', 'LB-101-31$', 'mickaelz', 'LB-101-6$',
#        'LB-101-7$', 'LB-101-9$', 'LB-105-1$', 'LB-105-11$', 'LB-105-12$',
#        'LB-105-14$', 'LB-105-15$', 'LB-105-16$', 'LB-105-17$',
#        'LB-105-18$', 'almta', 'LB-105-19$', '/*', 'LB-105-2$',
#        'LB-105-20$', 'LB-105-21$', 'LB-105-24$', 'LB-105-25$',
#        'LB-105-26$', 'LB-105-27$', 'LB-105-29$', 'LB-105-3$',
#        'LB-105-30$', 'LB-105-31$', 'LB-105-4$', 'LB-105-5$', 'LB-105-7$',
#        'LB-105-8$', 'LB-105-9$', 'LB-107-1$', 'LB-107-10$', 'LB-107-11$',
#        'LB-107-12$', 'LB-107-13$', 'LB-107-15$', 'DWM-11', 'DWM-12',
#        'LB-107-16$', 'UMFD-11', 'UMFD-12', 'DWM-4', 'DWM-5', 'LB-107-17$',
#        'UMFD-4', 'USER', 'ehsan', 'ehsank', 'user', 'LB-107-2$',
#        'LB-107-4$', 'LB-107-5$', 'LB-107-6$', 'LB-107-7$', 'LB-107-8$',
#        'LB-107-9$', 'LB-111-10$', 'LB-111-11$', 'LB-111-12$',
#        'LB-111-13$', 'LB-111-14$', 'LB-111-15$', 'LB-111-16$',
#        'LB-111-17$', 'LB-111-18$', 'LB-111-19$', 'LB-111-2$',
#        'LB-111-20$', 'LB-111-21$', 'LB-111-3$', 'LB-111-4$', 'LB-111-6$',
#        'LB-111-7$', 'LB-111-8$', 'LB105-1$', 'LB105-2$'], dtype=object)

# %%
df = pd.read_csv('host_host_type_user_24h.csv')
df = df[df.host_type=='dt']
chart = alt.Chart(df).mark_bar().encode(
    alt.Color('host:N', title='host'),
    alt.Y('count:Q', title='Logs count'),
    alt.X('user:N', title='user_name',sort=alt.SortField(field='host_type', order='descending')),
).properties(
    width=2500,
    height=600,
    title='hosts'
).configure_axis(
    labelFontSize=15,
    titleFontSize=20,
    labelAngle=45
).configure_legend(
    labelFontSize=15
)
chart
# Out:
# alt.Chart(...)

# %%
df = pd.read_csv('source_host_type_user_24h.csv')
df = df[df.host_type=='dt']
chart = alt.Chart(df).mark_bar().encode(
    alt.Color('source:N', title='host'),
    alt.Y('count:Q', title='Logs count'),
    alt.X('user:N', title='user_name',sort=alt.SortField(field='host_type', order='descending')),
).properties(
    width=2500,
    height=600,
    title='hosts'
).configure_axis(
    labelFontSize=15,
    titleFontSize=20,
    labelAngle=45
).configure_legend(
    labelFontSize=15
)
chart
# Out:
# alt.Chart(...)

# %%
df = pd.read_csv('host_type_host_24h.csv')
chart = alt.Chart(df).mark_bar().encode(
    alt.Color('host_type:N', title='host_type'),
    alt.Y('count:Q', title='Logs count'),
    alt.X('host:N', title='host',sort=alt.SortField(field='host_type', order='descending')),
).properties(
    width=2500,
    height=600,
    title='hosts'
).configure_axis(
    labelFontSize=15,
    titleFontSize=20,
    labelAngle=45
).configure_legend(
    labelFontSize=15
)
chart

# %%
df = pd.read_csv('host_type_source_24h.csv')
chart = alt.Chart(df).mark_bar().encode(
    alt.X('host_type:N', title='host_type'),
    alt.Y('count:Q', title='Logs count'),
    alt.Color('source:N', title='source'),
).properties(
    width=800,
    height=600,
    title='hosts sources'
).configure_axis(
    labelFontSize=15,
    titleFontSize=20,
    labelAngle=45
).configure_legend(
    labelFontSize=15,
    labelLimit=10000
)
chart
# Out:
# alt.Chart(...)
